# %% [markdown]
# # Groundwater head data curation
# This notebook describes setting up of groundwater head data for use with OLPROC.
#
# ## Background

# %% [markdown]
# ## Aim and purpose
# The purpose of this notebook is to curate raw head data for use with OLPROC. This notebook must be run before the notebook that curates `head-stage differences`.

# %% [markdown]
# Essential imports:

# %%
import os
import numpy as np
import pandas as pd
import pyemu
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})

import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
plt.rcParams.update({'font.size': 14})

# %%
data_dir = os.path.join('..', '..', 'data', 'raw_data', 'head')
obs_dir =  os.path.join('..', '..', 'data', 'observations')
assert(data_dir)
assert(obs_dir)

# %%
os.listdir(data_dir)
# Out:
# ['.ipynb_checkpoints',
#  'B10-1.csv',
#  'B14-1.csv',
#  'B15-1.csv',
#  'B16-1.csv',
#  'B2-1.csv',
#  'B22-1.csv',
#  'B26.csv',
#  'B29.csv',
#  'B34.csv',
#  'B35.csv',
#  'B36.csv',
#  'B37.csv',
#  'B4.csv',
#  'B8-2.csv',
#  'B9-2.csv',
#  'KB1-1.csv',
#  'KB4-3.csv',
#  'NI1403-2.csv',
#  'NI1404-1.csv',
#  'NI1405-1.csv',
#  'NI1407-2.csv',
#  'NI1408-1.csv',
#  'NI1409-1.csv',
#  'NI1410-1.csv',
#  'NI1412-1.csv',
#  'NI1412-3.csv',
#  'NI15-O1.csv',
#  'NI15-O44.csv',
#  'NI15-O46.csv',
#  'NI15-O47.csv',
#  'NI15-O48.csv',
#  'NI1501-3.csv',
#  'NI1502-2.csv',
#  'NI1504-2.csv',
#  'NI1505-2.csv',
#  'NI1506-1.csv',
#  'NI1507-2.csv',
#  'NI1601-3.csv',
#  'NI1602-1.csv',
#  'NI1603-1.csv',
#  'NI1605-1.csv',
#  'NI1606-1.csv',
#  'NI1607-2.csv',
#  'NI1608-1.csv',
#  'NI1609-2.csv',
#  'NI1610-2.csv',
#  'NI1611-1.csv',
#  'NI1612-1.csv',
#  'NI1613-1.csv',
#  'NI1701-1.csv',
#  'NI1702-1.csv',
#  'NI1703-1.csv',
#  'NI1703-2.csv',
#  'NI1704-1.csv',
#  'NI1705-1.csv',
#  'NI1706-1.csv',
#  'NI1707-1.csv',
#  'NI1708-1.csv',
#  'NI1709-1.csv',
#  'NI1711-1.csv',
#  'NI1712-1.csv',
#  'NI1801-1.csv',
#  'NI1802-1.csv',
#  'NI1803-1.csv',
#  'NI1804-1.csv',
#  'readme.md']

# %% [markdown]
# Load up the raw data:

# %%
head_data = {}

# %%
for file in os.listdir(data_dir):
    if '.csv' in file:
        head_data[file.replace('.csv', '')] = pd.read_csv(os.path.join(data_dir, file))

# %%
#df_test = pd.read_csv(os.path.join(data_dir, 'NI15-O44.csv'))

# %%
#df_test['head']

# %%
for key,value in head_data.items():
    print(f'No. rows in {key}: {len(value)}')
# Out:
# No. rows in B10-1: 5
# No. rows in B14-1: 3
# No. rows in B15-1: 4
# No. rows in B16-1: 3
# No. rows in B2-1: 6347
# No. rows in B22-1: 4
# No. rows in B26: 4
# No. rows in B29: 3
# No. rows in B34: 4
# No. rows in B35: 320
# No. rows in B36: 320
# No. rows in B37: 1921
# No. rows in B4: 3
# No. rows in B8-2: 6
# No. rows in B9-2: 5
# No. rows in KB1-1: 2971
# No. rows in KB4-3: 2020
# No. rows in NI1403-2: 3
# No. rows in NI1404-1: 5
# No. rows in NI1405-1: 3
# No. rows in NI1407-2: 4
# No. rows in NI1408-1: 3
# No. rows in NI1409-1: 1
# No. rows in NI1410-1: 4
# No. rows in NI1412-1: 328
# No. rows in NI1412-3: 326
# No. rows in NI15-O1: 6079
# No. rows in NI15-O44: 6345
# No. rows in NI15-O46: 3310
# No. rows in NI15-O47: 2008
# No. rows in NI15-O48: 6349
# No. rows in NI1501-3: 3059
# No. rows in NI1502-2: 4
# No. rows in NI1504-2: 4
# No. rows in NI1505-2: 3
# No. rows in NI1506-1: 2
# No. rows in NI1507-2: 5
# No. rows in NI1601-3: 4
# No. rows in NI1602-1: 4
# No. rows in NI1603-1: 979
# No. rows in NI1605-1: 1021
# No. rows in NI1606-1: 3
# No. rows in NI1607-2: 1021
# No. rows in NI1608-1: 3
# No. rows in NI1609-2: 2
# No. rows in NI1610-2: 2
# No. rows in NI1611-1: 976
# No. rows in NI1612-1: 976
# No. rows in NI1613-1: 976
# No. rows in NI1701-1: 2
# No. rows in NI1702-1: 2
# No. rows in NI1703-1: 976
# No. rows in NI1703-2: 976
# No. rows in NI1704-1: 5
# No. rows in NI1705-1: 13
# No. rows in NI1706-1: 4
# No. rows in NI1707-1: 5
# No. rows in NI1708-1: 1
# No. rows in NI1709-1: 1
# No. rows in NI1711-1: 1
# No. rows in NI1712-1: 976
# No. rows in NI1801-1: 9
# No. rows in NI1802-1: 4529
# No. rows in NI1803-1: 9
# No. rows in NI1804-1: 9

# %% [markdown]
# Ensure datetime columns contain actual datetime values

# %%
for key,value in head_data.items():
    print(key)
    head_data[key]['datetime'] = pd.to_datetime(head_data[key]['datetime'])
    head_data[key]['head'] = head_data[key]['head'].replace('\t', '')
    head_data[key]['head'] = head_data[key]['head'].astype(float)
# Out:
# B10-1
# B14-1
# B15-1
# B16-1
# B2-1
# B22-1
# B26
# B29
# B34
# B35
# B36
# B37
# B4
# B8-2
# B9-2
# KB1-1
# KB4-3
# NI1403-2
# NI1404-1
# NI1405-1
# NI1407-2
# NI1408-1
# NI1409-1
# NI1410-1
# NI1412-1
# NI1412-3
# NI15-O1
# NI15-O44
# NI15-O46
# NI15-O47
# NI15-O48
# NI1501-3
# NI1502-2
# NI1504-2
# NI1505-2
# NI1506-1
# NI1507-2
# NI1601-3
# NI1602-1
# NI1603-1
# NI1605-1
# NI1606-1
# NI1607-2
# NI1608-1
# NI1609-2
# NI1610-2
# NI1611-1
# NI1612-1
# NI1613-1
# NI1701-1
# NI1702-1
# NI1703-1
# NI1703-2
# NI1704-1
# NI1705-1
# NI1706-1
# NI1707-1
# NI1708-1
# NI1709-1
# NI1711-1
# NI1712-1
# NI1801-1
# NI1802-1
# NI1803-1
# NI1804-1

# %% [markdown]
# ### Visualize the data
# Let's visualize the raw data just to familiarize ourselves with it:

# %%
df = pd.concat(head_data).reset_index()
df.rename(columns={'level_0': 'site'}, inplace=True) # Rename the column

# %%
df.loc[df['datetime'].astype(str).str.contains('NaT')]['site'].unique()
# Out:
# array(['NI1605-1', 'NI1703-2', 'NI1802-1'], dtype=object)

# %%
plt.figure(figsize=(12, 6))
for site in df['site'].unique():
    print(f'Plotting {site}')
    x = df.loc[df['site'] == site]['datetime']
    y = df.loc[df['site'] == site]['head']
    plt.plot(x, y, label=site)
plt.legend()
plt.title('Head data, meters above sea level.', fontsize=14)
plt.tight_layout()
# Out:
# Plotting B10-1
# Plotting B14-1
# Plotting B15-1
# Plotting B16-1
# Plotting B2-1
# Plotting B22-1
# Plotting B26
# Plotting B29
# Plotting B34
# Plotting B35
# Plotting B36
# Plotting B37
# Plotting B4
# Plotting B8-2
# Plotting B9-2
# Plotting KB1-1
# Plotting KB4-3
# Plotting NI1403-2
# Plotting NI1404-1
# Plotting NI1405-1
# Plotting NI1407-2
# Plotting NI1408-1
# Plotting NI1409-1
# Plotting NI1410-1
# Plotting NI1412-1
# Plotting NI1412-3
# Plotting NI15-O1
# Plotting NI15-O44
# Plotting NI15-O46
# Plotting NI15-O47
# Plotting NI15-O48
# Plotting NI1501-3
# Plotting NI1502-2
# Plotting NI1504-2
# Plotting NI1505-2
# Plotting NI1506-1
# Plotting NI1507-2
# Plotting NI1601-3
# Plotting NI1602-1
# Plotting NI1603-1
# Plotting NI1605-1
# Plotting NI1606-1
# Plotting NI1607-2
# Plotting NI1608-1
# Plotting NI1609-2
# Plotting NI1610-2
# Plotting NI1611-1
# Plotting NI1612-1
# Plotting NI1613-1
# Plotting NI1701-1
# Plotting NI1702-1
# Plotting NI1703-1
# Plotting NI1703-2
# Plotting NI1704-1
# Plotting NI1705-1
# Plotting NI1706-1
# Plotting NI1707-1
# Plotting NI1708-1
# Plotting NI1709-1
# Plotting NI1711-1
# Plotting NI1712-1
# Plotting NI1801-1
# Plotting NI1802-1
# Plotting NI1803-1
# Plotting NI1804-1
# <ipython-input-62-9f1a619cb2f1>:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Resample head data
# Resample the data into daily average values:

# %%
head_data_resamp = {}

# %%
for site, dataframe in head_data.items():
    print(f'Resampling: {site}')
    head_data_resamp[site] = dataframe.resample('d', on='datetime').mean().dropna(how='all')
# Out:
# Resampling: B10-1
# Resampling: B14-1
# Resampling: B15-1
# Resampling: B16-1
# Resampling: B2-1
# Resampling: B22-1
# Resampling: B26
# Resampling: B29
# Resampling: B34
# Resampling: B35
# Resampling: B36
# Resampling: B37
# Resampling: B4
# Resampling: B8-2
# Resampling: B9-2
# Resampling: KB1-1
# Resampling: KB4-3
# Resampling: NI1403-2
# Resampling: NI1404-1
# Resampling: NI1405-1
# Resampling: NI1407-2
# Resampling: NI1408-1
# Resampling: NI1409-1
# Resampling: NI1410-1
# Resampling: NI1412-1
# Resampling: NI1412-3
# Resampling: NI15-O1
# Resampling: NI15-O44
# Resampling: NI15-O46
# Resampling: NI15-O47
# Resampling: NI15-O48
# Resampling: NI1501-3
# Resampling: NI1502-2
# Resampling: NI1504-2
# Resampling: NI1505-2
# Resampling: NI1506-1
# Resampling: NI1507-2
# Resampling: NI1601-3
# Resampling: NI1602-1
# Resampling: NI1603-1
# Resampling: NI1605-1
# Resampling: NI1606-1
# Resampling: NI1607-2
# Resampling: NI1608-1
# Resampling: NI1609-2
# Resampling: NI1610-2
# Resampling: NI1611-1
# Resampling: NI1612-1
# Resampling: NI1613-1
# Resampling: NI1701-1
# Resampling: NI1702-1
# Resampling: NI1703-1
# Resampling: NI1703-2
# Resampling: NI1704-1
# Resampling: NI1705-1
# Resampling: NI1706-1
# Resampling: NI1707-1
# Resampling: NI1708-1
# Resampling: NI1709-1
# Resampling: NI1711-1
# Resampling: NI1712-1
# Resampling: NI1801-1
# Resampling: NI1802-1
# Resampling: NI1803-1
# Resampling: NI1804-1

# %%
print('Data points after resampling to daily averages...')
for key,value in head_data_resamp.items():
    print(f'No. rows in {key}: {len(value)}')
# Out:
# Data points after resampling to daily averages...
# No. rows in B10-1: 5
# No. rows in B14-1: 3
# No. rows in B15-1: 4
# No. rows in B16-1: 3
# No. rows in B2-1: 1060
# No. rows in B22-1: 4
# No. rows in B26: 4
# No. rows in B29: 3
# No. rows in B34: 4
# No. rows in B35: 54
# No. rows in B36: 54
# No. rows in B37: 325
# No. rows in B4: 3
# No. rows in B8-2: 6
# No. rows in B9-2: 5
# No. rows in KB1-1: 419
# No. rows in KB4-3: 341
# No. rows in NI1403-2: 3
# No. rows in NI1404-1: 5
# No. rows in NI1405-1: 3
# No. rows in NI1407-2: 4
# No. rows in NI1408-1: 3
# No. rows in NI1409-1: 1
# No. rows in NI1410-1: 4
# No. rows in NI1412-1: 59
# No. rows in NI1412-3: 55
# No. rows in NI15-O1: 1018
# No. rows in NI15-O44: 1060
# No. rows in NI15-O46: 557
# No. rows in NI15-O47: 339
# No. rows in NI15-O48: 1064
# No. rows in NI1501-3: 515
# No. rows in NI1502-2: 4
# No. rows in NI1504-2: 4
# No. rows in NI1505-2: 3
# No. rows in NI1506-1: 2
# No. rows in NI1507-2: 5
# No. rows in NI1601-3: 4
# No. rows in NI1602-1: 4
# No. rows in NI1603-1: 85
# No. rows in NI1605-1: 1
# No. rows in NI1606-1: 3
# No. rows in NI1607-2: 171
# No. rows in NI1608-1: 3
# No. rows in NI1609-2: 2
# No. rows in NI1610-2: 2
# No. rows in NI1611-1: 82
# No. rows in NI1612-1: 82
# No. rows in NI1613-1: 82
# No. rows in NI1701-1: 2
# No. rows in NI1702-1: 2
# No. rows in NI1703-1: 82
# No. rows in NI1703-2: 82
# No. rows in NI1704-1: 5
# No. rows in NI1705-1: 13
# No. rows in NI1706-1: 4
# No. rows in NI1707-1: 5
# No. rows in NI1708-1: 1
# No. rows in NI1709-1: 1
# No. rows in NI1711-1: 1
# No. rows in NI1712-1: 82
# No. rows in NI1801-1: 9
# No. rows in NI1802-1: 416
# No. rows in NI1803-1: 9
# No. rows in NI1804-1: 9

# %%
df_resampled = pd.concat(head_data_resamp).reset_index()
df_resampled.rename(columns={'level_0': 'site'}, inplace=True) # Rename the column

# %% [markdown]
# ### Visualize both raw and processed data
# Lines in color show raw data. Black lines show daily average data. It is the daily average data that will be used as input for OLPROC, as well as for comparison with head data for each individual site.

# %%
plt.figure(figsize=(12, 6))
for site in df['site'].unique():
    x = df.loc[df['site'] == site]['datetime']
    y = df.loc[df['site'] == site]['head']
    plt.plot(x, y, label=site)
for site in df_resampled['site'].unique():
    x = df_resampled.loc[df_resampled['site'] == site]['datetime']
    y = df_resampled.loc[df_resampled['site'] == site]['head']
    plt.plot(x, y, label=f'{site} daily average', color='black', linewidth=2)
plt.legend()
plt.title('Head data, meters above sea level.', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Head data, meters above sea level.')

# %% [markdown]
# Terrible, terrible plot. Anyways, it can be discerned that daily averages represent the raw data to a satisfactory degree, with the exception of a limited number of days where intra-day variations were substantial.

# %% [markdown]
# ## Prepare datasets for OLPROC

# %%
df_resampled
# Out:
#           site   datetime     head  Unnamed: 2  Unnamed: 3
# 0        B10-1 2015-06-01  133.800         NaN         NaN
# 1        B10-1 2016-06-17  133.695         NaN         NaN
# 2        B10-1 2016-11-15  133.620         NaN         NaN
# 3        B10-1 2017-06-15  133.480         NaN         NaN
# 4        B10-1 2018-11-15  133.425         NaN         NaN
# ...        ...        ...      ...         ...         ...
# 8244  NI1804-1 2019-03-26  134.268         NaN         NaN
# 8245  NI1804-1 2019-04-23  134.185         NaN         NaN
# 8246  NI1804-1 2019-05-28  134.240         NaN         NaN
# 8247  NI1804-1 2019-06-25  134.130         NaN         NaN
# 8248  NI1804-1 2019-08-07  134.100         NaN         NaN
#
# [8249 rows x 5 columns]

# %%
df_resampled.site = df_resampled.site.str.lower()

# %%
df_resampled
# Out:
#           site   datetime     head  Unnamed: 2  Unnamed: 3
# 0        b10-1 2015-06-01  133.800         NaN         NaN
# 1        b10-1 2016-06-17  133.695         NaN         NaN
# 2        b10-1 2016-11-15  133.620         NaN         NaN
# 3        b10-1 2017-06-15  133.480         NaN         NaN
# 4        b10-1 2018-11-15  133.425         NaN         NaN
# ...        ...        ...      ...         ...         ...
# 8244  ni1804-1 2019-03-26  134.268         NaN         NaN
# 8245  ni1804-1 2019-04-23  134.185         NaN         NaN
# 8246  ni1804-1 2019-05-28  134.240         NaN         NaN
# 8247  ni1804-1 2019-06-25  134.130         NaN         NaN
# 8248  ni1804-1 2019-08-07  134.100         NaN         NaN
#
# [8249 rows x 5 columns]

# %%
loc_df = pd.read_csv(os.path.join(obs_dir, 'measurement_positions.csv'))
display(loc_df)
# Out:
#             name            x            y    type
# 0          b10-1  427074.7094  6654805.174    head
# 1          b14-1  427474.4248  6655148.009    head
# 2          b15-1  427480.5444  6655184.865    head
# 3          b16-1  427409.5473  6655023.271    head
# 4           b2-1  427384.1720  6655037.189    head
# ..           ...          ...          ...     ...
# 65  ni15-o46-stg  427316.2934  6655000.158   stage
# 66  ni15-o47-stg  427294.9467  6654962.316   stage
# 67  ni15-o48-stg  427166.6707  6654946.617   stage
# 68        gage-1  427070.6140  6654948.935  inflow
# 69        gage-2  427030.7600  6654934.260  inflow
#
# [70 rows x 4 columns]

# %%
df_resampled['layer'] = 0
df_resampled
# Out:
#           site   datetime     head  Unnamed: 2  Unnamed: 3  layer
# 0        b10-1 2015-06-01  133.800         NaN         NaN      0
# 1        b10-1 2016-06-17  133.695         NaN         NaN      0
# 2        b10-1 2016-11-15  133.620         NaN         NaN      0
# 3        b10-1 2017-06-15  133.480         NaN         NaN      0
# 4        b10-1 2018-11-15  133.425         NaN         NaN      0
# ...        ...        ...      ...         ...         ...    ...
# 8244  ni1804-1 2019-03-26  134.268         NaN         NaN      0
# 8245  ni1804-1 2019-04-23  134.185         NaN         NaN      0
# 8246  ni1804-1 2019-05-28  134.240         NaN         NaN      0
# 8247  ni1804-1 2019-06-25  134.130         NaN         NaN      0
# 8248  ni1804-1 2019-08-07  134.100         NaN         NaN      0
#
# [8249 rows x 6 columns]

# %%
for well in df_resampled.site.unique():
    print(well)
# Out:
# b10-1
# b14-1
# b15-1
# b16-1
# b2-1
# b22-1
# b26
# b29
# b34
# b35
# b36
# b37
# b4
# b8-2
# b9-2
# kb1-1
# kb4-3
# ni1403-2
# ni1404-1
# ni1405-1
# ni1407-2
# ni1408-1
# ni1409-1
# ni1410-1
# ni1412-1
# ni1412-3
# ni15-o1
# ni15-o44
# ni15-o46
# ni15-o47
# ni15-o48
# ni1501-3
# ni1502-2
# ni1504-2
# ni1505-2
# ni1506-1
# ni1507-2
# ni1601-3
# ni1602-1
# ni1603-1
# ni1605-1
# ni1606-1
# ni1607-2
# ni1608-1
# ni1609-2
# ni1610-2
# ni1611-1
# ni1612-1
# ni1613-1
# ni1701-1
# ni1702-1
# ni1703-1
# ni1703-2
# ni1704-1
# ni1705-1
# ni1706-1
# ni1707-1
# ni1708-1
# ni1709-1
# ni1711-1
# ni1712-1
# ni1801-1
# ni1802-1
# ni1803-1
# ni1804-1

# %%
df_resampled
# Out:
#           site   datetime     head  Unnamed: 2  Unnamed: 3  layer
# 0        b10-1 2015-06-01  133.800         NaN         NaN      0
# 1        b10-1 2016-06-17  133.695         NaN         NaN      0
# 2        b10-1 2016-11-15  133.620         NaN         NaN      0
# 3        b10-1 2017-06-15  133.480         NaN         NaN      0
# 4        b10-1 2018-11-15  133.425         NaN         NaN      0
# ...        ...        ...      ...         ...         ...    ...
# 8244  ni1804-1 2019-03-26  134.268         NaN         NaN      0
# 8245  ni1804-1 2019-04-23  134.185         NaN         NaN      0
# 8246  ni1804-1 2019-05-28  134.240         NaN         NaN      0
# 8247  ni1804-1 2019-06-25  134.130         NaN         NaN      0
# 8248  ni1804-1 2019-08-07  134.100         NaN         NaN      0
#
# [8249 rows x 6 columns]

# %% [markdown]
# Perhaps a redundant step, but for brevities sake let's change the clock hour for each datetime entry from 00:00:00 to 12:00:00, to better reflect that data represent daily average stage:

# %%
df_resampled['datetime'] = [i.replace(hour=12) for i in df_resampled['datetime']]

# %%
#df = df_resampled.merge(loc_df, left_on='site', right_on='NAME')[['site', 'datetime', 'head', 'LAYER']]
#df

# %%
#df_lyr1 = df.loc[df['LAYER'] == 1]
#df_lyr2 = df.loc[df['LAYER'] == 2]
#df_lyr3 = df.loc[df['LAYER'] == 3]

# %% [markdown]
# OLPROC reads site sample files (ssf/smp), which is long format data. The following section describes the exportation of the resampled dataset to a site sample file using `pyemu.utils.smp_utils.dataframe_to_smp`

# %%
output_dir = os.path.join('..', '..', 'data', 'olproc_input')

# %% [markdown]
# Perhaps a redundant step, but for brevities sake let's change the clock hour for each `datetime` entry from `00:00:00` to `12:00:00`, to better reflect that data represent daily average stage:

# %%
#for df in [df_lyr1, df_lyr2, df_lyr3]:
#    df['datetime'] = [i.replace(hour=12) for i in df['datetime']]

# %%
#display(df_lyr1)

# %% [markdown]
# Export to smp-file (note that an alternative version below exports headobs per layer):

# %%
pyemu.utils.smp_utils.dataframe_to_smp(
    df_resampled,
    os.path.join(output_dir, 'obs-head-all.ssf'),
    name_col='site',
    datetime_col='datetime',
    value_col='head',
    datetime_format='dd/mm/yyyy',
    value_format='{0:15.6E}',
    max_name_len=12
)

# %% [markdown]
# ---

# %% [markdown]
# ## End of Notebook

# %% [markdown]
# Use `pyemu.utils.smp_utils.dataframe_to_smp` to create a site sample file:

# %%
#pyemu.utils.smp_utils.dataframe_to_smp(
#    df_lyr1[['site', 'datetime', 'head']],
#    os.path.join(output_dir, 'obs-head1.ssf'),
#    name_col='site',
#    datetime_col='datetime',
#    value_col='head',
#    datetime_format='dd/mm/yyyy',
#    value_format='{0:15.6E}',
#    max_name_len=12
#)

# %%
#pyemu.utils.smp_utils.dataframe_to_smp(
#    df_lyr2[['site', 'datetime', 'head']],
#    os.path.join(output_dir, 'obs-head2.ssf'),
#    name_col='site',
#    datetime_col='datetime',
#    value_col='head',
#    datetime_format='dd/mm/yyyy',
#    value_format='{0:15.6E}',
#    max_name_len=12
#)

# %%
#pyemu.utils.smp_utils.dataframe_to_smp(
#    df_lyr3[['site', 'datetime', 'head']],
#    os.path.join(output_dir, 'obs-head3.ssf'),
#    name_col='site',
#    datetime_col='datetime',
#    value_col='head',
#    datetime_format='dd/mm/yyyy',
#    value_format='{0:15.6E}',
#    max_name_len=12
#)

# %% [markdown]
# Done.
