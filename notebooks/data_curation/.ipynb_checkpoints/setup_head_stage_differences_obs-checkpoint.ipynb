# %% [markdown]
# # Data curation of Groundwater head-Stream stage differences
# This notebook describes setting up of groundwater head-stream stage differences for use with OLPROC.
#
# ## Background

# %% [markdown]
# ## Aim and purpose
# Attention: It is a prerequisite that the two notebooks used to curate head and stage data has been run prior to running this notebook.

# %% [markdown]
# Essential imports:

# %%
import os
import numpy as np
import pandas as pd
import pyemu
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})

# %%
ssf_dir = os.path.join('..', '..', 'data', 'olproc_input')
assert(ssf_dir)

# %%
os.listdir(ssf_dir)
# Out:
# ['measured_head.ssf',
#  'measured_stage.ssf',
#  'measured_streamflow.ssf',
#  'readme.md']

# %%
head = pyemu.utils.smp_utils.smp_to_dataframe(os.path.join(ssf_dir, 'measured_head.ssf'), datetime_format=None)
stage = pyemu.utils.smp_utils.smp_to_dataframe(os.path.join(ssf_dir, 'measured_stage.ssf'), datetime_format=None)

# %%
print(head.name.unique())
# Out:
# ['B2-1' 'B2-2' 'B2-3' 'B35' 'B36' 'B37' 'KB1-1' 'KB1-2' 'KB4-3' 'KB4-4'
#  'NI1412-1' 'NI1412-3' 'NI15-O1' 'NI15-O44' 'NI15-O46' 'NI15-O47'
#  'NI15-O48' 'NI1501-3' 'NI1802-1']

# %%
print(stage.name.unique())
# Out:
# ['NI15-O1-STG' 'NI15-O44-STG' 'NI15-O46-STG' 'NI15-O47-STG' 'NI15-O48-STG']

# %% [markdown]
# This can be done programatically. But since it's only five datasets that contain both head and stage measurements, lets do it manually:

# %%
head = head.loc[head['name'].isin(['NI15-O1', 'NI15-O44', 'NI15-O46', 'NI15-O47', 'NI15-O48'])].reset_index(drop=True)

# %% [markdown]
# Let's also append -HEAD just to make it more obvious what's going on:

# %%
head['name'] = head['name'].astype(str) + '-HEAD'

# %%
print(head.name.unique())
# Out:
# ['NI15-O1-HEAD' 'NI15-O44-HEAD' 'NI15-O46-HEAD' 'NI15-O47-HEAD'
#  'NI15-O48-HEAD']

# %%
df = pd.concat([head, stage], ignore_index=True, sort=False)
print(df.name.unique())
display(df)
# Out:
# ['NI15-O1-HEAD' 'NI15-O44-HEAD' 'NI15-O46-HEAD' 'NI15-O47-HEAD'
#  'NI15-O48-HEAD' 'NI15-O1-STG' 'NI15-O44-STG' 'NI15-O46-STG'
#  'NI15-O47-STG' 'NI15-O48-STG']
#                 datetime          name       value
# 0    2016-11-15 12:00:00  NI15-O1-HEAD  136.156667
# 1    2016-11-16 12:00:00  NI15-O1-HEAD  136.150000
# 2    2016-11-17 12:00:00  NI15-O1-HEAD  136.186667
# 3    2016-11-18 12:00:00  NI15-O1-HEAD  136.233333
# 4    2016-11-19 12:00:00  NI15-O1-HEAD  136.308333
# ...                  ...           ...         ...
# 4069 2017-06-17 12:00:00  NI15-O48-STG  133.531667
# 4070 2017-06-18 12:00:00  NI15-O48-STG  133.530000
# 4071 2017-06-19 12:00:00  NI15-O48-STG  133.521667
# 4072 2017-06-20 12:00:00  NI15-O48-STG  133.538333
# 4073 2017-06-21 12:00:00  NI15-O48-STG  133.527500
#
# [4074 rows x 3 columns]

# %% [markdown]
# Pivot dataframe in order to facilitate calculation of head-stage differences:

# %%
dfp = df.pivot(index='datetime', columns='name', values='value')
display(dfp)
# Out:
# name                 NI15-O1-HEAD  NI15-O1-STG  NI15-O44-HEAD  NI15-O44-STG  \
# datetime
# 2015-12-08 12:00:00           NaN          NaN            NaN           NaN
# 2015-12-09 12:00:00           NaN          NaN            NaN           NaN
# 2015-12-10 12:00:00           NaN          NaN     136.305500    136.183333
# 2015-12-11 12:00:00           NaN          NaN     136.298192    136.173333
# 2015-12-12 12:00:00           NaN          NaN     136.306000    136.170000
# ...                           ...          ...            ...           ...
# 2017-06-17 12:00:00    136.061667   136.121667     136.241651    135.988333
# 2017-06-18 12:00:00    136.051667   136.118333     136.229904    135.981667
# 2017-06-19 12:00:00    136.038333   136.108333     136.220741    135.970000
# 2017-06-20 12:00:00    136.061667   136.126667     136.242378    135.990000
# 2017-06-21 12:00:00    136.060000   136.112500     136.214726    135.985000
#
# name                 NI15-O46-HEAD  NI15-O46-STG  NI15-O47-HEAD  NI15-O47-STG  \
# datetime
# 2015-12-08 12:00:00            NaN    134.890000            NaN    134.660000
# 2015-12-09 12:00:00            NaN    134.890000            NaN    134.660000
# 2015-12-10 12:00:00     135.046667    134.891667     134.470000    134.678333
# 2015-12-11 12:00:00     135.030000    134.876667     134.453333    134.676667
# 2015-12-12 12:00:00     135.033333    134.875000     134.453333    134.678333
# ...                            ...           ...            ...           ...
# 2017-06-17 12:00:00     135.130000           NaN            NaN           NaN
# 2017-06-18 12:00:00     135.123333           NaN            NaN           NaN
# 2017-06-19 12:00:00     135.115000           NaN            NaN           NaN
# 2017-06-20 12:00:00     135.140000           NaN            NaN           NaN
# 2017-06-21 12:00:00     135.130000           NaN            NaN           NaN
#
# name                 NI15-O48-HEAD  NI15-O48-STG
# datetime
# 2015-12-08 12:00:00            NaN           NaN
# 2015-12-09 12:00:00            NaN           NaN
# 2015-12-10 12:00:00     133.720000    133.690000
# 2015-12-11 12:00:00     133.723333    133.668333
# 2015-12-12 12:00:00     133.721667    133.673333
# ...                            ...           ...
# 2017-06-17 12:00:00     133.551667    133.531667
# 2017-06-18 12:00:00     133.550000    133.530000
# 2017-06-19 12:00:00     133.543333    133.521667
# 2017-06-20 12:00:00     133.570000    133.538333
# 2017-06-21 12:00:00     133.557500    133.527500
#
# [560 rows x 10 columns]

# %% [markdown]
# Compute stage-head differences:

# %%
sites = ['NI15-O1', 'NI15-O44', 'NI15-O46', 'NI15-O47', 'NI15-O48']
for site in sites:
    dfp[f'{site}-DIFF'] = dfp[f'{site}-HEAD'] - dfp[f'{site}-STG']

# %%
display(dfp)
# Out:
# name                 NI15-O1-HEAD  NI15-O1-STG  NI15-O44-HEAD  NI15-O44-STG  \
# datetime
# 2015-12-08 12:00:00           NaN          NaN            NaN           NaN
# 2015-12-09 12:00:00           NaN          NaN            NaN           NaN
# 2015-12-10 12:00:00           NaN          NaN     136.305500    136.183333
# 2015-12-11 12:00:00           NaN          NaN     136.298192    136.173333
# 2015-12-12 12:00:00           NaN          NaN     136.306000    136.170000
# ...                           ...          ...            ...           ...
# 2017-06-17 12:00:00    136.061667   136.121667     136.241651    135.988333
# 2017-06-18 12:00:00    136.051667   136.118333     136.229904    135.981667
# 2017-06-19 12:00:00    136.038333   136.108333     136.220741    135.970000
# 2017-06-20 12:00:00    136.061667   136.126667     136.242378    135.990000
# 2017-06-21 12:00:00    136.060000   136.112500     136.214726    135.985000
#
# name                 NI15-O46-HEAD  NI15-O46-STG  NI15-O47-HEAD  NI15-O47-STG  \
# datetime
# 2015-12-08 12:00:00            NaN    134.890000            NaN    134.660000
# 2015-12-09 12:00:00            NaN    134.890000            NaN    134.660000
# 2015-12-10 12:00:00     135.046667    134.891667     134.470000    134.678333
# 2015-12-11 12:00:00     135.030000    134.876667     134.453333    134.676667
# 2015-12-12 12:00:00     135.033333    134.875000     134.453333    134.678333
# ...                            ...           ...            ...           ...
# 2017-06-17 12:00:00     135.130000           NaN            NaN           NaN
# 2017-06-18 12:00:00     135.123333           NaN            NaN           NaN
# 2017-06-19 12:00:00     135.115000           NaN            NaN           NaN
# 2017-06-20 12:00:00     135.140000           NaN            NaN           NaN
# 2017-06-21 12:00:00     135.130000           NaN            NaN           NaN
#
# name                 NI15-O48-HEAD  NI15-O48-STG  NI15-O1-DIFF  NI15-O44-DIFF  \
# datetime
# 2015-12-08 12:00:00            NaN           NaN           NaN            NaN
# 2015-12-09 12:00:00            NaN           NaN           NaN            NaN
# 2015-12-10 12:00:00     133.720000    133.690000           NaN       0.122167
# 2015-12-11 12:00:00     133.723333    133.668333           NaN       0.124859
# 2015-12-12 12:00:00     133.721667    133.673333           NaN       0.136000
# ...                            ...           ...           ...            ...
# 2017-06-17 12:00:00     133.551667    133.531667     -0.060000       0.253318
# 2017-06-18 12:00:00     133.550000    133.530000     -0.066666       0.248237
# 2017-06-19 12:00:00     133.543333    133.521667     -0.070000       0.250741
# 2017-06-20 12:00:00     133.570000    133.538333     -0.065000       0.252378
# 2017-06-21 12:00:00     133.557500    133.527500     -0.052500       0.229726
#
# name                 NI15-O46-DIFF  NI15-O47-DIFF  NI15-O48-DIFF
# datetime
# 2015-12-08 12:00:00            NaN            NaN            NaN
# 2015-12-09 12:00:00            NaN            NaN            NaN
# 2015-12-10 12:00:00       0.155000      -0.208333       0.030000
# 2015-12-11 12:00:00       0.153333      -0.223334       0.055000
# 2015-12-12 12:00:00       0.158333      -0.225000       0.048334
# ...                            ...            ...            ...
# 2017-06-17 12:00:00            NaN            NaN       0.020000
# 2017-06-18 12:00:00            NaN            NaN       0.020000
# 2017-06-19 12:00:00            NaN            NaN       0.021666
# 2017-06-20 12:00:00            NaN            NaN       0.031667
# 2017-06-21 12:00:00            NaN            NaN       0.030000
#
# [560 rows x 15 columns]

# %%
fig, axs = plt.subplots(len(sites), sharex=True, figsize=(12,8))

for (index, site) in enumerate(sites):
    temp_df = dfp[[f'{site}-HEAD', f'{site}-STG', f'{site}-DIFF']]
    ax2 = axs[index].twinx()
    ax2.plot(temp_df.index, temp_df[f'{site}-DIFF'], color='black', label='Difference')
    axs[index].plot(temp_df.index, temp_df[f'{site}-HEAD'], color='blue', label='Head')
    axs[index].plot(temp_df.index, temp_df[f'{site}-STG'], color='red', label='Stage')
    axs[index].legend()
    axs[index].title.set_text(site)

plt.legend()
plt.tight_layout()

# %% [markdown]
# Filter out relevant columns and return datetime index as a separate column:

# %%
dfp = dfp[['NI15-O1-DIFF', 'NI15-O44-DIFF', 'NI15-O46-DIFF', 'NI15-O47-DIFF', 'NI15-O48-DIFF']]
dfp['datetime'] = dfp.index
display(dfp)
# Out:
# name                 NI15-O1-DIFF  NI15-O44-DIFF  NI15-O46-DIFF  \
# datetime
# 2015-12-08 12:00:00           NaN            NaN            NaN
# 2015-12-09 12:00:00           NaN            NaN            NaN
# 2015-12-10 12:00:00           NaN       0.122167       0.155000
# 2015-12-11 12:00:00           NaN       0.124859       0.153333
# 2015-12-12 12:00:00           NaN       0.136000       0.158333
# ...                           ...            ...            ...
# 2017-06-17 12:00:00     -0.060000       0.253318            NaN
# 2017-06-18 12:00:00     -0.066666       0.248237            NaN
# 2017-06-19 12:00:00     -0.070000       0.250741            NaN
# 2017-06-20 12:00:00     -0.065000       0.252378            NaN
# 2017-06-21 12:00:00     -0.052500       0.229726            NaN
#
# name                 NI15-O47-DIFF  NI15-O48-DIFF            datetime
# datetime
# 2015-12-08 12:00:00            NaN            NaN 2015-12-08 12:00:00
# 2015-12-09 12:00:00            NaN            NaN 2015-12-09 12:00:00
# 2015-12-10 12:00:00      -0.208333       0.030000 2015-12-10 12:00:00
# 2015-12-11 12:00:00      -0.223334       0.055000 2015-12-11 12:00:00
# 2015-12-12 12:00:00      -0.225000       0.048334 2015-12-12 12:00:00
# ...                            ...            ...                 ...
# 2017-06-17 12:00:00            NaN       0.020000 2017-06-17 12:00:00
# 2017-06-18 12:00:00            NaN       0.020000 2017-06-18 12:00:00
# 2017-06-19 12:00:00            NaN       0.021666 2017-06-19 12:00:00
# 2017-06-20 12:00:00            NaN       0.031667 2017-06-20 12:00:00
# 2017-06-21 12:00:00            NaN       0.030000 2017-06-21 12:00:00
#
# [560 rows x 6 columns]

# %% [markdown]
# Convert from wide to long-form format:

# %%
dfl = pd.melt(dfp, id_vars='datetime', value_vars=['NI15-O1-DIFF', 'NI15-O44-DIFF', 'NI15-O46-DIFF', 'NI15-O47-DIFF', 'NI15-O48-DIFF'])
display(dfl)
# Out:
#                 datetime           name     value
# 0    2015-12-08 12:00:00   NI15-O1-DIFF       NaN
# 1    2015-12-09 12:00:00   NI15-O1-DIFF       NaN
# 2    2015-12-10 12:00:00   NI15-O1-DIFF       NaN
# 3    2015-12-11 12:00:00   NI15-O1-DIFF       NaN
# 4    2015-12-12 12:00:00   NI15-O1-DIFF       NaN
# ...                  ...            ...       ...
# 2795 2017-06-17 12:00:00  NI15-O48-DIFF  0.020000
# 2796 2017-06-18 12:00:00  NI15-O48-DIFF  0.020000
# 2797 2017-06-19 12:00:00  NI15-O48-DIFF  0.021666
# 2798 2017-06-20 12:00:00  NI15-O48-DIFF  0.031667
# 2799 2017-06-21 12:00:00  NI15-O48-DIFF  0.030000
#
# [2800 rows x 3 columns]

# %% [markdown]
# Drop NaN rows and print length of new dataframe:

# %%
dfl = dfl.dropna(how='any').reset_index(drop=True)
print(len(dfl))
# Out:
# 1838

# %% [markdown]
# ## Visualize results
# For good measure let's visualize the curated dataset that will be used as input for OLPROC:

# %%
plt.figure(figsize=(12, 6))
for site in dfl['name'].unique():
    x = dfl.loc[dfl['name'] == site]['datetime']
    y = dfl.loc[dfl['name'] == site]['value']
    plt.plot(x, y, label=site)
plt.legend()
plt.title('Head-Stage difference (meters).', fontsize=14)
plt.tight_layout()

# %% [markdown]
# ## Prepare datasets for OLPROC

# %% [markdown]
# OLPROC reads site sample files (ssf/smp), which is long format data. The following section describes the exportation of the resampled dataset to a site sample file using `pyemu.utils.smp_utils.dataframe_to_smp`

# %% [markdown]
# Use `pyemu.utils.smp_utils.dataframe_to_smp` to create a site sample file:

# %%
pyemu.utils.smp_utils.dataframe_to_smp(
    dfl,
    os.path.join(ssf_dir, 'head_stage_difference.ssf'),
    name_col='name',
    datetime_col='datetime',
    value_col='value',
    datetime_format='dd/mm/yyyy',
    value_format='{0:15.6E}',
    max_name_len=12
)

# %% [markdown]
# Done.
