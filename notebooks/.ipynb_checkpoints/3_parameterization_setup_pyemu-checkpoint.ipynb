# %% [markdown]
# ### TODO
#
# - Parameterize EVT (must first instantiate EVT pckg)
# - Parameterize Reach 1 inflow
# - Parameterize Lumprem models
# - Covariance matrices

# %%
import os
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import flopy
from flopy.utils.gridintersect import GridIntersect
import pyemu

from shapely.geometry import Polygon, Point
import shapefile
from shapely.prepared import prep

import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
plt.rcParams['font.size']=12

# %%
bins_pth = os.path.join('..', 'bins', 'win') if 'nt' in os.name else os.path.join('..', 'bins', 'linux') # Binaries
shapefile_pth = os.path.join('..', 'data', 'raw_data', 'shapefiles')
observations_pth = os.path.join('..', 'data', 'observations') # Measured data (field obs)

# %%
org_model_ws = os.path.join('..', 'temp_flopy_lumprem')
os.listdir(org_model_ws)
# Out:
# ['ghbpp.dat',
#  'ghbpp.tpl',
#  'ghb_new.ts',
#  'hagfors_1.cbb',
#  'hagfors_1.disv',
#  'hagfors_1.disv.grb',
#  'hagfors_1.ghb',
#  'hagfors_1.hds',
#  'hagfors_1.ic',
#  'hagfors_1.ims',
#  'hagfors_1.lst',
#  'hagfors_1.nam',
#  'hagfors_1.npf',
#  'hagfors_1.obs',
#  'hagfors_1.oc',
#  'hagfors_1.rch',
#  'hagfors_1.sfr',
#  'hagfors_1.sfr.bud',
#  'hagfors_1.sfr.obs',
#  'hagfors_1.sto',
#  'hagfors_1.tdis',
#  'head.obs.csv',
#  'lr_blueviolet.tpl',
#  'lr_limegreen.tpl',
#  'lr_lu1.tpl',
#  'lr_magenta.tpl',
#  'lr_orange.tpl',
#  'lr_red.tpl',
#  'lr_royalblue.tpl',
#  'lr_yellow.tpl',
#  'mfsim.lst',
#  'mfsim.nam',
#  'rch_new.ts',
#  'sfr_gage.obs.csv',
#  'sfr_pred_leak.obs.csv',
#  'sfr_pred_outfr1.obs.csv',
#  'sfr_segfile.dat',
#  'sfr_stage.obs.csv']

# %%
tmp_model_ws = os.path.join('..', 'temp_pst_from')
if os.path.exists(tmp_model_ws):
    shutil.rmtree(tmp_model_ws)
shutil.copytree(org_model_ws,tmp_model_ws)
os.listdir(tmp_model_ws)
# Out:
# ['ghbpp.dat',
#  'ghbpp.tpl',
#  'ghb_new.ts',
#  'hagfors_1.cbb',
#  'hagfors_1.disv',
#  'hagfors_1.disv.grb',
#  'hagfors_1.ghb',
#  'hagfors_1.hds',
#  'hagfors_1.ic',
#  'hagfors_1.ims',
#  'hagfors_1.lst',
#  'hagfors_1.nam',
#  'hagfors_1.npf',
#  'hagfors_1.obs',
#  'hagfors_1.oc',
#  'hagfors_1.rch',
#  'hagfors_1.sfr',
#  'hagfors_1.sfr.bud',
#  'hagfors_1.sfr.obs',
#  'hagfors_1.sto',
#  'hagfors_1.tdis',
#  'head.obs.csv',
#  'lr_blueviolet.tpl',
#  'lr_limegreen.tpl',
#  'lr_lu1.tpl',
#  'lr_magenta.tpl',
#  'lr_orange.tpl',
#  'lr_red.tpl',
#  'lr_royalblue.tpl',
#  'lr_yellow.tpl',
#  'mfsim.lst',
#  'mfsim.nam',
#  'rch_new.ts',
#  'sfr_gage.obs.csv',
#  'sfr_pred_leak.obs.csv',
#  'sfr_pred_outfr1.obs.csv',
#  'sfr_segfile.dat',
#  'sfr_stage.obs.csv']

# %%
ml_name = 'hagfors_1'

# %%
template_ws = os.path.join('..', f'{ml_name}_template')

pf = pyemu.utils.PstFrom(
    original_d=tmp_model_ws,
    new_d=template_ws,
    remove_existing=True,
    longnames=True,
    spatial_reference=None,
    zero_based=False,
    tpl_subfolder='tpl',
    start_datetime='1-1-2016'
)
# Out:
# 2021-12-20 22:04:49.621112 starting: opening PstFrom.log for logging
# 2021-12-20 22:04:49.621112 starting PstFrom process
# 2021-12-20 22:04:49.622110 starting: setting up dirs
# 2021-12-20 22:04:49.622110 starting: removing existing new_d '..\hagfors_1_template'
# 2021-12-20 22:04:49.665995 finished: removing existing new_d '..\hagfors_1_template' took: 0:00:00.043885
# 2021-12-20 22:04:49.665995 starting: copying original_d '..\temp_pst_from' to new_d '..\hagfors_1_template'
# 2021-12-20 22:04:49.758745 finished: copying original_d '..\temp_pst_from' to new_d '..\hagfors_1_template' took: 0:00:00.092750
# 2021-12-20 22:04:49.760740 finished: setting up dirs took: 0:00:00.138630

# %%
sim = flopy.mf6.MFSimulation.load(ml_name, 'mf6', os.path.join(bins_pth, 'mf6'), template_ws)
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package disv...
# WARNING: Unable to resolve dimension of ('gwf6', 'disv', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
#     loading package rch...
#     loading package ic...
#     loading package npf...
#     loading package oc...
#     loading package sto...
#     loading package sfr...
#     loading package obs...
#     loading package ghb...
#   loading ims package hagfors_1...

# %% [markdown]
# ## 1. Add parameters

# %% [markdown]
# Set all data external so that PEST can adjust parameter values during history matching:

# %%
sim.set_all_data_external(True)

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing ims package hagfors_1...
#   writing model hagfors_1...
#     writing model name file...
#     writing package disv...
#     writing package rch_ts...
#     writing package rch...
#     writing package ic...
#     writing package npf...
#     writing package oc...
#     writing package sto...
#     writing package sfr_obs...
#     writing package sfr...
#     writing package gwf_obs...
#     writing package ghb_ts...
#     writing package ghb...

# %%
gwf = sim.get_model(ml_name)

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(1, 1, 1, aspect='equal')
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates
ax.set_title('Model grid', fontsize=18)

mapview = flopy.plot.PlotMapView(gwf, layer=0)
linecollection = mapview.plot_grid(lw=0.25)

plt.show()

# %% [markdown]
# ### 1.1 Generate pilot points for kh, kv, sy and ss

# %% [markdown]
# Import (head, stage & flow) measurement locations, so that we can see how the pilot points will be located in relation to them:

# %%
sfr_obs = pd.read_excel(os.path.join(observations_pth, 'obs_flow_and_stage.xlsx')) # contains both stage & flow
head_obs = pd.read_excel(os.path.join(observations_pth, 'obs_head_per_layer.xlsx'))#.drop_duplicates(subset=['POINT_X', 'POINT_Y'])
head_obs['TYPE'] = 'HEAD'

# %%
measurement_points = pd.concat([head_obs, sfr_obs])
measurement_points['NAME'] = measurement_points['NAME'].str.lower()
measurement_points.head()
# Out:
#     NAME        POINT_X       POINT_Y  LAYER  TYPE
# 0   b9-2  426918.374000  6.654803e+06    1.0  HEAD
# 1  b10-2  427074.709423  6.654805e+06    1.0  HEAD
# 2  b12-1  427448.188505  6.655156e+06    1.0  HEAD
# 3  b16-1  427409.547301  6.655023e+06    1.0  HEAD
# 4   b2-1  427384.172044  6.655037e+06    1.0  HEAD

# %%
hds_meas = pyemu.utils.smp_to_dataframe(os.path.join('..', 'data', 'olproc_input', 'obs-head-all.ssf'))
stg_meas = pyemu.utils.smp_to_dataframe(os.path.join('..', 'data', 'olproc_input', 'obs-stage1.ssf'))
inf_meas = pyemu.utils.smp_to_dataframe(os.path.join('..', 'data', 'olproc_input', 'obs-gage1.ssf'))

# %%
for df in [hds_meas, stg_meas, inf_meas]:
    df['name'] = df['name'].str.lower()

# %%
measurement_points = measurement_points.loc[measurement_points['NAME'].isin(pd.concat([hds_meas, stg_meas, inf_meas]).name.unique())]

# %% [markdown]
# #### Generate pilot points using shapely

# %%
ml_boundary = shapefile.Reader(os.path.join(shapefile_pth, 'model_boundary.shp')) # Model boundary shapefile
mlb_shape = np.array(np.rint(ml_boundary.shapeRecords()[0].shape.points)) # Model boundary array

# %% [markdown]
# Instantiate a shapely polygon of the model boundary:

# %%
mlb_shapely = Polygon(mlb_shape)

# %% [markdown]
# Create prepared polygon of the model boundary:

# %%
mlb_shapely_prep = prep(mlb_shapely)

# %% [markdown]
# Construct a rectangular mesh of points:

# %%
xmin, xmax, ymin, ymax = 426900, 427700, 6654650, 6655350 # These are the same coordinates used to construct the base-grid
resolution = 28 # Equal space (in meters) between pilot points
basepoints = []
for lat in np.arange(xmin, xmax, resolution):
    for lon in np.arange(ymin, ymax, resolution):
        basepoints.append(Point((round(lat,4), round(lon,4))))

# %% [markdown]
# Use the shapely `contains` (point-in-polygon method) to select points inside the model boundary (increase the number of pps once workflow is confirmed working):

# %%
basepip = [] # Basepoints in polygon
for point in basepoints:
    if mlb_shapely_prep.contains(point):
        basepip.append(point)
print(f'Number of points per layer: {len(basepip)}') # We need to extend it into three dimensions
# Out:
# Number of points per layer: 308

# %%
fig = plt.figure(figsize=(8, 8), dpi=100)
ax = fig.add_subplot(1, 1, 1, aspect='equal')
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates
ax.set_title('Coarse pilot point locations', fontsize=18)

mapview = flopy.plot.PlotMapView(gwf, layer=0)
linecollection = mapview.plot_grid(lw=0.25)

x = np.array([i.coords[0] for i in basepip])[:,0]
y = np.array([i.coords[0] for i in basepip])[:,1]
plt.scatter(x, y, s=5, c='black', alpha=0.5, label='PILOT POINT')

for category in measurement_points['TYPE'].unique():
    x = measurement_points.loc[measurement_points['TYPE'] == category]['POINT_X']
    y = measurement_points.loc[measurement_points['TYPE'] == category]['POINT_Y']
    ax.scatter(x, y, s=20, alpha=0.6, label=category)
    
plt.legend()
plt.show()

# %% [markdown]
# These points now need to be assigned a z-value, since we are going to use 3D-pilot points. To do this, we will need to intersect the model grid and retrieve the z-values of each layer, so that a copy of these pps can be positioned in each of the three layers:

# %%
ix = GridIntersect(gwf.modelgrid)
# Out:
# c:\users\nat12nho\appdata\local\programs\python\python38\lib\site-packages\flopy\utils\gridintersect.py:317: ShapelyDeprecationWarning: Setting custom attributes on geometry objects is deprecated, and will raise an AttributeError in Shapely 2.0
#   p.name = icell

# %%
pp_intersect = {
    'cellids': [],
    'vertices': [],
    'ixshapes': [],
}
for point in basepip:
    pp_intersect['cellids'].append(ix.intersect(point).cellids[0])
    pp_intersect['vertices'].append(ix.intersect(point).vertices[0])
    pp_intersect['ixshapes'].append(ix.intersect(point).ixshapes[0])

# %%
pp_intersect = pd.DataFrame(pp_intersect)
display(pp_intersect)
# Out:
#      cellids                  vertices                ixshapes
# 0        262  ((426900.0, 6654790.0),)  POINT (426900 6654790)
# 1        184  ((426900.0, 6654818.0),)  POINT (426900 6654818)
# 2        114  ((426900.0, 6654846.0),)  POINT (426900 6654846)
# 3         49  ((426900.0, 6654874.0),)  POINT (426900 6654874)
# 4          0  ((426900.0, 6654902.0),)  POINT (426900 6654902)
# ..       ...                       ...                     ...
# 303     2067  ((427572.0, 6655182.0),)  POINT (427572 6655182)
# 304     2731  ((427600.0, 6655098.0),)  POINT (427600 6655098)
# 305     2578  ((427600.0, 6655126.0),)  POINT (427600 6655126)
# 306     2386  ((427600.0, 6655154.0),)  POINT (427600 6655154)
# 307     2735  ((427628.0, 6655126.0),)  POINT (427628 6655126)
#
# [308 rows x 3 columns]

# %%
def get_grid_elevation(elevation_array, index_array):
    '''
    returns list of elevations
    '''
    
    elevations = list(elevation_array)
    indices = list(index_array)
    
    return [elevation_array[i] for i in index_array]

# %%
pp_intersect['top'] = get_grid_elevation(elevation_array = gwf.modelgrid.top, index_array=pp_intersect['cellids'])
pp_intersect['botm_1'] = get_grid_elevation(gwf.modelgrid.botm[0], pp_intersect['cellids'])
pp_intersect['botm_2'] = get_grid_elevation(gwf.modelgrid.botm[1], pp_intersect['cellids'])
pp_intersect['botm_3'] = get_grid_elevation(gwf.modelgrid.botm[2], pp_intersect['cellids'])

# %% [markdown]
# Create pps in-between the layer boundaries (i.e. vertically centered in the cells):

# %%
pp_intersect['pps_l1'] = (pp_intersect['top'] + pp_intersect['botm_1']) / 2
pp_intersect['pps_l2'] = (pp_intersect['botm_1'] + pp_intersect['botm_2']) / 2
pp_intersect['pps_l3'] = (pp_intersect['botm_2'] + pp_intersect['botm_3']) / 2
display(pp_intersect)
# Out:
#      cellids                  vertices                ixshapes         top  \
# 0        262  ((426900.0, 6654790.0),)  POINT (426900 6654790)  135.564896
# 1        184  ((426900.0, 6654818.0),)  POINT (426900 6654818)  135.877808
# 2        114  ((426900.0, 6654846.0),)  POINT (426900 6654846)  136.619507
# 3         49  ((426900.0, 6654874.0),)  POINT (426900 6654874)  137.646805
# 4          0  ((426900.0, 6654902.0),)  POINT (426900 6654902)  136.599197
# ..       ...                       ...                     ...         ...
# 303     2067  ((427572.0, 6655182.0),)  POINT (427572 6655182)  155.270905
# 304     2731  ((427600.0, 6655098.0),)  POINT (427600 6655098)  147.556305
# 305     2578  ((427600.0, 6655126.0),)  POINT (427600 6655126)  143.514603
# 306     2386  ((427600.0, 6655154.0),)  POINT (427600 6655154)  151.082794
# 307     2735  ((427628.0, 6655126.0),)  POINT (427628 6655126)  143.696503
#
#          botm_1      botm_2      botm_3      pps_l1      pps_l2      pps_l3
# 0    123.399101  118.538399  116.154800  129.481998  120.968750  117.346600
# 1    123.678596  118.809502  116.403099  129.778202  121.244049  117.606300
# 2    124.892403  120.271103  118.062202  130.755955  122.581753  119.166653
# 3    125.777702  121.388603  119.260498  131.712254  123.583153  120.324551
# 4    126.678703  122.498398  120.362503  131.638950  124.588551  121.430450
# ..          ...         ...         ...         ...         ...         ...
# 303  140.833298  138.167892  136.250198  148.052101  139.500595  137.209045
# 304  139.560394  136.775803  135.341797  143.558350  138.168098  136.058800
# 305  139.526199  137.070404  135.688507  141.520401  138.298302  136.379456
# 306  140.218399  137.978104  136.304199  145.650597  139.098251  137.141151
# 307  139.584106  137.293198  135.698898  141.640305  138.438652  136.496048
#
# [308 rows x 10 columns]

# %%
pp_intersect['x'] = np.array([i.coords[0] for i in basepip])[:,0]
pp_intersect['y'] = np.array([i.coords[0] for i in basepip])[:,1]
pp_intersect = pp_intersect[['x', 'y', 'pps_l1', 'pps_l2', 'pps_l3']]

# %% [markdown]
# Convert the dataframe into a 3d pilot point file format:

# %%
pp_coarse3d = pd.melt(pp_intersect, id_vars=['x', 'y'], value_vars=['pps_l1', 'pps_l2', 'pps_l3'])

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random

fig = pyplot.figure(figsize=(6,6))
ax = Axes3D(fig)
ax.set_box_aspect([2,2,1])

x, y = pp_coarse3d.x.values, pp_coarse3d.y.values

ax.scatter(x, y, pp_coarse3d.value.values)
plt.title('pps in 3d-space')
pyplot.show()

# %%
pp_coarse3d['name'] = [f'ppc{i:04d}' for i in pp_coarse3d.index.values] # ppc = pilot point coarse.

# %%
pp_coarse3d[['zone','val']] = 1, 1 #redundant?
pp_coarse3d['z'] = pp_coarse3d['value']

# %%
pp_coarse3d['layer'] = [int(i[-1]) for i in pp_coarse3d['variable']]

# %%
pp_coarse3d = pp_coarse3d[['name', 'x', 'y', 'z', 'zone', 'val', 'layer']]

# %%
display(pp_coarse3d)
# Out:
#         name         x          y           z  zone  val  layer
# 0    ppc0000  426900.0  6654790.0  129.481998     1    1      1
# 1    ppc0001  426900.0  6654818.0  129.778202     1    1      1
# 2    ppc0002  426900.0  6654846.0  130.755955     1    1      1
# 3    ppc0003  426900.0  6654874.0  131.712254     1    1      1
# 4    ppc0004  426900.0  6654902.0  131.638950     1    1      1
# ..       ...       ...        ...         ...   ...  ...    ...
# 919  ppc0919  427572.0  6655182.0  137.209045     1    1      3
# 920  ppc0920  427600.0  6655098.0  136.058800     1    1      3
# 921  ppc0921  427600.0  6655126.0  136.379456     1    1      3
# 922  ppc0922  427600.0  6655154.0  137.141151     1    1      3
# 923  ppc0923  427628.0  6655126.0  136.496048     1    1      3
#
# [924 rows x 7 columns]

# %% [markdown]
# Covariance matrix:

# %%
from lumpyrem import run
#MKPPSTAT
# mkppstat requires no headers in ppoint file ...sigh...
pp_coarse3d.to_csv(os.path.join(template_ws, 'mkppoints3d_coarse.dat'),
                       header=None, index=False, sep='\t')

# %%
# Input for MKPPSTAT
# A (a)-factor of 1.5 is often reasonable. from tutorial 
npoints_h, npoints_v = 10, 10 # np-horizontal, np-vertical
a_h, a_v = 1.2, 1.2 # a-horizontal, a-vertical
# run MKPPSTAT
run.run_process(
    'mkppstat3d',
    path=template_ws,
    commands=['mkppoints3d_coarse.dat', npoints_h, a_h, npoints_v, a_v, 'ppstat3d_coarse.dat']
)
# Out:
#
#  Program MKPPSTAT3D writes a pilot points statistical specification file
#    based on a 3D pilot points file using local pilot point density to set
#    local variogram range.
#
#  Enter name of 3D pilot points file:   - data for 924 pilot points read from pilot points file
#     mkppoints3d_coarse.dat
#
#  Enter no. of pilot points to compute local ave. hor. pp. sepn.:  Enter factor of ave. hor. sepn. for local variogram hor. "a" value:
#  Enter no. of pilot points to compute local ave. vert. pp. sepn.:  Enter factor of ave. vert. sepn. for local variogram vert. "a" value:
#  Enter name for 3D pilot point statistical spec. file:  - file ppstat3d_coarse.dat written ok

# %%
# run PPCOV3D_SVA - pilot point covariance 3d - spatially varying anisotropy
run.run_process(
    'ppcov3d_sva',
    path=template_ws,
    commands=['ppstat3d_coarse.dat', 'y', 1, 'x',  'cov3d_coarse.mat', '']
)
# Out:
#
#  Program PPCOV3D_SVA creates a covariance matrix file for 3D pilot point
#    parameters where geostatistical properties are pilot-point-specific.
#
#  Enter name of 3D pilot points statistical specs file:  Skip a line at the top of this file?  [y/n]:   - data for 924 pilot points read from file ppstat3d_coarse.dat
#
#  Is overall variogram spherical, exponential or Gaussian? [s/x/g]:  Is overall variogram spherical, exponential or Gaussian? [s/x/g]:
#  Enter name for output matrix file:  Enter pilot point prefix for parameter names (<Enter> if none):
#  Filling covariance matrix....
#  Using SVD to assure positive definiteness of matrix....
#  - file cov3d_coarse.mat written ok.

# %%
covmat_coarse = pyemu.Cov.from_ascii(os.path.join(template_ws, "cov3d_coarse.mat"))

# This covaraince matrix can now be used as the base for all pilot point parameters. 
# Note that in this case the variance is 1, so it is easy to scale to a parameters prior varaince
# Depending on how you setup the scrpt, variance can be assigned at various stages (i.e. when running PPCOV_SVA, or by manipulating the matrix later)
# Note that parameter names (headers and row names) come from the parameter name sin the ppoint file. These can have a prefix added by PPCOV_SVA, or changed in the dataframe. The latter is more versatile.
covmat_coarse.to_dataframe().head()
# Out:
#           ppc0000   ppc0001   ppc0002   ppc0003   ppc0004   ppc0005   ppc0006  \
# ppc0000  1.000000  0.352656  0.123847  0.043416  0.022600  0.263169  0.352766
# ppc0001  0.352656  1.000000  0.350582  0.122852  0.043593  0.097319  0.228839
# ppc0002  0.123847  0.350582  1.000000  0.350556  0.124193  0.036953  0.096408
# ppc0003  0.043416  0.122852  0.350556  1.000000  0.352853  0.013507  0.036389
# ppc0004  0.022600  0.043593  0.124193  0.352853  1.000000  0.008023  0.013448
#
#           ppc0007   ppc0008   ppc0009  ...       ppc0914       ppc0915  \
# ppc0000  0.228766  0.096756  0.036538  ...  3.060688e-11  1.698240e-12
# ppc0001  0.352584  0.227938  0.095834  ...  3.558494e-12  2.495942e-12
# ppc0002  0.228771  0.352818  0.228071  ...  4.869266e-12  3.551156e-12
# ppc0003  0.096580  0.227266  0.352740  ...  6.405313e-12  4.865048e-12
# ppc0004  0.036925  0.096916  0.229185  ...  8.848158e-11  6.385362e-12
#
#               ppc0916       ppc0917       ppc0918       ppc0919       ppc0920  \
# ppc0000  1.117774e-12  7.106052e-13  4.406712e-13  3.985827e-12  6.156540e-12
# ppc0001  1.700035e-12  1.117000e-12  7.148883e-13  4.429976e-13  6.527077e-13
# ppc0002  2.507372e-12  1.705955e-12  1.126155e-12  7.190089e-13  9.480546e-13
# ppc0003  3.565501e-12  2.514043e-12  1.715395e-12  1.129670e-12  1.328068e-12
# ppc0004  4.861940e-12  3.557839e-12  2.515818e-12  2.164774e-11  2.242836e-11
#
#               ppc0921       ppc0922       ppc0923
# ppc0000  2.755716e-13  2.701818e-12  1.802917e-12
# ppc0001  4.271474e-13  2.815216e-13  1.677463e-13
# ppc0002  6.445458e-13  4.355954e-13  2.476545e-13
# ppc0003  9.399477e-13  6.533070e-13  3.553180e-13
# ppc0004  1.312243e-12  1.254190e-11  6.982719e-12
#
# [5 rows x 924 columns]

# %%
pf.add_parameters(
    filenames=f'{ml_name}.npf_k_layer1.txt',
    par_type='pilotpoints',
    par_name_base="hk_layer_1",
    pargp="hk_layer_1",
    #zone_array=ib,
    upper_bound=864.0,
    lower_bound=0.864,
    ult_ubound=1200.0,
    ult_lbound=0.00001,
    transform='log',
    #geostruct=covmat_coarse, AttributeError: 'Cov' object has no attribute 'sill'
    pp_space=pp_coarse3d.loc[pp_coarse3d['layer'] == 1]
)
# Out:
# 2021-12-20 22:05:21.249745 starting: adding pilotpoints type multiplier style parameters for file(s) ['hagfors_1.npf_k_layer1.txt']
# 2021-12-20 22:05:21.249745 starting: loading array ..\hagfors_1_template\hagfors_1.npf_k_layer1.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-f54e09da845e> in <module>
# ----> 1 pf.add_parameters(
#       2     filenames=f'{ml_name}.npf_k_layer1.txt',
#       3     par_type='pilotpoints',
#       4     par_name_base="hk_layer_1",
#       5     pargp="hk_layer_1",
#
# c:\users\nat12nho\appdata\local\programs\python\python38\lib\site-packages\pyemu\utils\pst_from.py in add_parameters(self, filenames, par_type, zone_array, dist_type, sigma_range, upper_bound, lower_bound, transform, par_name_base, index_cols, use_cols, pargp, pp_space, use_pp_zones, num_eig_kl, spatial_reference, geostruct, datetime, mfile_fmt, mfile_skip, ult_ubound, ult_lbound, rebuild_pst, alt_inst_str, comment_char, par_style)
#    1777             skip_dict,
#    1778             headerlines,  # needed for direct pars (need to be in tpl)
# -> 1779         ) = self._par_prep(
#    1780             filenames,
#    1781             idx_cols,
#
# c:\users\nat12nho\appdata\local\programs\python\python38\lib\site-packages\pyemu\utils\pst_from.py in _par_prep(self, filenames, index_cols, use_cols, fmts, seps, skip_rows, c_char)
#     887                     )
#     888                 # read array type input file
# --> 889                 arr = np.loadtxt(dest_filepath, delimiter=sep, ndmin=2)
#     890                 self.logger.log("loading array {0}".format(dest_filepath))
#     891                 self.logger.statement(
#
# c:\users\nat12nho\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1157         # converting the data
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#    1161                 X = np.array(x, dtype)
#
# c:\users\nat12nho\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#    1081             if len(vals) != N:
#    1082                 line_num = i + skiprows + 1
# -> 1083                 raise ValueError("Wrong number of columns at line %d"
#    1084                                  % line_num)
#    1085
#
# ValueError: Wrong number of columns at line 155

# %% [markdown]
# ### General Head Boundaries (GHB)

# %%
ghbpp = pd.read_csv(os.path.join(tmp_model_ws, 'ghbpp.dat'), sep='\t')
ghbpp.head()

# %%
ghbpp['zone'] = 1

# %%
ghbpp = ghbpp[['ppid', 'x', 'y', 'zone', 'cond', 'bnames']]

# %%
ghbpp.rename(columns={'cond': 'parval1'}, inplace=True)

# %%
ghbppred = ghbpp.loc[ghbpp['bnames'] == 'red'][['ppid', 'x', 'y', 'zone', 'parval1']]

# %%
ghbppred

# %%
pf.add_parameters(
    filenames=f'{ml_name}.ghb_stress_period_data_1.txt', 
    par_name_base='ghbr_rhk',
    pargp='ghb_hk',
    index_cols=[0,1], 
    use_cols=[3],
    upper_bound=10.,
    lower_bound=0.1,
    ult_ubound=100.,
    ult_lbound=0.01,
    par_type='pilotpoints',
    pp_space=ghbppred
)

# %% [markdown]
# ### Stream Flow Routing (SFR)

# %%
# add grid-scale parameters for SFR reach conductance.  
# Use layer, row, col and reach number in the 
# parameter names
pf.add_parameters(
    filenames=f'{ml_name}.sfr_packagedata.txt', 
    par_name_base='sfr_rhk',
    pargp='sfr_rhk',
    index_cols=[0,1,2], 
    use_cols=[9],
    upper_bound=10.,
    lower_bound=0.1,
    ult_ubound=100.,
    ult_lbound=0.01,
    par_type='grid'
)

# %%
pp_coarse3d.loc[pp_coarse3d['layer'] == 1]

# %% [markdown]
# ## 2. Add observations
#
# ### 2.1 Heads
#
# #### Computed head
#
# - Is there a point of having "hds_usecol:" in the obsnme and obgnme or can this be removed safely?

# %%
df = pd.read_csv(os.path.join(template_ws, 'head.obs.csv'),index_col=0)
df.head()
# Out:
#                   B9-2       B10-2       B12-1       B16-1        B2-1  \
# time
# 0.000000    136.357417  136.171989  141.672073  138.887187  138.683830
# 30.416667   136.380164  136.192273  141.687803  138.895642  138.693801
# 60.833333   136.257096  136.093482  141.612178  138.862508  138.654511
# 91.250000   136.195614  136.040609  141.565019  138.839727  138.627792
# 121.666667  136.417963  136.219815  141.702506  138.900679  138.699918
#
#                  B22-1         B27         B29       KB1-1       KB4-3  ...  \
# time                                                                    ...
# 0.000000    141.594246  141.849394  138.901786  137.643041  135.914168  ...
# 30.416667   141.609088  141.865356  138.913362  137.646867  135.922649  ...
# 60.833333   141.538782  141.787370  138.866656  137.631479  135.892420  ...
# 91.250000   141.494517  141.739204  138.835307  137.621462  135.874067  ...
# 121.666667  141.622439  141.880899  138.920876  137.649795  135.929335  ...
#
#               NI1609-3    NI1612-2    NI1701-1    NI1702-1    NI1704-2  \
# time
# 0.000000    137.946918  137.475572  137.734305  137.660615  135.925181
# 30.416667   137.953822  137.481993  137.740273  137.666753  135.936037
# 60.833333   137.921722  137.454039  137.716987  137.643609  135.896254
# 91.250000   137.903585  137.437602  137.702773  137.629293  135.873463
# 121.666667  137.961909  137.488519  137.745315  137.671608  135.945846
#
#               NI1705-2    NI1706-2    NI1707-1    NI1708-1    NI1711-1
# time
# 0.000000    136.050387  135.981682  135.897330  139.074642  139.553246
# 30.416667   136.060870  135.990418  135.906981  139.080679  139.559330
# 60.833333   136.023459  135.959705  135.873142  139.055335  139.532027
# 91.250000   136.001664  135.941456  135.853264  139.039877  139.516018
# 121.666667  136.069796  135.997458  135.914923  139.086183  139.565766
#
# [5 rows x 145 columns]

# %%
sp_start = pd.to_datetime('2016-01-01') + pd.to_timedelta(df.index.values,unit='d')

# %%
hds_file = os.path.join(tmp_model_ws, 'head.obs.csv')

hds_df = pf.add_observations(
    hds_file,
    insfile='head.csv.ins',
    index_cols='time',
    use_cols=list(df.columns.values),
    prefix='hds'
)
# Out:
# 2021-12-20 22:09:06.943716 starting: adding observations from output file ..\temp_pst_from\head.obs.csv
# 2021-12-20 22:09:06.944712 starting: adding observations from tabular output file '['..\\temp_pst_from\\head.obs.csv']'
# 2021-12-20 22:09:06.944712 starting: reading list ..\hagfors_1_template\..\temp_pst_from\head.obs.csv
# 2021-12-20 22:09:06.954688 finished: reading list ..\hagfors_1_template\..\temp_pst_from\head.obs.csv took: 0:00:00.009976
# 2021-12-20 22:09:06.955684 starting: building insfile for tabular output file ..\temp_pst_from\head.obs.csv
# 2021-12-20 22:09:06.984606 finished: building insfile for tabular output file ..\temp_pst_from\head.obs.csv took: 0:00:00.028922
# 2021-12-20 22:09:06.985603 starting: adding observation from instruction file '..\hagfors_1_template\head.csv.ins'
# 2021-12-20 22:09:07.078388 finished: adding observation from instruction file '..\hagfors_1_template\head.csv.ins' took: 0:00:00.092785
# 2021-12-20 22:09:07.085368 finished: adding observations from tabular output file '['..\\temp_pst_from\\head.obs.csv']' took: 0:00:00.140656

# %%
hds_df
# Out:
#                                                                                 obsnme  \
# hds_usecol:b10-2_time:0.0                                    hds_usecol:b10-2_time:0.0
# hds_usecol:b10-2_time:1003.75                            hds_usecol:b10-2_time:1003.75
# hds_usecol:b10-2_time:1034.166666667              hds_usecol:b10-2_time:1034.166666667
# hds_usecol:b10-2_time:1064.583333333              hds_usecol:b10-2_time:1064.583333333
# hds_usecol:b10-2_time:1095.0                              hds_usecol:b10-2_time:1095.0
# ...                                                                                ...
# hds_usecol:ni1804-3_time:882.0833333333001  hds_usecol:ni1804-3_time:882.0833333333001
# hds_usecol:ni1804-3_time:91.25                          hds_usecol:ni1804-3_time:91.25
# hds_usecol:ni1804-3_time:912.5                          hds_usecol:ni1804-3_time:912.5
# hds_usecol:ni1804-3_time:942.9166666666999  hds_usecol:ni1804-3_time:942.9166666666999
# hds_usecol:ni1804-3_time:973.3333333333001  hds_usecol:ni1804-3_time:973.3333333333001
#
#                                                 obsval  weight  \
# hds_usecol:b10-2_time:0.0                   136.171989     1.0
# hds_usecol:b10-2_time:1003.75               136.249412     1.0
# hds_usecol:b10-2_time:1034.166666667        136.271584     1.0
# hds_usecol:b10-2_time:1064.583333333        136.229212     1.0
# hds_usecol:b10-2_time:1095.0                136.046690     1.0
# ...                                                ...     ...
# hds_usecol:ni1804-3_time:882.0833333333001  135.636800     1.0
# hds_usecol:ni1804-3_time:91.25              135.645460     1.0
# hds_usecol:ni1804-3_time:912.5              135.630127     1.0
# hds_usecol:ni1804-3_time:942.9166666666999  135.696071     1.0
# hds_usecol:ni1804-3_time:973.3333333333001  135.728970     1.0
#
#                                                          obgnme
# hds_usecol:b10-2_time:0.0                      hds_usecol:b10-2
# hds_usecol:b10-2_time:1003.75                  hds_usecol:b10-2
# hds_usecol:b10-2_time:1034.166666667           hds_usecol:b10-2
# hds_usecol:b10-2_time:1064.583333333           hds_usecol:b10-2
# hds_usecol:b10-2_time:1095.0                   hds_usecol:b10-2
# ...                                                         ...
# hds_usecol:ni1804-3_time:882.0833333333001  hds_usecol:ni1804-3
# hds_usecol:ni1804-3_time:91.25              hds_usecol:ni1804-3
# hds_usecol:ni1804-3_time:912.5              hds_usecol:ni1804-3
# hds_usecol:ni1804-3_time:942.9166666666999  hds_usecol:ni1804-3
# hds_usecol:ni1804-3_time:973.3333333333001  hds_usecol:ni1804-3
#
# [7105 rows x 4 columns]

# %% [markdown]
# Set weights to zero:

# %%
hds_df.loc[:,'weight'] = 0.0

# %%
hds_df.head()
# Out:
#                                                                     obsnme  \
# hds_usecol:b10-2_time:0.0                        hds_usecol:b10-2_time:0.0
# hds_usecol:b10-2_time:1003.75                hds_usecol:b10-2_time:1003.75
# hds_usecol:b10-2_time:1034.166666667  hds_usecol:b10-2_time:1034.166666667
# hds_usecol:b10-2_time:1064.583333333  hds_usecol:b10-2_time:1064.583333333
# hds_usecol:b10-2_time:1095.0                  hds_usecol:b10-2_time:1095.0
#
#                                           obsval  weight            obgnme
# hds_usecol:b10-2_time:0.0             136.171989     0.0  hds_usecol:b10-2
# hds_usecol:b10-2_time:1003.75         136.249412     0.0  hds_usecol:b10-2
# hds_usecol:b10-2_time:1034.166666667  136.271584     0.0  hds_usecol:b10-2
# hds_usecol:b10-2_time:1064.583333333  136.229212     0.0  hds_usecol:b10-2
# hds_usecol:b10-2_time:1095.0          136.046690     0.0  hds_usecol:b10-2

# %% [markdown]
# #### Measured head
# The plan is to change the `obsval` of `hds_df` with real, measured data. Let's load the field measured data:

# %%
hds_meas = pyemu.utils.smp_to_dataframe(os.path.join('..', 'data', 'olproc_input', 'obs-head-all.ssf'))
hds_meas['name'] = hds_meas['name'].str.lower()
hds_meas
# Out:
#                  datetime      name       value
# 0     2016-11-15 12:00:00      b2-1  137.053540
# 1     2016-11-16 12:00:00      b2-1  137.048832
# 2     2016-11-17 12:00:00      b2-1  137.053302
# 3     2016-11-18 12:00:00      b2-1  137.053829
# 4     2016-11-19 12:00:00      b2-1  137.055800
# ...                   ...       ...         ...
# 10451 2017-05-01 12:00:00  ni1501-3  136.763333
# 10452 2017-05-02 12:00:00  ni1501-3  136.746667
# 10453 2017-05-03 12:00:00  ni1501-3  136.730000
# 10454 2017-05-04 12:00:00  ni1501-3  136.716667
# 10455 2017-05-05 12:00:00  ni1501-3  136.725000
#
# [10456 rows x 3 columns]

# %% [markdown]
# #### Plot measured heads

# %%
for site in hds_meas['name'].unique():
    
    site_obs_data = hds_meas.loc[hds_meas['name'] == site]
    
    fig,ax = plt.subplots(1,1,figsize=(10,2))
    
    ax.plot(site_obs_data.datetime,site_obs_data.value)
    ax.set_title(site)

plt.show()

# %% [markdown]
# These datasets will now be sampled for use in history-matching purposes. Sampling can be done in different ways. Let's explore two options based on a notebook developed by Jeremy White (https://github.com/jtwhite79/decision_support_analysis_notebooks/blob/main/notebooks/process_obs_and_set_weights.ipynb) and visualize the options together with the raw data.

# %% [markdown]
# #### Option 1: sampling the nearest data

# %%
hds_meas_nearest, hds_meas_lowpass = [], []

# %%
for site in hds_meas['name'].unique():
    site_obs_data = hds_meas.loc[hds_meas['name'] == site].copy()
    site_obs_data.index = site_obs_data.datetime
    site_obs_data = site_obs_data.reindex(sp_start,method='nearest')
    site_obs_data['datetime'] = site_obs_data.index
    site_obs_data.sort_values(by='datetime', inplace=True)
    hds_meas_nearest.append(site_obs_data)
hds_meas_nearest = pd.concat(hds_meas_nearest,axis=0,ignore_index=True)
hds_meas_nearest.shape
# Out:
# (1323, 3)

# %% [markdown]
# This dataframe now contain alot of duplicate values (as is apparent below). Let's clean this up.

# %%
hds_meas_nearest
# Out:
#                           datetime      name      value
# 0    2016-01-01 00:00:00.000000000      b2-1  137.05354
# 1    2016-01-31 10:00:00.000028800      b2-1  137.05354
# 2    2016-03-01 19:59:59.999971200      b2-1  137.05354
# 3    2016-04-01 06:00:00.000000000      b2-1  137.05354
# 4    2016-05-01 16:00:00.000028800      b2-1  137.05354
# ...                            ...       ...        ...
# 1318 2019-08-31 07:59:59.999971200  ni1501-3  136.72500
# 1319 2019-09-30 18:00:00.000000000  ni1501-3  136.72500
# 1320 2019-10-31 04:00:00.000028800  ni1501-3  136.72500
# 1321 2019-11-30 13:59:59.999971200  ni1501-3  136.72500
# 1322 2019-12-31 00:00:00.000000000  ni1501-3  136.72500
#
# [1323 rows x 3 columns]

# %%
hds_meas_nearest = hds_meas_nearest.drop_duplicates('value').reset_index(drop=True)

# %% [markdown]
# #### Option 2: using a lowpass filter

# %%
for site in hds_meas['name'].unique():
    site_obs_data = hds_meas.loc[hds_meas['name'] == site].copy()
    site_obs_data.index = site_obs_data.datetime
    
    sm = site_obs_data.value.rolling(window=60,center=True,min_periods=1).mean()
    sm_site_obs_data = sm.reindex(sp_start,method='nearest')

    df = pd.DataFrame(sm_site_obs_data)
    df['datetime'], df['name'] = df.index, site
    df = df[['datetime', 'name', 'value']]
    df.sort_values(by="datetime",inplace=True)
    hds_meas_lowpass.append(df)
hds_meas_lowpass = pd.concat(hds_meas_lowpass,axis=0,ignore_index=True).drop_duplicates('value').reset_index(drop=True)
hds_meas_lowpass.shape
# Out:
# (384, 3)

# %% [markdown]
# Ensure that sampled data is only collected from time-periods of when actual measurements were collected:

# %%
obs_sites = hds_meas['name'].unique().copy()

# %%
def add_timedeltas(df, model_start_time):
    df['timedelta'] = [(dt - pd.to_datetime(model_start_time)).total_seconds() / 86400 for dt in df.datetime]

# %%
for df in [hds_meas, hds_meas_nearest, hds_meas_lowpass]:
    add_timedeltas(df, '2016-01-01')

# %%
def match_timedeltas(measured_df, timeinterp_df):
    '''
    This function compares timedeltas of the time-interpolated values with that of the field measurements.
    
    If a time-interpolated value is within +- 2 days of a field measurement,
    this value is accepted, else the row is dropped.
    '''
    timedelta_match = []
    
    for i, r in timeinterp_df.iterrows():

        results = []

        for j in measured_df.timedelta:
            result = j + 2 >= r.timedelta >= j - 2 # determine whether there is a match between datasets
            results.append(result)

        if any(results) == True:
            timedelta_match.append(True)
        else:
            timedelta_match.append(False)
            
    return timedelta_match

# %%
for df in [hds_meas_nearest, hds_meas_lowpass]:
    df['td_match'] = False
    
    # Loop over each site
    for site in hds_meas.name.unique():
        meas_df = hds_meas.loc[hds_meas['name'] == site]
        df_sub = df.loc[df['name'] == site]
        
        df.loc[df['name'] == site, 'td_match'] = match_timedeltas(meas_df, df_sub)

# %%
hds_meas_nearest = hds_meas_nearest.loc[hds_meas_nearest['td_match'] == True].reset_index(drop=True)
hds_meas_lowpass = hds_meas_lowpass.loc[hds_meas_lowpass['td_match'] == True].reset_index(drop=True)

# %% [markdown]
# #### Visualize the two sampling options. `Nearest data` samples are shown in red. `Lowpass data` samples are shown in green:

# %%
for site in obs_sites:
    
    site_obs_data = hds_meas.loc[hds_meas['name'] == site]
    site_obs_data_nearest = hds_meas_nearest.loc[hds_meas_nearest['name'] == site]
    site_obs_data_lowpass = hds_meas_lowpass.loc[hds_meas_lowpass['name'] == site]
    
    fig,ax = plt.subplots(1,1,figsize=(10,2))
    
    ax.plot(site_obs_data.datetime,site_obs_data.value)
    ax.plot(site_obs_data_nearest.datetime,site_obs_data_nearest.value,'r-',lw=1,marker='.',ms=10)
    ax.scatter(site_obs_data_nearest.datetime,site_obs_data_nearest.value, color='r')

    ax.plot(site_obs_data_lowpass.datetime, site_obs_data_lowpass.value,'g-',lw=1,marker='.',ms=10)
    ax.scatter(site_obs_data_lowpass.datetime, site_obs_data_lowpass.value, color='g')

plt.show()

# %% [markdown]
# The lowpass sampling method seem to capture the trend of the data better than using the nearest option. Because of this, the lowpass interpolated measurements will be used in the history-matching process.
#
# #### Replace model `obsval` with `lowpass` interpolated measurements
# A reminder of how the PEST observations are setup:

# %%
hds_df.head()
# Out:
#                                                                     obsnme  \
# hds_usecol:b10-2_time:0.0                        hds_usecol:b10-2_time:0.0
# hds_usecol:b10-2_time:1003.75                hds_usecol:b10-2_time:1003.75
# hds_usecol:b10-2_time:1034.166666667  hds_usecol:b10-2_time:1034.166666667
# hds_usecol:b10-2_time:1064.583333333  hds_usecol:b10-2_time:1064.583333333
# hds_usecol:b10-2_time:1095.0                  hds_usecol:b10-2_time:1095.0
#
#                                           obsval  weight            obgnme
# hds_usecol:b10-2_time:0.0             136.171989     0.0  hds_usecol:b10-2
# hds_usecol:b10-2_time:1003.75         136.249412     0.0  hds_usecol:b10-2
# hds_usecol:b10-2_time:1034.166666667  136.271584     0.0  hds_usecol:b10-2
# hds_usecol:b10-2_time:1064.583333333  136.229212     0.0  hds_usecol:b10-2
# hds_usecol:b10-2_time:1095.0          136.046690     0.0  hds_usecol:b10-2

# %% [markdown]
# Now, the mission is to assign a weight > 0 for the observations where we have time-interpolated (using a lowpass filter) measurements. Recall that the time-interpolated measurements are located in the `hds_meas_lowpass` DataFrame. The values in this dataframe must now be matched with the corresponding values of `hds_df`.
#
# As we can see, we have a `datetime` column. This information must be converted into model time so that values can be matched:

# %%
hds_meas_lowpass.iloc[:]
# Out:
#                          datetime      name       value   timedelta  td_match
# 0   2016-11-30 13:59:59.999971200      b2-1  137.048802  334.583333      True
# 1   2016-12-31 00:00:00.000000000      b2-1  137.040387  365.000000      True
# 2   2017-01-30 10:00:00.000028800      b2-1  137.022339  395.416667      True
# 3   2017-03-01 19:59:59.999971200      b2-1  136.991891  425.833333      True
# 4   2017-04-01 06:00:00.000000000      b2-1  136.978018  456.250000      True
# ..                            ...       ...         ...         ...       ...
# 344 2016-12-31 00:00:00.000000000  ni1501-3  136.730250  365.000000      True
# 345 2017-01-30 10:00:00.000028800  ni1501-3  136.723472  395.416667      True
# 346 2017-03-01 19:59:59.999971200  ni1501-3  136.760056  425.833333      True
# 347 2017-04-01 06:00:00.000000000  ni1501-3  136.783125  456.250000      True
# 348 2017-05-01 16:00:00.000028800  ni1501-3  136.769786  486.666667      True
#
# [349 rows x 5 columns]

# %%
def build_matching_obs_columns(df, col_prefix):
    
    # Build partial obsnme column (for matching against PEST observations dataframe)
    df['matchcol'] = [f'{col_prefix}_usecol:{i}_time:{j}' for i, j in zip(df['name'], df['timedelta'])]
    df['matchcol'] = [i[:i.index('.') + 2] for i in df['matchcol']]
    
    df['obsgnme'] = [f'{col_prefix}_usecol:{i}' for i in df['name']]
    
    df['weight'] = 1.0
    
    df['obsval'] = df['value']

# %%
build_matching_obs_columns(hds_meas_lowpass, 'hds')

# %% [markdown]
# `obsnme` in the `hds_meas_lowpass` dataframe will now be used to find matching `obsnme` rows in `hds_df` and then replace `obsval` and `weight` with time-interpolated field measurements:

# %%
hds_meas_lowpass.head()
# Out:
#                        datetime  name       value   timedelta  td_match  \
# 0 2016-11-30 13:59:59.999971200  b2-1  137.048802  334.583333      True
# 1 2016-12-31 00:00:00.000000000  b2-1  137.040387  365.000000      True
# 2 2017-01-30 10:00:00.000028800  b2-1  137.022339  395.416667      True
# 3 2017-03-01 19:59:59.999971200  b2-1  136.991891  425.833333      True
# 4 2017-04-01 06:00:00.000000000  b2-1  136.978018  456.250000      True
#
#                      matchcol          obsgnme  weight      obsval
# 0  hds_usecol:b2-1_time:334.5  hds_usecol:b2-1     1.0  137.048802
# 1  hds_usecol:b2-1_time:365.0  hds_usecol:b2-1     1.0  137.040387
# 2  hds_usecol:b2-1_time:395.4  hds_usecol:b2-1     1.0  137.022339
# 3  hds_usecol:b2-1_time:425.8  hds_usecol:b2-1     1.0  136.991891
# 4  hds_usecol:b2-1_time:456.2  hds_usecol:b2-1     1.0  136.978018

# %% [markdown]
# Add a temporary `matchcol` column so that `obsval` can be changed to time-interpolated measured counterparts:

# %%
hds_df['matchcol'] = [i[:i.index('.') + 2] for i in hds_df['obsnme']]

# %% [markdown]
# Assign the time-interpolated measurements to the `obsval` and give these measurements a positive weight for the history-matching process:

# %%
for i,r in hds_meas_lowpass.iterrows():

    hds_df.loc[hds_df.matchcol == r.matchcol, 'weight'] = 1.0
    hds_df.loc[hds_df.matchcol == r.matchcol, 'obsval'] = r.value

# %%
hds_df.loc[hds_df['weight'] == 1.0]
# Out:
#                                                                           obsnme  \
# hds_usecol:b2-1_time:1003.75                        hds_usecol:b2-1_time:1003.75
# hds_usecol:b2-1_time:1034.166666667          hds_usecol:b2-1_time:1034.166666667
# hds_usecol:b2-1_time:1064.583333333          hds_usecol:b2-1_time:1064.583333333
# hds_usecol:b2-1_time:1095.0                          hds_usecol:b2-1_time:1095.0
# hds_usecol:b2-1_time:1125.416666667          hds_usecol:b2-1_time:1125.416666667
# ...                                                                          ...
# hds_usecol:ni1802-1_time:1338.333333333  hds_usecol:ni1802-1_time:1338.333333333
# hds_usecol:ni1802-1_time:1368.75                hds_usecol:ni1802-1_time:1368.75
# hds_usecol:ni1802-1_time:1399.166666667  hds_usecol:ni1802-1_time:1399.166666667
# hds_usecol:ni1802-1_time:1429.583333333  hds_usecol:ni1802-1_time:1429.583333333
# hds_usecol:ni1802-1_time:1460.0                  hds_usecol:ni1802-1_time:1460.0
#
#                                              obsval  weight  \
# hds_usecol:b2-1_time:1003.75             136.924315     1.0
# hds_usecol:b2-1_time:1034.166666667      136.889646     1.0
# hds_usecol:b2-1_time:1064.583333333      136.882786     1.0
# hds_usecol:b2-1_time:1095.0              136.875700     1.0
# hds_usecol:b2-1_time:1125.416666667      136.852400     1.0
# ...                                             ...     ...
# hds_usecol:ni1802-1_time:1338.333333333  134.114778     1.0
# hds_usecol:ni1802-1_time:1368.75         134.206133     1.0
# hds_usecol:ni1802-1_time:1399.166666667  134.231439     1.0
# hds_usecol:ni1802-1_time:1429.583333333  134.257222     1.0
# hds_usecol:ni1802-1_time:1460.0          134.297448     1.0
#
#                                                       obgnme  \
# hds_usecol:b2-1_time:1003.75                 hds_usecol:b2-1
# hds_usecol:b2-1_time:1034.166666667          hds_usecol:b2-1
# hds_usecol:b2-1_time:1064.583333333          hds_usecol:b2-1
# hds_usecol:b2-1_time:1095.0                  hds_usecol:b2-1
# hds_usecol:b2-1_time:1125.416666667          hds_usecol:b2-1
# ...                                                      ...
# hds_usecol:ni1802-1_time:1338.333333333  hds_usecol:ni1802-1
# hds_usecol:ni1802-1_time:1368.75         hds_usecol:ni1802-1
# hds_usecol:ni1802-1_time:1399.166666667  hds_usecol:ni1802-1
# hds_usecol:ni1802-1_time:1429.583333333  hds_usecol:ni1802-1
# hds_usecol:ni1802-1_time:1460.0          hds_usecol:ni1802-1
#
#                                                                 matchcol
# hds_usecol:b2-1_time:1003.75                 hds_usecol:b2-1_time:1003.7
# hds_usecol:b2-1_time:1034.166666667          hds_usecol:b2-1_time:1034.1
# hds_usecol:b2-1_time:1064.583333333          hds_usecol:b2-1_time:1064.5
# hds_usecol:b2-1_time:1095.0                  hds_usecol:b2-1_time:1095.0
# hds_usecol:b2-1_time:1125.416666667          hds_usecol:b2-1_time:1125.4
# ...                                                                  ...
# hds_usecol:ni1802-1_time:1338.333333333  hds_usecol:ni1802-1_time:1338.3
# hds_usecol:ni1802-1_time:1368.75         hds_usecol:ni1802-1_time:1368.7
# hds_usecol:ni1802-1_time:1399.166666667  hds_usecol:ni1802-1_time:1399.1
# hds_usecol:ni1802-1_time:1429.583333333  hds_usecol:ni1802-1_time:1429.5
# hds_usecol:ni1802-1_time:1460.0          hds_usecol:ni1802-1_time:1460.0
#
# [349 rows x 5 columns]

# %% [markdown]
# Remove the temporary `matchcol` column from the history-matching dataset:

# %%
hds_df.drop('matchcol', axis=1, inplace=True)

# %% [markdown]
# **Setting up history-matching for heads completed.**

# %% [markdown]
# ### 2.2 Head differences

# %% [markdown]
# Create the csv-file from measured head that will be read

# %%
hds_meas_lowpass_td = hds_meas_lowpass.copy() # temporal difference

# %%
hds_meas_lowpass_td
# Out:
#                          datetime      name       value   timedelta  td_match  \
# 0   2016-11-30 13:59:59.999971200      b2-1  137.048802  334.583333      True
# 1   2016-12-31 00:00:00.000000000      b2-1  137.040387  365.000000      True
# 2   2017-01-30 10:00:00.000028800      b2-1  137.022339  395.416667      True
# 3   2017-03-01 19:59:59.999971200      b2-1  136.991891  425.833333      True
# 4   2017-04-01 06:00:00.000000000      b2-1  136.978018  456.250000      True
# ..                            ...       ...         ...         ...       ...
# 344 2016-12-31 00:00:00.000000000  ni1501-3  136.730250  365.000000      True
# 345 2017-01-30 10:00:00.000028800  ni1501-3  136.723472  395.416667      True
# 346 2017-03-01 19:59:59.999971200  ni1501-3  136.760056  425.833333      True
# 347 2017-04-01 06:00:00.000000000  ni1501-3  136.783125  456.250000      True
# 348 2017-05-01 16:00:00.000028800  ni1501-3  136.769786  486.666667      True
#
#                            matchcol              obsgnme  weight      obsval
# 0        hds_usecol:b2-1_time:334.5      hds_usecol:b2-1     1.0  137.048802
# 1        hds_usecol:b2-1_time:365.0      hds_usecol:b2-1     1.0  137.040387
# 2        hds_usecol:b2-1_time:395.4      hds_usecol:b2-1     1.0  137.022339
# 3        hds_usecol:b2-1_time:425.8      hds_usecol:b2-1     1.0  136.991891
# 4        hds_usecol:b2-1_time:456.2      hds_usecol:b2-1     1.0  136.978018
# ..                              ...                  ...     ...         ...
# 344  hds_usecol:ni1501-3_time:365.0  hds_usecol:ni1501-3     1.0  136.730250
# 345  hds_usecol:ni1501-3_time:395.4  hds_usecol:ni1501-3     1.0  136.723472
# 346  hds_usecol:ni1501-3_time:425.8  hds_usecol:ni1501-3     1.0  136.760056
# 347  hds_usecol:ni1501-3_time:456.2  hds_usecol:ni1501-3     1.0  136.783125
# 348  hds_usecol:ni1501-3_time:486.6  hds_usecol:ni1501-3     1.0  136.769786
#
# [349 rows x 9 columns]

# %% [markdown]
# ### 2.3 Stage

# %% [markdown]
# Read computed stage:

# %%
df = pd.read_csv(os.path.join(template_ws, 'sfr_stage.obs.csv'),index_col=0)
df.head()
# Out:
#             NI15-O1-STG  NI15-O44-STG  NI15-O46-STG  NI15-O47-STG  \
# time
# 0.000000     136.867571    136.873137    135.592200    135.349386
# 30.416667    136.868639    136.874285    135.593802    135.351231
# 60.833333    136.863942    136.869487    135.588722    135.345959
# 91.250000    136.861386    136.866862    135.585851    135.342946
# 121.666667   136.869915    136.875578    135.595100    135.352549
#
#             NI15-O48-STG
# time
# 0.000000      134.493341
# 30.416667     134.495954
# 60.833333     134.489886
# 91.250000     134.486358
# 121.666667    134.497427

# %%
stg_file = os.path.join(template_ws, 'sfr_stage.obs.csv')

stg_df = pf.add_observations(
    stg_file,
    insfile='stage.csv.ins',
    index_cols='time',
    use_cols=list(df.columns.values),
    prefix='stg'
)
# Out:
# 2021-12-20 22:09:24.418527 starting: adding observations from output file ..\hagfors_1_template\sfr_stage.obs.csv
# 2021-12-20 22:09:24.419524 starting: adding observations from tabular output file '['..\\hagfors_1_template\\sfr_stage.obs.csv']'
# 2021-12-20 22:09:24.420522 starting: reading list ..\hagfors_1_template\..\hagfors_1_template\sfr_stage.obs.csv
# 2021-12-20 22:09:24.423513 finished: reading list ..\hagfors_1_template\..\hagfors_1_template\sfr_stage.obs.csv took: 0:00:00.002991
# 2021-12-20 22:09:24.423513 starting: building insfile for tabular output file ..\hagfors_1_template\sfr_stage.obs.csv
# 2021-12-20 22:09:24.435481 finished: building insfile for tabular output file ..\hagfors_1_template\sfr_stage.obs.csv took: 0:00:00.011968
# 2021-12-20 22:09:24.436479 starting: adding observation from instruction file '..\hagfors_1_template\stage.csv.ins'
# 2021-12-20 22:09:24.454434 finished: adding observation from instruction file '..\hagfors_1_template\stage.csv.ins' took: 0:00:00.017955
# 2021-12-20 22:09:24.456427 finished: adding observations from tabular output file '['..\\hagfors_1_template\\sfr_stage.obs.csv']' took: 0:00:00.036903

# %%
stg_df.loc[:,'weight'] = 0.0

# %%
stg_df.head()
# Out:
#                                                                                 obsnme  \
# stg_usecol:ni15-o1-stg_time:0.0                        stg_usecol:ni15-o1-stg_time:0.0
# stg_usecol:ni15-o1-stg_time:1003.75                stg_usecol:ni15-o1-stg_time:1003.75
# stg_usecol:ni15-o1-stg_time:1034.166666667  stg_usecol:ni15-o1-stg_time:1034.166666667
# stg_usecol:ni15-o1-stg_time:1064.583333333  stg_usecol:ni15-o1-stg_time:1064.583333333
# stg_usecol:ni15-o1-stg_time:1095.0                  stg_usecol:ni15-o1-stg_time:1095.0
#
#                                                 obsval  weight  \
# stg_usecol:ni15-o1-stg_time:0.0             136.867571     0.0
# stg_usecol:ni15-o1-stg_time:1003.75         136.871375     0.0
# stg_usecol:ni15-o1-stg_time:1034.166666667  136.872380     0.0
# stg_usecol:ni15-o1-stg_time:1064.583333333  136.870392     0.0
# stg_usecol:ni15-o1-stg_time:1095.0          136.861729     0.0
#
#                                                             obgnme
# stg_usecol:ni15-o1-stg_time:0.0             stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:1003.75         stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:1034.166666667  stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:1064.583333333  stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:1095.0          stg_usecol:ni15-o1-stg

# %%
stg_meas = pyemu.utils.smp_to_dataframe(os.path.join('..', 'data', 'olproc_input', 'obs-stage1.ssf'))
stg_meas['name'] = stg_meas['name'].str.lower()
stg_meas
# Out:
#                 datetime          name       value
# 0    2016-11-15 12:00:00   ni15-o1-stg  136.156667
# 1    2016-11-16 12:00:00   ni15-o1-stg  136.153333
# 2    2016-11-17 12:00:00   ni15-o1-stg  136.193333
# 3    2016-11-18 12:00:00   ni15-o1-stg  136.243333
# 4    2016-11-19 12:00:00   ni15-o1-stg  136.316667
# ...                  ...           ...         ...
# 2495 2017-06-17 12:00:00  ni15-o48-stg  133.531667
# 2496 2017-06-18 12:00:00  ni15-o48-stg  133.530000
# 2497 2017-06-19 12:00:00  ni15-o48-stg  133.521667
# 2498 2017-06-20 12:00:00  ni15-o48-stg  133.538333
# 2499 2017-06-21 12:00:00  ni15-o48-stg  133.527500
#
# [2500 rows x 3 columns]

# %%
for site in stg_meas['name'].unique():
    
    site_obs_data = stg_meas.loc[stg_meas['name'] == site]
    
    fig,ax = plt.subplots(1,1,figsize=(10,2))
    
    ax.plot(site_obs_data.datetime,site_obs_data.value)
    ax.set_title(site)

plt.show()

# %%
stg_meas_nearest, stg_meas_lowpass = [], []

# %%
for site in stg_meas['name'].unique():
    site_obs_data = stg_meas.loc[stg_meas['name'] == site].copy()
    site_obs_data.index = site_obs_data.datetime
    site_obs_data = site_obs_data.reindex(sp_start,method='nearest')
    site_obs_data['datetime'] = site_obs_data.index
    site_obs_data.sort_values(by='datetime', inplace=True)
    stg_meas_nearest.append(site_obs_data)
stg_meas_nearest = pd.concat(stg_meas_nearest,axis=0,ignore_index=True).drop_duplicates('value').reset_index(drop=True)
stg_meas_nearest.shape
# Out:
# (88, 3)

# %%
for site in stg_meas['name'].unique():
    site_obs_data = stg_meas.loc[stg_meas['name'] == site].copy()
    site_obs_data.index = site_obs_data.datetime
    
    sm = site_obs_data.value.rolling(window=30,center=True,min_periods=1).mean() # test window of 30 inst of 60
    sm_site_obs_data = sm.reindex(sp_start,method='nearest')

    df = pd.DataFrame(sm_site_obs_data)
    df['datetime'], df['name'] = df.index, site
    df = df[['datetime', 'name', 'value']]
    df.sort_values(by="datetime",inplace=True)
    stg_meas_lowpass.append(df)
stg_meas_lowpass = pd.concat(stg_meas_lowpass,axis=0,ignore_index=True).drop_duplicates('value').reset_index(drop=True)
stg_meas_lowpass.shape
# Out:
# (90, 3)

# %%
obs_sites = stg_meas['name'].unique().copy()

# %%
for df in [stg_meas, stg_meas_nearest, stg_meas_lowpass]:
    add_timedeltas(df, '2016-01-01')

# %%
for df in [stg_meas_nearest, stg_meas_lowpass]:
    df['td_match'] = False
    
    # Loop over each site
    for site in stg_meas.name.unique():
        meas_df = stg_meas.loc[stg_meas['name'] == site]
        df_sub = df.loc[df['name'] == site]
        
        df.loc[df['name'] == site, 'td_match'] = match_timedeltas(meas_df, df_sub)

# %%
stg_meas_nearest = stg_meas_nearest.loc[stg_meas_nearest['td_match'] == True].reset_index(drop=True)
stg_meas_lowpass = stg_meas_lowpass.loc[stg_meas_lowpass['td_match'] == True].reset_index(drop=True)

# %%
for site in obs_sites:
    
    site_obs_data = stg_meas.loc[stg_meas['name'] == site]
    site_obs_data_nearest = stg_meas_nearest.loc[stg_meas_nearest['name'] == site]
    site_obs_data_lowpass = stg_meas_lowpass.loc[stg_meas_lowpass['name'] == site]
    
    fig,ax = plt.subplots(1,1,figsize=(10,2))
    
    ax.plot(site_obs_data.datetime,site_obs_data.value)
    ax.plot(site_obs_data_nearest.datetime,site_obs_data_nearest.value,'r-',lw=1,marker='.',ms=10)
    ax.scatter(site_obs_data_nearest.datetime,site_obs_data_nearest.value, color='r')

    ax.plot(site_obs_data_lowpass.datetime, site_obs_data_lowpass.value,'g-',lw=1,marker='.',ms=10)
    ax.scatter(site_obs_data_lowpass.datetime, site_obs_data_lowpass.value, color='g')

plt.show()

# %%
stg_df
# Out:
#                                                                                         obsnme  \
# stg_usecol:ni15-o1-stg_time:0.0                                stg_usecol:ni15-o1-stg_time:0.0
# stg_usecol:ni15-o1-stg_time:1003.75                        stg_usecol:ni15-o1-stg_time:1003.75
# stg_usecol:ni15-o1-stg_time:1034.166666667          stg_usecol:ni15-o1-stg_time:1034.166666667
# stg_usecol:ni15-o1-stg_time:1064.583333333          stg_usecol:ni15-o1-stg_time:1064.583333333
# stg_usecol:ni15-o1-stg_time:1095.0                          stg_usecol:ni15-o1-stg_time:1095.0
# ...                                                                                        ...
# stg_usecol:ni15-o48-stg_time:882.0833333333001  stg_usecol:ni15-o48-stg_time:882.0833333333001
# stg_usecol:ni15-o48-stg_time:91.25                          stg_usecol:ni15-o48-stg_time:91.25
# stg_usecol:ni15-o48-stg_time:912.5                          stg_usecol:ni15-o48-stg_time:912.5
# stg_usecol:ni15-o48-stg_time:942.9166666666999  stg_usecol:ni15-o48-stg_time:942.9166666666999
# stg_usecol:ni15-o48-stg_time:973.3333333333001  stg_usecol:ni15-o48-stg_time:973.3333333333001
#
#                                                     obsval  weight  \
# stg_usecol:ni15-o1-stg_time:0.0                 136.867571     0.0
# stg_usecol:ni15-o1-stg_time:1003.75             136.871375     0.0
# stg_usecol:ni15-o1-stg_time:1034.166666667      136.872380     0.0
# stg_usecol:ni15-o1-stg_time:1064.583333333      136.870392     0.0
# stg_usecol:ni15-o1-stg_time:1095.0              136.861729     0.0
# ...                                                    ...     ...
# stg_usecol:ni15-o48-stg_time:882.0833333333001  134.484417     0.0
# stg_usecol:ni15-o48-stg_time:91.25              134.486358     0.0
# stg_usecol:ni15-o48-stg_time:912.5              134.482886     0.0
# stg_usecol:ni15-o48-stg_time:942.9166666666999  134.497681     0.0
# stg_usecol:ni15-o48-stg_time:973.3333333333001  134.504647     0.0
#
#                                                                  obgnme
# stg_usecol:ni15-o1-stg_time:0.0                  stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:1003.75              stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:1034.166666667       stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:1064.583333333       stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:1095.0               stg_usecol:ni15-o1-stg
# ...                                                                 ...
# stg_usecol:ni15-o48-stg_time:882.0833333333001  stg_usecol:ni15-o48-stg
# stg_usecol:ni15-o48-stg_time:91.25              stg_usecol:ni15-o48-stg
# stg_usecol:ni15-o48-stg_time:912.5              stg_usecol:ni15-o48-stg
# stg_usecol:ni15-o48-stg_time:942.9166666666999  stg_usecol:ni15-o48-stg
# stg_usecol:ni15-o48-stg_time:973.3333333333001  stg_usecol:ni15-o48-stg
#
# [245 rows x 4 columns]

# %%
stg_meas_lowpass
# Out:
#                         datetime          name       value   timedelta  \
# 0  2016-11-30 13:59:59.999971200   ni15-o1-stg  136.172889  334.583333
# 1  2016-12-31 00:00:00.000000000   ni15-o1-stg  136.131667  365.000000
# 2  2017-01-30 10:00:00.000028800   ni15-o1-stg  136.123389  395.416667
# 3  2017-03-01 19:59:59.999971200   ni15-o1-stg  136.163389  425.833333
# 4  2017-04-01 06:00:00.000000000   ni15-o1-stg  136.264389  456.250000
# ..                           ...           ...         ...         ...
# 77 2017-01-30 10:00:00.000028800  ni15-o48-stg  133.573111  395.416667
# 78 2017-03-01 19:59:59.999971200  ni15-o48-stg  133.603611  425.833333
# 79 2017-04-01 06:00:00.000000000  ni15-o48-stg  133.680167  456.250000
# 80 2017-05-01 16:00:00.000028800  ni15-o48-stg  133.615722  486.666667
# 81 2017-06-01 01:59:59.999971200  ni15-o48-stg  133.540389  517.083333
#
#     td_match
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ..       ...
# 77      True
# 78      True
# 79      True
# 80      True
# 81      True
#
# [82 rows x 5 columns]

# %%
build_matching_obs_columns(stg_meas_lowpass, 'stg')

# %%
stg_meas_lowpass.head()
# Out:
#                        datetime         name       value   timedelta  \
# 0 2016-11-30 13:59:59.999971200  ni15-o1-stg  136.172889  334.583333
# 1 2016-12-31 00:00:00.000000000  ni15-o1-stg  136.131667  365.000000
# 2 2017-01-30 10:00:00.000028800  ni15-o1-stg  136.123389  395.416667
# 3 2017-03-01 19:59:59.999971200  ni15-o1-stg  136.163389  425.833333
# 4 2017-04-01 06:00:00.000000000  ni15-o1-stg  136.264389  456.250000
#
#    td_match                           matchcol                 obsgnme  \
# 0      True  stg_usecol:ni15-o1-stg_time:334.5  stg_usecol:ni15-o1-stg
# 1      True  stg_usecol:ni15-o1-stg_time:365.0  stg_usecol:ni15-o1-stg
# 2      True  stg_usecol:ni15-o1-stg_time:395.4  stg_usecol:ni15-o1-stg
# 3      True  stg_usecol:ni15-o1-stg_time:425.8  stg_usecol:ni15-o1-stg
# 4      True  stg_usecol:ni15-o1-stg_time:456.2  stg_usecol:ni15-o1-stg
#
#    weight      obsval
# 0     1.0  136.172889
# 1     1.0  136.131667
# 2     1.0  136.123389
# 3     1.0  136.163389
# 4     1.0  136.264389

# %%
stg_df['matchcol'] = [i[:i.index('.') + 2] for i in stg_df['obsnme']]

# %%
for i,r in stg_meas_lowpass.iterrows():

    stg_df.loc[stg_df.matchcol == r.matchcol, 'weight'] = 1.0
    stg_df.loc[stg_df.matchcol == r.matchcol, 'obsval'] = r.value

# %%
stg_df.loc[stg_df['weight'] == 1.0]
# Out:
#                                                                                         obsnme  \
# stg_usecol:ni15-o1-stg_time:334.5833333333          stg_usecol:ni15-o1-stg_time:334.5833333333
# stg_usecol:ni15-o1-stg_time:365.0                            stg_usecol:ni15-o1-stg_time:365.0
# stg_usecol:ni15-o1-stg_time:395.4166666667          stg_usecol:ni15-o1-stg_time:395.4166666667
# stg_usecol:ni15-o1-stg_time:425.8333333333          stg_usecol:ni15-o1-stg_time:425.8333333333
# stg_usecol:ni15-o1-stg_time:456.25                          stg_usecol:ni15-o1-stg_time:456.25
# ...                                                                                        ...
# stg_usecol:ni15-o48-stg_time:456.25                        stg_usecol:ni15-o48-stg_time:456.25
# stg_usecol:ni15-o48-stg_time:486.6666666667        stg_usecol:ni15-o48-stg_time:486.6666666667
# stg_usecol:ni15-o48-stg_time:517.0833333333001  stg_usecol:ni15-o48-stg_time:517.0833333333001
# stg_usecol:ni15-o48-stg_time:60.83333333333        stg_usecol:ni15-o48-stg_time:60.83333333333
# stg_usecol:ni15-o48-stg_time:91.25                          stg_usecol:ni15-o48-stg_time:91.25
#
#                                                     obsval  weight  \
# stg_usecol:ni15-o1-stg_time:334.5833333333      136.172889     1.0
# stg_usecol:ni15-o1-stg_time:365.0               136.131667     1.0
# stg_usecol:ni15-o1-stg_time:395.4166666667      136.123389     1.0
# stg_usecol:ni15-o1-stg_time:425.8333333333      136.163389     1.0
# stg_usecol:ni15-o1-stg_time:456.25              136.264389     1.0
# ...                                                    ...     ...
# stg_usecol:ni15-o48-stg_time:456.25             133.680167     1.0
# stg_usecol:ni15-o48-stg_time:486.6666666667     133.615722     1.0
# stg_usecol:ni15-o48-stg_time:517.0833333333001  133.540389     1.0
# stg_usecol:ni15-o48-stg_time:60.83333333333     133.660328     1.0
# stg_usecol:ni15-o48-stg_time:91.25              133.734222     1.0
#
#                                                                  obgnme  \
# stg_usecol:ni15-o1-stg_time:334.5833333333       stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:365.0                stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:395.4166666667       stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:425.8333333333       stg_usecol:ni15-o1-stg
# stg_usecol:ni15-o1-stg_time:456.25               stg_usecol:ni15-o1-stg
# ...                                                                 ...
# stg_usecol:ni15-o48-stg_time:456.25             stg_usecol:ni15-o48-stg
# stg_usecol:ni15-o48-stg_time:486.6666666667     stg_usecol:ni15-o48-stg
# stg_usecol:ni15-o48-stg_time:517.0833333333001  stg_usecol:ni15-o48-stg
# stg_usecol:ni15-o48-stg_time:60.83333333333     stg_usecol:ni15-o48-stg
# stg_usecol:ni15-o48-stg_time:91.25              stg_usecol:ni15-o48-stg
#
#                                                                           matchcol
# stg_usecol:ni15-o1-stg_time:334.5833333333       stg_usecol:ni15-o1-stg_time:334.5
# stg_usecol:ni15-o1-stg_time:365.0                stg_usecol:ni15-o1-stg_time:365.0
# stg_usecol:ni15-o1-stg_time:395.4166666667       stg_usecol:ni15-o1-stg_time:395.4
# stg_usecol:ni15-o1-stg_time:425.8333333333       stg_usecol:ni15-o1-stg_time:425.8
# stg_usecol:ni15-o1-stg_time:456.25               stg_usecol:ni15-o1-stg_time:456.2
# ...                                                                            ...
# stg_usecol:ni15-o48-stg_time:456.25             stg_usecol:ni15-o48-stg_time:456.2
# stg_usecol:ni15-o48-stg_time:486.6666666667     stg_usecol:ni15-o48-stg_time:486.6
# stg_usecol:ni15-o48-stg_time:517.0833333333001  stg_usecol:ni15-o48-stg_time:517.0
# stg_usecol:ni15-o48-stg_time:60.83333333333      stg_usecol:ni15-o48-stg_time:60.8
# stg_usecol:ni15-o48-stg_time:91.25               stg_usecol:ni15-o48-stg_time:91.2
#
# [82 rows x 5 columns]

# %%
stg_df.drop('matchcol', axis=1, inplace=True)

# %% [markdown]
# **Setting up history-matching for stage completed.**

# %% [markdown]
# ### 2.4 Stage differences

# %% [markdown]
# ### 2.5 Inflow (Stream gage)

# %%
df = pd.read_csv(os.path.join(template_ws, 'sfr_gage.obs.csv'),index_col=0)
df.head()
# Out:
#                  GAGE-1       GAGE-2
# time
# 0.000000    32391.78341  34373.17375
# 30.416667   32863.87620  34891.90214
# 60.833333   31837.92432  33786.35305
# 91.250000   31249.64871  33154.93345
# 121.666667  33117.00416  35166.82392

# %%
inf_file = os.path.join(tmp_model_ws, 'sfr_gage.obs.csv')

inf_df = pf.add_observations(
    inf_file,
    insfile='sfr_gage.csv.ins',
    index_cols='time',
    use_cols=list(df.columns.values),
    prefix='inf'
)
# Out:
# 2021-12-20 22:09:28.643175 starting: adding observations from output file ..\temp_pst_from\sfr_gage.obs.csv
# 2021-12-20 22:09:28.643175 starting: adding observations from tabular output file '['..\\temp_pst_from\\sfr_gage.obs.csv']'
# 2021-12-20 22:09:28.644171 starting: reading list ..\hagfors_1_template\..\temp_pst_from\sfr_gage.obs.csv
# 2021-12-20 22:09:28.646167 finished: reading list ..\hagfors_1_template\..\temp_pst_from\sfr_gage.obs.csv took: 0:00:00.001996
# 2021-12-20 22:09:28.647165 starting: building insfile for tabular output file ..\temp_pst_from\sfr_gage.obs.csv
# 2021-12-20 22:09:28.656139 finished: building insfile for tabular output file ..\temp_pst_from\sfr_gage.obs.csv took: 0:00:00.008974
# 2021-12-20 22:09:28.657164 starting: adding observation from instruction file '..\hagfors_1_template\sfr_gage.csv.ins'
# 2021-12-20 22:09:28.668143 finished: adding observation from instruction file '..\hagfors_1_template\sfr_gage.csv.ins' took: 0:00:00.010979
# 2021-12-20 22:09:28.671100 finished: adding observations from tabular output file '['..\\temp_pst_from\\sfr_gage.obs.csv']' took: 0:00:00.027925

# %%
inf_df
# Out:
#                                                                             obsnme  \
# inf_usecol:gage-1_time:0.0                              inf_usecol:gage-1_time:0.0
# inf_usecol:gage-1_time:1003.75                      inf_usecol:gage-1_time:1003.75
# inf_usecol:gage-1_time:1034.166666667        inf_usecol:gage-1_time:1034.166666667
# inf_usecol:gage-1_time:1064.583333333        inf_usecol:gage-1_time:1064.583333333
# inf_usecol:gage-1_time:1095.0                        inf_usecol:gage-1_time:1095.0
# ...                                                                            ...
# inf_usecol:gage-2_time:882.0833333333001  inf_usecol:gage-2_time:882.0833333333001
# inf_usecol:gage-2_time:91.25                          inf_usecol:gage-2_time:91.25
# inf_usecol:gage-2_time:912.5                          inf_usecol:gage-2_time:912.5
# inf_usecol:gage-2_time:942.9166666666999  inf_usecol:gage-2_time:942.9166666666999
# inf_usecol:gage-2_time:973.3333333333001  inf_usecol:gage-2_time:973.3333333333001
#
#                                                obsval  weight  \
# inf_usecol:gage-1_time:0.0                32391.78341     1.0
# inf_usecol:gage-1_time:1003.75            33504.52625     1.0
# inf_usecol:gage-1_time:1034.166666667     33681.60234     1.0
# inf_usecol:gage-1_time:1064.583333333     33256.37008     1.0
# inf_usecol:gage-1_time:1095.0             31377.85670     1.0
# ...                                               ...     ...
# inf_usecol:gage-2_time:882.0833333333001  32806.19799     1.0
# inf_usecol:gage-2_time:91.25              33154.93345     1.0
# inf_usecol:gage-2_time:912.5              32530.49821     1.0
# inf_usecol:gage-2_time:942.9166666666999  35218.57295     1.0
# inf_usecol:gage-2_time:973.3333333333001  36499.87881     1.0
#
#                                                      obgnme
# inf_usecol:gage-1_time:0.0                inf_usecol:gage-1
# inf_usecol:gage-1_time:1003.75            inf_usecol:gage-1
# inf_usecol:gage-1_time:1034.166666667     inf_usecol:gage-1
# inf_usecol:gage-1_time:1064.583333333     inf_usecol:gage-1
# inf_usecol:gage-1_time:1095.0             inf_usecol:gage-1
# ...                                                     ...
# inf_usecol:gage-2_time:882.0833333333001  inf_usecol:gage-2
# inf_usecol:gage-2_time:91.25              inf_usecol:gage-2
# inf_usecol:gage-2_time:912.5              inf_usecol:gage-2
# inf_usecol:gage-2_time:942.9166666666999  inf_usecol:gage-2
# inf_usecol:gage-2_time:973.3333333333001  inf_usecol:gage-2
#
# [98 rows x 4 columns]

# %%
inf_df.loc[:,'weight'] = 0.0

# %%
inf_df.head()
# Out:
#                                                                       obsnme  \
# inf_usecol:gage-1_time:0.0                        inf_usecol:gage-1_time:0.0
# inf_usecol:gage-1_time:1003.75                inf_usecol:gage-1_time:1003.75
# inf_usecol:gage-1_time:1034.166666667  inf_usecol:gage-1_time:1034.166666667
# inf_usecol:gage-1_time:1064.583333333  inf_usecol:gage-1_time:1064.583333333
# inf_usecol:gage-1_time:1095.0                  inf_usecol:gage-1_time:1095.0
#
#                                             obsval  weight             obgnme
# inf_usecol:gage-1_time:0.0             32391.78341     0.0  inf_usecol:gage-1
# inf_usecol:gage-1_time:1003.75         33504.52625     0.0  inf_usecol:gage-1
# inf_usecol:gage-1_time:1034.166666667  33681.60234     0.0  inf_usecol:gage-1
# inf_usecol:gage-1_time:1064.583333333  33256.37008     0.0  inf_usecol:gage-1
# inf_usecol:gage-1_time:1095.0          31377.85670     0.0  inf_usecol:gage-1

# %%
inf_meas = pyemu.utils.smp_to_dataframe(os.path.join('..', 'data', 'olproc_input', 'obs-gage1.ssf'))
inf_meas['name'] = inf_meas['name'].str.lower()
inf_meas
# Out:
#                 datetime    name      value
# 0    2016-01-01 12:00:00  gage-1  10395.130
# 1    2016-01-02 12:00:00  gage-1  10933.620
# 2    2016-01-03 12:00:00  gage-1   6578.902
# 3    2016-01-04 12:00:00  gage-1   6883.264
# 4    2016-01-05 12:00:00  gage-1   8264.599
# ...                  ...     ...        ...
# 1871 2019-12-28 12:00:00  gage-2  26121.600
# 1872 2019-12-29 12:00:00  gage-2  27442.800
# 1873 2019-12-30 12:00:00  gage-2  35524.800
# 1874 2019-12-31 12:00:00  gage-2  36986.400
# 1875 2020-01-01 12:00:00  gage-2  30328.200
#
# [1876 rows x 3 columns]

# %%
for site in inf_meas['name'].unique():
    
    site_obs_data = inf_meas.loc[inf_meas['name'] == site]
    
    fig,ax = plt.subplots(1,1,figsize=(10,2))
    
    ax.plot(site_obs_data.datetime,site_obs_data.value)
    ax.set_title(site)

plt.show()

# %%
inf_meas_nearest, inf_meas_lowpass = [], []

# %%
for site in inf_meas['name'].unique():
    site_obs_data = inf_meas.loc[inf_meas['name'] == site].copy()
    site_obs_data.index = site_obs_data.datetime
    site_obs_data = site_obs_data.reindex(sp_start,method='nearest')
    site_obs_data['datetime'] = site_obs_data.index
    site_obs_data.sort_values(by='datetime', inplace=True)
    inf_meas_nearest.append(site_obs_data)
inf_meas_nearest = pd.concat(inf_meas_nearest,axis=0,ignore_index=True).drop_duplicates('value').reset_index(drop=True)
inf_meas_nearest.shape
# Out:
# (64, 3)

# %%
for site in inf_meas['name'].unique():
    site_obs_data = inf_meas.loc[inf_meas['name'] == site].copy()
    site_obs_data.index = site_obs_data.datetime
    
    sm = site_obs_data.value.rolling(window=30,center=True,min_periods=1).mean() #30 window
    sm_site_obs_data = sm.reindex(sp_start,method='nearest')

    df = pd.DataFrame(sm_site_obs_data)
    df['datetime'], df['name'] = df.index, site
    df = df[['datetime', 'name', 'value']]
    df.sort_values(by='datetime', inplace=True)
    inf_meas_lowpass.append(df)
inf_meas_lowpass = pd.concat(inf_meas_lowpass,axis=0,ignore_index=True).drop_duplicates('value').reset_index(drop=True)
inf_meas_lowpass.shape
# Out:
# (64, 3)

# %%
obs_sites = inf_meas['name'].unique().copy()

# %%
for df in [inf_meas, inf_meas_nearest, inf_meas_lowpass]:
    add_timedeltas(df, '2016-01-01')

# %%
for df in [inf_meas_nearest, inf_meas_lowpass]:
    df['td_match'] = False
    
    # Loop over each site
    for site in inf_meas.name.unique():
        meas_df = inf_meas.loc[inf_meas['name'] == site]
        df_sub = df.loc[df['name'] == site]
        
        df.loc[df['name'] == site, 'td_match'] = match_timedeltas(meas_df, df_sub)

# %%
inf_meas_nearest = inf_meas_nearest.loc[inf_meas_nearest['td_match'] == True].reset_index(drop=True)
inf_meas_lowpass = inf_meas_lowpass.loc[inf_meas_lowpass['td_match'] == True].reset_index(drop=True)

# %%
for site in obs_sites:
    
    site_obs_data = inf_meas.loc[inf_meas['name'] == site]
    site_obs_data_nearest = inf_meas_nearest.loc[inf_meas_nearest['name'] == site]
    site_obs_data_lowpass = inf_meas_lowpass.loc[inf_meas_lowpass['name'] == site]
    
    fig,ax = plt.subplots(1,1,figsize=(10,2))
    
    ax.plot(site_obs_data.datetime,site_obs_data.value)
    ax.plot(site_obs_data_nearest.datetime,site_obs_data_nearest.value,'r-',lw=1,marker='.',ms=10)
    ax.scatter(site_obs_data_nearest.datetime,site_obs_data_nearest.value, color='r')

    ax.plot(site_obs_data_lowpass.datetime, site_obs_data_lowpass.value,'g-',lw=1,marker='.',ms=10)
    ax.scatter(site_obs_data_lowpass.datetime, site_obs_data_lowpass.value, color='g')

plt.show()

# %%
inf_df.head()
# Out:
#                                                                       obsnme  \
# inf_usecol:gage-1_time:0.0                        inf_usecol:gage-1_time:0.0
# inf_usecol:gage-1_time:1003.75                inf_usecol:gage-1_time:1003.75
# inf_usecol:gage-1_time:1034.166666667  inf_usecol:gage-1_time:1034.166666667
# inf_usecol:gage-1_time:1064.583333333  inf_usecol:gage-1_time:1064.583333333
# inf_usecol:gage-1_time:1095.0                  inf_usecol:gage-1_time:1095.0
#
#                                             obsval  weight             obgnme
# inf_usecol:gage-1_time:0.0             32391.78341     0.0  inf_usecol:gage-1
# inf_usecol:gage-1_time:1003.75         33504.52625     0.0  inf_usecol:gage-1
# inf_usecol:gage-1_time:1034.166666667  33681.60234     0.0  inf_usecol:gage-1
# inf_usecol:gage-1_time:1064.583333333  33256.37008     0.0  inf_usecol:gage-1
# inf_usecol:gage-1_time:1095.0          31377.85670     0.0  inf_usecol:gage-1

# %%
inf_meas_lowpass
# Out:
#                         datetime    name         value    timedelta  td_match
# 0  2016-01-01 00:00:00.000000000  gage-1   8556.474067     0.000000      True
# 1  2016-01-31 10:00:00.000028800  gage-1  22134.921700    30.416667      True
# 2  2016-03-01 19:59:59.999971200  gage-1   7562.068733    60.833333      True
# 3  2016-04-01 06:00:00.000000000  gage-1  48614.415400    91.250000      True
# 4  2016-05-01 16:00:00.000028800  gage-1  80535.739967   121.666667      True
# ..                           ...     ...           ...          ...       ...
# 58 2019-08-31 07:59:59.999971200  gage-2  13548.060000  1338.333333      True
# 59 2019-09-30 18:00:00.000000000  gage-2  14957.460000  1368.750000      True
# 60 2019-10-31 04:00:00.000028800  gage-2  30166.986667  1399.166667      True
# 61 2019-11-30 13:59:59.999971200  gage-2  48048.117333  1429.583333      True
# 62 2019-12-31 00:00:00.000000000  gage-2  39218.717647  1460.000000      True
#
# [63 rows x 5 columns]

# %%
build_matching_obs_columns(inf_meas_lowpass, 'inf')

# %%
inf_meas_lowpass.head()
# Out:
#                        datetime    name         value   timedelta  td_match  \
# 0 2016-01-01 00:00:00.000000000  gage-1   8556.474067    0.000000      True
# 1 2016-01-31 10:00:00.000028800  gage-1  22134.921700   30.416667      True
# 2 2016-03-01 19:59:59.999971200  gage-1   7562.068733   60.833333      True
# 3 2016-04-01 06:00:00.000000000  gage-1  48614.415400   91.250000      True
# 4 2016-05-01 16:00:00.000028800  gage-1  80535.739967  121.666667      True
#
#                        matchcol            obsgnme  weight        obsval
# 0    inf_usecol:gage-1_time:0.0  inf_usecol:gage-1     1.0   8556.474067
# 1   inf_usecol:gage-1_time:30.4  inf_usecol:gage-1     1.0  22134.921700
# 2   inf_usecol:gage-1_time:60.8  inf_usecol:gage-1     1.0   7562.068733
# 3   inf_usecol:gage-1_time:91.2  inf_usecol:gage-1     1.0  48614.415400
# 4  inf_usecol:gage-1_time:121.6  inf_usecol:gage-1     1.0  80535.739967

# %%
inf_df['matchcol'] = [i[:i.index('.') + 2] for i in inf_df['obsnme']]

# %%
for i,r in inf_meas_lowpass.iterrows():

    inf_df.loc[inf_df.matchcol == r.matchcol, 'weight'] = 1.0
    inf_df.loc[inf_df.matchcol == r.matchcol, 'obsval'] = r.value

# %%
inf_df.loc[inf_df['weight'] == 1.0]
# Out:
#                                                                       obsnme  \
# inf_usecol:gage-1_time:0.0                        inf_usecol:gage-1_time:0.0
# inf_usecol:gage-1_time:1003.75                inf_usecol:gage-1_time:1003.75
# inf_usecol:gage-1_time:1034.166666667  inf_usecol:gage-1_time:1034.166666667
# inf_usecol:gage-1_time:1064.583333333  inf_usecol:gage-1_time:1064.583333333
# inf_usecol:gage-1_time:1095.0                  inf_usecol:gage-1_time:1095.0
# ...                                                                      ...
# inf_usecol:gage-2_time:1338.333333333  inf_usecol:gage-2_time:1338.333333333
# inf_usecol:gage-2_time:1368.75                inf_usecol:gage-2_time:1368.75
# inf_usecol:gage-2_time:1399.166666667  inf_usecol:gage-2_time:1399.166666667
# inf_usecol:gage-2_time:1429.583333333  inf_usecol:gage-2_time:1429.583333333
# inf_usecol:gage-2_time:1460.0                  inf_usecol:gage-2_time:1460.0
#
#                                              obsval  weight  \
# inf_usecol:gage-1_time:0.0              8556.474067     1.0
# inf_usecol:gage-1_time:1003.75          6134.064933     1.0
# inf_usecol:gage-1_time:1034.166666667  17319.757500     1.0
# inf_usecol:gage-1_time:1064.583333333  19286.405667     1.0
# inf_usecol:gage-1_time:1095.0          16807.024800     1.0
# ...                                             ...     ...
# inf_usecol:gage-2_time:1338.333333333  13548.060000     1.0
# inf_usecol:gage-2_time:1368.75         14957.460000     1.0
# inf_usecol:gage-2_time:1399.166666667  30166.986667     1.0
# inf_usecol:gage-2_time:1429.583333333  48048.117333     1.0
# inf_usecol:gage-2_time:1460.0          39218.717647     1.0
#
#                                                   obgnme  \
# inf_usecol:gage-1_time:0.0             inf_usecol:gage-1
# inf_usecol:gage-1_time:1003.75         inf_usecol:gage-1
# inf_usecol:gage-1_time:1034.166666667  inf_usecol:gage-1
# inf_usecol:gage-1_time:1064.583333333  inf_usecol:gage-1
# inf_usecol:gage-1_time:1095.0          inf_usecol:gage-1
# ...                                                  ...
# inf_usecol:gage-2_time:1338.333333333  inf_usecol:gage-2
# inf_usecol:gage-2_time:1368.75         inf_usecol:gage-2
# inf_usecol:gage-2_time:1399.166666667  inf_usecol:gage-2
# inf_usecol:gage-2_time:1429.583333333  inf_usecol:gage-2
# inf_usecol:gage-2_time:1460.0          inf_usecol:gage-2
#
#                                                             matchcol
# inf_usecol:gage-1_time:0.0                inf_usecol:gage-1_time:0.0
# inf_usecol:gage-1_time:1003.75         inf_usecol:gage-1_time:1003.7
# inf_usecol:gage-1_time:1034.166666667  inf_usecol:gage-1_time:1034.1
# inf_usecol:gage-1_time:1064.583333333  inf_usecol:gage-1_time:1064.5
# inf_usecol:gage-1_time:1095.0          inf_usecol:gage-1_time:1095.0
# ...                                                              ...
# inf_usecol:gage-2_time:1338.333333333  inf_usecol:gage-2_time:1338.3
# inf_usecol:gage-2_time:1368.75         inf_usecol:gage-2_time:1368.7
# inf_usecol:gage-2_time:1399.166666667  inf_usecol:gage-2_time:1399.1
# inf_usecol:gage-2_time:1429.583333333  inf_usecol:gage-2_time:1429.5
# inf_usecol:gage-2_time:1460.0          inf_usecol:gage-2_time:1460.0
#
# [63 rows x 5 columns]

# %%
inf_df.drop('matchcol', axis=1, inplace=True)

# %%
inf_df
# Out:
#                                                                             obsnme  \
# inf_usecol:gage-1_time:0.0                              inf_usecol:gage-1_time:0.0
# inf_usecol:gage-1_time:1003.75                      inf_usecol:gage-1_time:1003.75
# inf_usecol:gage-1_time:1034.166666667        inf_usecol:gage-1_time:1034.166666667
# inf_usecol:gage-1_time:1064.583333333        inf_usecol:gage-1_time:1064.583333333
# inf_usecol:gage-1_time:1095.0                        inf_usecol:gage-1_time:1095.0
# ...                                                                            ...
# inf_usecol:gage-2_time:882.0833333333001  inf_usecol:gage-2_time:882.0833333333001
# inf_usecol:gage-2_time:91.25                          inf_usecol:gage-2_time:91.25
# inf_usecol:gage-2_time:912.5                          inf_usecol:gage-2_time:912.5
# inf_usecol:gage-2_time:942.9166666666999  inf_usecol:gage-2_time:942.9166666666999
# inf_usecol:gage-2_time:973.3333333333001  inf_usecol:gage-2_time:973.3333333333001
#
#                                                 obsval  weight  \
# inf_usecol:gage-1_time:0.0                 8556.474067     1.0
# inf_usecol:gage-1_time:1003.75             6134.064933     1.0
# inf_usecol:gage-1_time:1034.166666667     17319.757500     1.0
# inf_usecol:gage-1_time:1064.583333333     19286.405667     1.0
# inf_usecol:gage-1_time:1095.0             16807.024800     1.0
# ...                                                ...     ...
# inf_usecol:gage-2_time:882.0833333333001  32806.197990     0.0
# inf_usecol:gage-2_time:91.25              33154.933450     0.0
# inf_usecol:gage-2_time:912.5              32530.498210     0.0
# inf_usecol:gage-2_time:942.9166666666999  35218.572950     0.0
# inf_usecol:gage-2_time:973.3333333333001  36499.878810     0.0
#
#                                                      obgnme
# inf_usecol:gage-1_time:0.0                inf_usecol:gage-1
# inf_usecol:gage-1_time:1003.75            inf_usecol:gage-1
# inf_usecol:gage-1_time:1034.166666667     inf_usecol:gage-1
# inf_usecol:gage-1_time:1064.583333333     inf_usecol:gage-1
# inf_usecol:gage-1_time:1095.0             inf_usecol:gage-1
# ...                                                     ...
# inf_usecol:gage-2_time:882.0833333333001  inf_usecol:gage-2
# inf_usecol:gage-2_time:91.25              inf_usecol:gage-2
# inf_usecol:gage-2_time:912.5              inf_usecol:gage-2
# inf_usecol:gage-2_time:942.9166666666999  inf_usecol:gage-2
# inf_usecol:gage-2_time:973.3333333333001  inf_usecol:gage-2
#
# [98 rows x 4 columns]

# %%
sum(inf_df['weight'])
# Out:
# 63.0

# %% [markdown]
# ### 2.6 Inflow differences

# %% [markdown]
# ### 2.7 Head-Stage differences
#
# This is a customized measurement type
#
# Start by creating the synthetic dataset:

# %%
hds_comp = pd.read_csv(os.path.join(template_ws, 'head.obs.csv'),index_col=0)
hds_comp.head()
# Out:
#                   B9-2       B10-2       B12-1       B16-1        B2-1  \
# time
# 0.000000    136.357417  136.171989  141.672073  138.887187  138.683830
# 30.416667   136.380164  136.192273  141.687803  138.895642  138.693801
# 60.833333   136.257096  136.093482  141.612178  138.862508  138.654511
# 91.250000   136.195614  136.040609  141.565019  138.839727  138.627792
# 121.666667  136.417963  136.219815  141.702506  138.900679  138.699918
#
#                  B22-1         B27         B29       KB1-1       KB4-3  ...  \
# time                                                                    ...
# 0.000000    141.594246  141.849394  138.901786  137.643041  135.914168  ...
# 30.416667   141.609088  141.865356  138.913362  137.646867  135.922649  ...
# 60.833333   141.538782  141.787370  138.866656  137.631479  135.892420  ...
# 91.250000   141.494517  141.739204  138.835307  137.621462  135.874067  ...
# 121.666667  141.622439  141.880899  138.920876  137.649795  135.929335  ...
#
#               NI1609-3    NI1612-2    NI1701-1    NI1702-1    NI1704-2  \
# time
# 0.000000    137.946918  137.475572  137.734305  137.660615  135.925181
# 30.416667   137.953822  137.481993  137.740273  137.666753  135.936037
# 60.833333   137.921722  137.454039  137.716987  137.643609  135.896254
# 91.250000   137.903585  137.437602  137.702773  137.629293  135.873463
# 121.666667  137.961909  137.488519  137.745315  137.671608  135.945846
#
#               NI1705-2    NI1706-2    NI1707-1    NI1708-1    NI1711-1
# time
# 0.000000    136.050387  135.981682  135.897330  139.074642  139.553246
# 30.416667   136.060870  135.990418  135.906981  139.080679  139.559330
# 60.833333   136.023459  135.959705  135.873142  139.055335  139.532027
# 91.250000   136.001664  135.941456  135.853264  139.039877  139.516018
# 121.666667  136.069796  135.997458  135.914923  139.086183  139.565766
#
# [5 rows x 145 columns]

# %%
stg_comp = pd.read_csv(os.path.join(template_ws, 'sfr_stage.obs.csv'),index_col=0)
stg_comp.head()
# Out:
#             NI15-O1-STG  NI15-O44-STG  NI15-O46-STG  NI15-O47-STG  \
# time
# 0.000000     136.867571    136.873137    135.592200    135.349386
# 30.416667    136.868639    136.874285    135.593802    135.351231
# 60.833333    136.863942    136.869487    135.588722    135.345959
# 91.250000    136.861386    136.866862    135.585851    135.342946
# 121.666667   136.869915    136.875578    135.595100    135.352549
#
#             NI15-O48-STG
# time
# 0.000000      134.493341
# 30.416667     134.495954
# 60.833333     134.489886
# 91.250000     134.486358
# 121.666667    134.497427

# %%
columns = [
    'NI15-O1', 'NI15-O1-STG',
    'NI15-O44', 'NI15-O44-STG',
    'NI15-O46', 'NI15-O46-STG',
    'NI15-O47', 'NI15-O47-STG',
    'NI15-O48', 'NI15-O48-STG'
]

# %%
dh = pd.concat([hds_comp, stg_comp], axis=1)[columns]

# %%
for i, j in zip(columns[::2], columns[1::2]):
    dh[f'dh{i}'] = dh[i] - dh[j]

# %%
dh = dh[[f'dh{i}' for i in columns[::2]]]

# %%
dh.head()
# Out:
#             dhNI15-O1  dhNI15-O44  dhNI15-O46  dhNI15-O47  dhNI15-O48
# time
# 0.000000     0.208945    0.075404    0.403074    0.202253    0.176435
# 30.416667    0.210025    0.076171    0.405124    0.203319    0.178159
# 60.833333    0.205085    0.073089    0.396993    0.199137    0.170715
# 91.250000    0.202034    0.071007    0.391654    0.196444    0.166349
# 121.666667   0.211083    0.076702    0.406551    0.204126    0.179929

# %%
dh.to_csv(os.path.join(template_ws, 'dh_orbacken.obs.csv'))

# %%
dho_file = os.path.join(template_ws, 'dh_orbacken.obs.csv')

dho_df = pf.add_observations( #delta h örbäcken (head stage difference at 5 points)
    dho_file,
    insfile='dh_orbacken.csv.ins',
    index_cols='time',
    use_cols=list(dh.columns.values),
    prefix='dho'
)
# Out:
# 2021-12-20 22:32:04.959060 starting: adding observations from output file ..\hagfors_1_template\dh_orbacken.obs.csv
# 2021-12-20 22:32:04.960056 starting: adding observations from tabular output file '['..\\hagfors_1_template\\dh_orbacken.obs.csv']'
# 2021-12-20 22:32:04.960056 starting: reading list ..\hagfors_1_template\..\hagfors_1_template\dh_orbacken.obs.csv
# 2021-12-20 22:32:04.969050 finished: reading list ..\hagfors_1_template\..\hagfors_1_template\dh_orbacken.obs.csv took: 0:00:00.008994
# 2021-12-20 22:32:04.970048 starting: building insfile for tabular output file ..\hagfors_1_template\dh_orbacken.obs.csv
# 2021-12-20 22:32:04.978026 finished: building insfile for tabular output file ..\hagfors_1_template\dh_orbacken.obs.csv took: 0:00:00.007978
# 2021-12-20 22:32:04.979024 starting: adding observation from instruction file '..\hagfors_1_template\dh_orbacken.csv.ins'
# 2021-12-20 22:32:04.989999 finished: adding observation from instruction file '..\hagfors_1_template\dh_orbacken.csv.ins' took: 0:00:00.010975
# 2021-12-20 22:32:04.992988 finished: adding observations from tabular output file '['..\\hagfors_1_template\\dh_orbacken.obs.csv']' took: 0:00:00.032932

# %%
dho_df['weight'] = 0.0

# %%
dho_df.head()
# Out:
#                                                                             obsnme  \
# dho_usecol:dhni15-o1_time:0.0                        dho_usecol:dhni15-o1_time:0.0
# dho_usecol:dhni15-o1_time:1003.75                dho_usecol:dhni15-o1_time:1003.75
# dho_usecol:dhni15-o1_time:1034.166666667  dho_usecol:dhni15-o1_time:1034.166666667
# dho_usecol:dhni15-o1_time:1064.583333333  dho_usecol:dhni15-o1_time:1064.583333333
# dho_usecol:dhni15-o1_time:1095.0                  dho_usecol:dhni15-o1_time:1095.0
#
#                                             obsval  weight  \
# dho_usecol:dhni15-o1_time:0.0             0.208945     0.0
# dho_usecol:dhni15-o1_time:1003.75         0.213314     0.0
# dho_usecol:dhni15-o1_time:1034.166666667  0.213859     0.0
# dho_usecol:dhni15-o1_time:1064.583333333  0.211918     0.0
# dho_usecol:dhni15-o1_time:1095.0          0.203000     0.0
#
#                                                         obgnme
# dho_usecol:dhni15-o1_time:0.0             dho_usecol:dhni15-o1
# dho_usecol:dhni15-o1_time:1003.75         dho_usecol:dhni15-o1
# dho_usecol:dhni15-o1_time:1034.166666667  dho_usecol:dhni15-o1
# dho_usecol:dhni15-o1_time:1064.583333333  dho_usecol:dhni15-o1
# dho_usecol:dhni15-o1_time:1095.0          dho_usecol:dhni15-o1

# %% [markdown]
# ## End of notebook

# %% [markdown]
# ---

# %% [markdown]
# Setup directory structure:

# %%
model_root = os.path.join('..', 'temp_ml_param')

runmodel_ws = os.path.join(model_root, 'runmodel')
model_ws = os.path.join(runmodel_ws, 'model')
preproc_ws = os.path.join(runmodel_ws, 'preproc')
lumprem_ws = os.path.join(runmodel_ws, 'lumprem')

pest_ws = os.path.join(model_root, 'pest')
template_ws = os.path.join(pest_ws, 'template')
instruction_ws = os.path.join(pest_ws, 'instruction')

# %%
dir_lvl1 = [runmodel_ws, pest_ws]
dir_lvl2 = [model_ws, preproc_ws, lumprem_ws, template_ws, instruction_ws]

# %%
if os.path.exists(model_root):
    shutil.rmtree(model_root)

os.mkdir(model_root)

# %%
for pth in dir_lvl1:
    os.mkdir(pth)
for pth in dir_lvl2:
    os.mkdir(pth)

# %%
shutil.copytree(org_model_ws,model_ws, dirs_exist_ok=True)
os.listdir(model_ws)

# %% [markdown]
# Move all the LUMPREM template files to `template_ws` and SEGLIST files to `preproc_ws` directories:

# %%
def move_files(old_pth, new_pth, file):
    from_ = os.path.join(old_pth, file)
    to_ = os.path.join(new_pth, file)
    shutil.move(from_, to_)

# %%
lr_tpls = [i for i in os.listdir(model_ws) if '.tpl' in i]

# %%
for file in lr_tpls:
    move_files(model_ws, template_ws, file)

# %%
move_files(model_ws, preproc_ws, 'sfr_segfile.dat')
move_files(model_ws, preproc_ws, 'ghbpp.dat')

# %% [markdown]
# Move all the LUMPREM input files to `lumprem_ws`:

# %%
lr_prep_pth = os.path.join('..', 'temp_lr_prep')

# %%
os.listdir(lr_prep_pth)

# %%
for file in os.listdir(lr_prep_pth):
    shutil.copyfile(os.path.join(lr_prep_pth, file), os.path.join(lumprem_ws, file))

# %%
os.listdir(lumprem_ws)

# %% [markdown]
# START

# %%
ml_name = 'hagfors_1'

# %%
sim = flopy.mf6.MFSimulation.load(ml_name, 'mf6', os.path.join(bins_pth, 'mf6'), model_ws)

# %% [markdown]
# Set all data external so that PEST can adjust parameter values during history matching:

# %%
sim.set_all_data_external(True)

# %%
sim.write_simulation()

# %%
gwf = sim.get_model(ml_name)

# %%
fig = plt.figure(figsize=(10, 10), dpi=100)
ax = fig.add_subplot(1, 1, 1, aspect='equal')
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates
ax.set_title('Model grid', fontsize=18)

mapview = flopy.plot.PlotMapView(gwf, layer=0)
linecollection = mapview.plot_grid(lw=0.25)

plt.show()

# %% [markdown]
# ## Generate pilot points
# 3D-pilot points will be generated for the following areal properties:
# - SY & SS (perhaps SS could be skipped?)
# - Porosity and possibly diffusion/dispersion and any other parameter needed to represent transport
# - Kh and Kz
#
# In addition, pilot points will be generated along the following linear features:
# - Streambed hydraulic conductivity along Creek Örbäcken (SFR package)
# - GHB conductance

# %% [markdown]
# ### 3D pilot points
# Because we want to do a data-worth analysis, we should consider the total amount of pilot points to be employed to find a suitable compromise between adjustable parameters and model run-time.
#
# For this reason, we will create different sets of pilot points for each parameter type (in order to not use an exessive amount of pps).
#
# Sy, SS and possibly porosity (along with other parameters that govern transport) could be parameterized using a coarser pp-spacing, so let's start with that.

# %% [markdown]
# However, before we start, let's import the observation locations, so that we can see how the pilot points will be located in relation to them:

# %%
sfr_obs = pd.read_excel(os.path.join(observations_pth, 'obs_flow_and_stage.xlsx'))
head_obs = pd.read_excel(os.path.join(observations_pth, 'obs_head_per_layer.xlsx')).drop_duplicates(subset=['POINT_X', 'POINT_Y'])
head_obs['TYPE'] = 'HEAD'

# %%
obs_points = pd.concat([head_obs, sfr_obs])
display(obs_points)

# %% [markdown]
# #### Coarse 3D pilot points
# Let's create the coarse pilot point distribution:

# %%
ml_boundary = shapefile.Reader(os.path.join(shapefile_pth, 'model_boundary.shp')) # Model boundary shapefile
mlb_shape = np.array(np.rint(ml_boundary.shapeRecords()[0].shape.points)) # Model boundary array

# %% [markdown]
# Instantiate a shapely polygon of the model boundary:

# %%
mlb_shapely = Polygon(mlb_shape)

# %% [markdown]
# Create prepared polygon of the model boundary:

# %%
#mlb_shapely_prep = prep(mlb_shapely.buffer(50)) buffer cause an issue because the grid can't be sampled outside the model boundary
mlb_shapely_prep = prep(mlb_shapely)

# %% [markdown]
# Construct a rectangular mesh of points:

# %%
xmin, xmax, ymin, ymax = 426900, 427700, 6654650, 6655350 # These are the same coordinates used to construct the base-grid
resolution = 30 # Equal space (in meters) between pilot points
basepoints = []
for lat in np.arange(xmin, xmax, resolution):
    for lon in np.arange(ymin, ymax, resolution):
        basepoints.append(Point((round(lat,4), round(lon,4))))

# %% [markdown]
# Use the shapely `contains` (point-in-polygon method) to select points inside the model boundary (increase the number of pps once workflow is confirmed working):

# %%
basepip = [] # Basepoints in polygon
for point in basepoints:
    if mlb_shapely_prep.contains(point):
        basepip.append(point)
print(f'Number of points per layer: {len(basepip)}') # We need to extend it into three dimensions

# %% [markdown]
# Plot the position of the pilot points on top of the model grid:

# %%
fig = plt.figure(figsize=(10, 10), dpi=100)
ax = fig.add_subplot(1, 1, 1, aspect='equal')
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates
ax.set_title('Coarse pilot point locations', fontsize=18)

mapview = flopy.plot.PlotMapView(gwf, layer=0)
linecollection = mapview.plot_grid(lw=0.25)

x = np.array([i.coords[0] for i in basepip])[:,0]
y = np.array([i.coords[0] for i in basepip])[:,1]
plt.scatter(x, y, s=5, c='black', alpha=0.5, label='PILOT POINT')

for category in obs_points['TYPE'].unique():
    x = obs_points.loc[obs_points['TYPE'] == category]['POINT_X']
    y = obs_points.loc[obs_points['TYPE'] == category]['POINT_Y']
    ax.scatter(x, y, s=20, alpha=0.6, label=category)
    
plt.legend()
plt.show()

# %% [markdown]
# These points now need to be assigned a z-value, since we are going to use 3D-pilot points. To do this, we will need to intersect the model grid and retrieve the z-values of each layer, so that a copy of these pps can be positioned in each of the three layers:

# %%
ix = GridIntersect(gwf.modelgrid)

# %%
pp_intersect = {
    'cellids': [],
    'vertices': [],
    'ixshapes': [],
}
for point in basepip:
    pp_intersect['cellids'].append(ix.intersect(point).cellids[0])
    pp_intersect['vertices'].append(ix.intersect(point).vertices[0])
    pp_intersect['ixshapes'].append(ix.intersect(point).ixshapes[0])

# %%
pp_intersect = pd.DataFrame(pp_intersect)
display(pp_intersect)

# %% [markdown]
# We can see that the order is respected:

# %%
[i.coords[0] for i in basepip][:5]

# %% [markdown]
# Let's use the cellids to sample pilot point elevations (**this takes about 2 minutes on my laptop for 295 cells** and could/should probably be speed up somehow - considering it has to be done for top, botm1, botm2 and botm3):

# %%
def get_grid_elevation(elevation_array, index_array):
    '''
    returns list of elevations
    '''
    
    elevations = list(elevation_array)
    indices = list(index_array)
    
    return [elevation_array[i] for i in index_array]

# %%
pp_intersect['top'] = get_grid_elevation(elevation_array = gwf.modelgrid.top, index_array=pp_intersect['cellids'])

# %%
pp_intersect['botm_1'] = get_grid_elevation(gwf.modelgrid.botm[0], pp_intersect['cellids'])
pp_intersect['botm_2'] = get_grid_elevation(gwf.modelgrid.botm[1], pp_intersect['cellids'])
pp_intersect['botm_3'] = get_grid_elevation(gwf.modelgrid.botm[2], pp_intersect['cellids'])

# %%
pp_intersect

# %% [markdown]
# Create pps in-between the layer boundaries (i.e. vertically centered in the cells):

# %%
pp_intersect['pps_l1'] = (pp_intersect['top'] + pp_intersect['botm_1']) / 2

# %%
pp_intersect['pps_l2'] = (pp_intersect['botm_1'] + pp_intersect['botm_2']) / 2

# %%
pp_intersect['pps_l3'] = (pp_intersect['botm_2'] + pp_intersect['botm_3']) / 2

# %%
display(pp_intersect)

# %% [markdown]
# Add x, y and clean up df:

# %%
pp_intersect['x'] = np.array([i.coords[0] for i in basepip])[:,0]
pp_intersect['y'] = np.array([i.coords[0] for i in basepip])[:,1]

# %%
pp_intersect = pp_intersect[['x', 'y', 'pps_l1', 'pps_l2', 'pps_l3']]

# %%
pp_intersect

# %% [markdown]
# Visualize

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random

fig = pyplot.figure(figsize=(6,6))
ax = Axes3D(fig)
ax.set_box_aspect([2,2,1])

x, y = pp_intersect.x.values, pp_intersect.y.values

ax.scatter(x, y, pp_intersect.pps_l1.values)
ax.scatter(x, y, pp_intersect.pps_l2.values)
ax.scatter(x, y, pp_intersect.pps_l3.values)
plt.title('pps in 3d-space')
pyplot.show()

# %% [markdown]
# Convert the dataframe into a 3d pilot point file format:

# %%
pp_coarse3d = pd.melt(pp_intersect, id_vars=['x', 'y'], value_vars=['pps_l1', 'pps_l2', 'pps_l3'])

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random

fig = pyplot.figure(figsize=(6,6))
ax = Axes3D(fig)
ax.set_box_aspect([2,2,1])

x, y = pp_coarse3d.x.values, pp_coarse3d.y.values

ax.scatter(x, y, pp_coarse3d.value.values)
plt.title('pps in 3d-space')
pyplot.show()

# %% [markdown]
# Insert columns:

# %%
pp_coarse3d['name'] = [f'ppc{i:04d}' for i in pp_coarse3d.index.values] # ppc = pilot point coarse.

# %%
pp_coarse3d[['zone','val']] = 1, 1
pp_coarse3d['z'] = pp_coarse3d['value']

# %%
pp_coarse3d['layer'] = [int(i[-1]) for i in pp_coarse3d['variable']]

# %%
pp_coarse3d = pp_coarse3d[['name', 'x', 'y', 'z', 'zone', 'val', 'layer']]

# %%
display(pp_coarse3d)

# %%
from lumpyrem import run
#MKPPSTAT
# mkppstat requires no headers in ppoint file ...sigh...
pp_coarse3d.to_csv(os.path.join(preproc_ws, 'mkppoints3d_coarse.dat'),
                       header=None, index=False, sep='\t')

# %%
# Input for MKPPSTAT
# A (a)-factor of 1.5 is often reasonable. from tutorial 
npoints_h, npoints_v = 10, 10 # np-horizontal, np-vertical
a_h, a_v = 1.2, 1.2 # a-horizontal, a-vertical
# run MKPPSTAT
run.run_process(
    'mkppstat3d',
    path=preproc_ws,
    commands=['mkppoints3d_coarse.dat', npoints_h, a_h, npoints_v, a_v, 'ppstat3d_coarse.dat']
)

# %%
# run PPCOV3D_SVA - pilot point covariance 3d - spatially varying anisotropy
run.run_process(
    'ppcov3d_sva',
    path=preproc_ws,
    commands=['ppstat3d_coarse.dat', 'y', 1, 'x',  'cov3d_coarse.mat', '']
)

# %%
# Load cov mat file with Pyemu for further processing
import pyemu
covmat_coarse = pyemu.Cov.from_ascii(os.path.join(preproc_ws, "cov3d_coarse.mat"))

# This covaraince matrix can now be used as the base for all pilot point parameters. 
# Note that in this case the variance is 1, so it is easy to scale to a parameters prior varaince
# Depending on how you setup the scrpt, variance can be assigned at various stages (i.e. when running PPCOV_SVA, or by manipulating the matrix later)
# Note that parameter names (headers and row names) come from the parameter name sin the ppoint file. These can have a prefix added by PPCOV_SVA, or changed in the dataframe. The latter is more versatile.
covmat_coarse.to_dataframe().head()

# %% [markdown]
# Is this matrix only used during regularization?

# %%
plt.figure(figsize=(8, 8), dpi=100)
plt.imshow(covmat_coarse.as_2d)

# %%
pp_coarse3d[['kh', 'kv', 'sy', 'ss']] = 86.4, 8.64, 0.2, 0.00001

# %%
pp_coarse3d

# %%
pp_coarse3d.to_csv(os.path.join(preproc_ws, 'pp3d_coarse.dat'), index=False, sep='\t')

# %% [markdown]
# ## Setup parameterization for 3D elements (K, storage, porosity)

# %%
# Write generic template
with open(os.path.join(preproc_ws, 'gen_mf_array.tpl'), 'a') as f:
    f.write('$#p prop_mf.write_in_sequence(format="(1x,1pg18.11)")')

# %%
def write_script(filename, lines):

    with open(filename, 'a') as f:
        for line in lines:
            f.write(line)
            f.write('\n')

# %% [markdown]
# Calculate kriging factors (porosity not included yet):

# %%
write_script(os.path.join(preproc_ws, 'plproc.dat'), [
f'''
### Read model grid ###
cl_mf = read_mf6_grid_specs(file=../model/{ml_name}.disv.grb,                  &
                            dimensions=2,                             &
                            slist_layer_idomain=idomain1;  layer=1,   &
                            slist_layer_idomain=idomain2;  layer=2,   &
                            slist_layer_idomain=idomain3;  layer=3)



### Read 3D pilot-points file ###
cl_pp = read_list_file(file=pp3d_coarse.dat,               &
                       id_type=character,                  &
                       dimensions=2,                       &
                       skiplines=1,                        &
                       slist=zone; col=5,                  &
                       slist=lyr; col=7,                   &
                       plist=kh_pp; col=8,                 &
                       plist=kv_pp; col=9,                 &
                       plist=sy_pp; col=10,                &
                       plist=ss_pp; col=11)


### Calculate kriging factors for each layer ###
calc_kriging_factors_auto_2d(target_clist=cl_mf, source_clist=cl_pp;select=(lyr==1), file=factors_pp_lyr1.dat)

calc_kriging_factors_auto_2d(target_clist=cl_mf, source_clist=cl_pp;select=(lyr==2), file=factors_pp_lyr2.dat)

calc_kriging_factors_auto_2d(target_clist=cl_mf, source_clist=cl_pp;select=(lyr==3), file=factors_pp_lyr3.dat)

### Write to template file ###
prop_mf=new_plist(reference_clist=cl_mf,value=1.0)

###   Horizontal K   ###
### Write kh layer 1 ###
prop_mf=86.4
prop_mf=kh_pp.krige_using_file(file='factors_pp_lyr1.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.npf_k_layer1.txt)

### Write kh layer 2 ###
prop_mf=86.4
prop_mf=kh_pp.krige_using_file(file='factors_pp_lyr2.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.npf_k_layer2.txt)

### Write kh layer 3 ###
prop_mf=86.4
prop_mf=kh_pp.krige_using_file(file='factors_pp_lyr3.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.npf_k_layer3.txt)


###    Vertical K    ###
### Write kv layer 1 ###
prop_mf=8.64
prop_mf=kv_pp.krige_using_file(file='factors_pp_lyr1.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.npf_k33_layer1.txt)

### Write kv layer 2 ###
prop_mf=8.64
prop_mf=kv_pp.krige_using_file(file='factors_pp_lyr2.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.npf_k33_layer2.txt)

### Write kv layer 3 ###
prop_mf=8.64
prop_mf=kv_pp.krige_using_file(file='factors_pp_lyr3.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.npf_k33_layer3.txt)



###      STORAGE     ###
###        sy        ###
### Write sy layer 1 ###
prop_mf=0.2
prop_mf=sy_pp.krige_using_file(file='factors_pp_lyr1.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.sto_sy_layer1.txt)


###        ss        ###
### Write ss layer 2 ###
prop_mf=0.000001
prop_mf=ss_pp.krige_using_file(file='factors_pp_lyr2.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.sto_ss_layer2.txt)

### Write ss layer 3 ###
prop_mf=0.000001
prop_mf=ss_pp.krige_using_file(file='factors_pp_lyr3.dat',transform='log')
write_model_input_file(template_file=gen_mf_array.tpl, &
    model_input_file=../model/{ml_name}.sto_ss_layer3.txt)
'''
])

# %%
# run PLPROC
run.run_process(
    'plproc',
    path=preproc_ws,
    commands=['plproc.dat']
)

# %% [markdown]
# Comment out kriging factors:

# %%
def replace_in_file(path, input_file, original_str, replacement_str):
    # Read in the file
    with open(os.path.join(path, input_file), 'r') as file :
        filedata = file.read()

    # Replace the target string
    filedata = filedata.replace(original_str, replacement_str)

    # Write the file out again
    with open(os.path.join(path, input_file), 'w') as file:
        file.write(filedata)

# %%
# Comment out kriging factors
replace_in_file(preproc_ws, 'plproc.dat', 'calc_kriging_factors', '#calc_kriging_factors')

# %%
# run PLPROC
run.run_process(
    'plproc',
    path=preproc_ws,
    commands=['plproc.dat']
)

# %% [markdown]
# ### Write template file

# %%
import copy
pp_coarse3d_tpl = copy.deepcopy(pp_coarse3d)

# %%
pp_coarse3d_tpl

# %%
pp_coarse3d_tpl['kh'] = [f'$kh{r.layer}pp{i + 1:03d}$' for i,r in pp_coarse3d_tpl.iterrows()]
pp_coarse3d_tpl['kv'] = [f'$kv{r.layer}pp{i + 1:03d}$' for i,r in pp_coarse3d_tpl.iterrows()] 
pp_coarse3d_tpl['sy'] = [f'$sy{r.layer}pp{i + 1:03d}$' for i,r in pp_coarse3d_tpl.iterrows()]
pp_coarse3d_tpl['ss'] = [f'$ss{r.layer}pp{i + 1:03d}$' for i,r in pp_coarse3d_tpl.iterrows()]

# %%
pp_coarse3d_tpl

# %%
pp_coarse3d_tpl.to_csv(os.path.join(template_ws, 'pp3d_coarse.tpl'), index=False, sep='\t')

# %%
def line_prepender(filename, line):
    with open(filename, 'r+') as f:
        content = f.read()
        f.seek(0, 0)
        f.write(line.rstrip('\r\n') + '\n' + content)

# %%
line_prepender(os.path.join(template_ws, 'pp3d_coarse.tpl'), 'ptf $')

# %% [markdown]
# ## Setup parameterization for SFR
# Setup pilot points for linear boundary conditions General Head Boundaries (GHBs) and Creek Örbäcken (SFR), starting with SFR:

# %%
segfile = pd.read_csv(os.path.join(preproc_ws, 'sfr_segfile.dat'), sep='\t', names=['x', 'y', 'seg'])
display(segfile)

# %% [markdown]
# Fix the segments. This should probably be done in a better way and perhaps changed after the first round of history matching to get a better representation of stream reaches. This solution is just to make things work.

# %%
def largest_divisor(n):
    a = 1
    for i in range(2, n):
        if n % i == 0:
            a = i
    return a

# %%
nseg = largest_divisor(len(segfile))
#nseg = largest_divisor(nseg) # divide again to reduce the amount of pps from 135 to 45 (perhaps a stupid move)
print(nseg)

# %%
rows_per_seg = int(len(segfile) / nseg)
print(rows_per_seg)

# %%
for i in range(nseg):
    segfile.loc[(i * rows_per_seg):((i + 1) * rows_per_seg), ('seg')] = f's{i + 1}'

# %%
segfile

# %% [markdown]
# Rewrite seglist:

# %%
segfile.to_csv(
    os.path.join(preproc_ws, 'sfr_segfile.dat'),
    header=None,
    index=False,
    sep='\t',
    float_format='%.3f'
)

# %%
write_script(os.path.join(preproc_ws, 'plproc_seglist_temp.dat'), [
f'''
### Read model grid ###

cl_mf = read_mf6_grid_specs(  &
    file=../model/{ml_name}.disv.grb,  &
    dimensions=3,             & # Note 3D in this case
    slist_layernum = layer,   &
    slist_idomain = idomain   &
    )


### Read Creek Örbäcken SFR seglist file ###
sl_sfr = read_segfile(file="sfr_segfile.dat", protocol=table)

### Create clist with sl_sfr as its base ###
cl_sfr_pp = create_clist_from_seglist(seglist=sl_sfr, linkage_type=endpoints, dist_thresh=5.0)

### Write reports (pps will be constructed based on theses reports) ###
cl_sfr_pp.report_dependent_lists(file='report_sfr_seglist.dat')
'''
])

# %%
# run PLPROC
run.run_process(
    'plproc',
    path=preproc_ws,
    commands=['plproc_seglist_temp.dat']
)

# %%
sfr_pps = pd.read_csv(os.path.join(preproc_ws, 'report_sfr_seglist.dat'), skiprows=[0, 1, 2])

# %%
sfr_pps

# %%
sfr_pps.columns = sfr_pps.columns.str.replace(r'\ (?= *?\ )', '')

# %%
sfr_pps.iloc[:,0] = sfr_pps.iloc[:,0].str.replace(r'\ (?= *?\ )', '')

# %%
sfr_pps[['Index', 'Int_ID', 'X-coord', 'Y-coord']] = sfr_pps['Index Int_ID X-coord Y-coord'].str.split(' ', 3, expand=True)

# %%
sfr_pps['cond'] = 86.4

# %%
sfr_pps.rename(columns={'Int_ID': 'ppid', 'X-coord': 'x', 'Y-coord': 'y'}, inplace=True)

# %%
sfr_pps = sfr_pps[['ppid', 'x', 'y', 'cond']]

# %%
display(sfr_pps)

# %%
sfr_pps.to_csv(
    os.path.join(preproc_ws, 'sfrpp.dat'),
    index=False,
    sep='\t',
)

# %% [markdown]
# #### Parameterize the INFLOW parameter of reach 1

# %%
sfr_pkgdatafile = f'{ml_name}.sfr_packagedata.txt'
shutil.copyfile(os.path.join(model_ws, sfr_pkgdatafile), os.path.join(preproc_ws, sfr_pkgdatafile))

# %%
os.rename(
    os.path.join(preproc_ws, f'{ml_name}.sfr_packagedata.txt'),
    os.path.join(preproc_ws, f'{ml_name}.sfr_packagedata.tpl')
)

# %%
sfr_perdatafile = f'{ml_name}.sfr_perioddata_1.txt'
shutil.copyfile(os.path.join(model_ws, sfr_perdatafile), os.path.join(template_ws, sfr_perdatafile))

# %%
os.rename(
    os.path.join(template_ws, f'{ml_name}.sfr_perioddata_1.txt'),
    os.path.join(template_ws, f'{ml_name}.sfr_perioddata_1.tpl')
)

# %%
line_prepender(os.path.join(template_ws, f'{ml_name}.sfr_perioddata_1.tpl'), 'ptf $')

# %%
with open(os.path.join(template_ws, f'{ml_name}.sfr_perioddata_1.tpl'), 'r') as file:
    sfr_perdata = file.readlines() #pestfile partial parameters

# %%
temp_row = sfr_perdata[2].split()
display(temp_row)

# %%
temp_row[-1] = '$sfr_inflow1$\n'
display(temp_row)

# %%
new_row = ' '.join(temp_row)
display(new_row)

# %%
sfr_perdata[2] = new_row

# %%
with open(os.path.join(template_ws, f'{ml_name}.sfr_perioddata_1.tpl'), 'w') as file:
    for line in sfr_perdata:
        file.write(line)

# %% [markdown]
# #### Write script

# %%
write_script(os.path.join(preproc_ws, 'plproc_sfr.dat'), [
f'''
### Read model grid ###

cl_mf = read_mf6_grid_specs(  &
    file=../model/{ml_name}.disv.grb,  &
    dimensions=3,             & # Note 3D in this case
    slist_layernum = layer,   &
    slist_idomain = idomain   &
    )


### Read Creek Örbäcken SFR seglist file ###
sl_sfr = read_segfile(file="sfr_segfile.dat", protocol=table)

### Create clist with sl_sfr as its base ###
cl_sfr_pp = create_clist_from_seglist(seglist=sl_sfr, linkage_type=endpoints, dist_thresh=5.0)

### Instruct PLPROC to read the *_cond.dat list file to obtain conductance values at  ###
### pilot points by inserting the following function into the PLPROC script.          ###
read_list_file(reference_clist='cl_sfr_pp', file='sfrpp.dat', skiprows=1, plist='pp_sfr_cond';column=4)

### Instruct PLPROC to build an SLIST of model drain cells to which interpolation must take place ###
sfr_cells = cl_mf.find_cells_in_lists(file=../model/{ml_name}.sfr_packagedata.txt, model_type=mf6_disv, &
    list_col_start=2, keytext_start='top_of_file', keytext_end='end_of_file')

### Calculate interpolation factors to these model cells through linear interpolation ###
calc_linear_interp_factors(source_clist=cl_sfr_pp, target_clist=cl_mf;select=(sfr_cells.ne.0), file="factors_sfr_cells.dat", search_radius=50)

### Write ###
sfr_cond=new_plist(reference_clist=cl_mf,value=0.0)

sfr_cond=pp_sfr_cond.interp_using_file(file=factors_sfr_cells.dat, transform=log)

replace_cells_in_lists(                                 &
    old_file={ml_name}.sfr_packagedata.tpl,             &
    new_file=../model/{ml_name}.sfr_packagedata.txt,    &
    model_type=mf6_disv,                                &
    list_col_start=2,                                   &
    keytext_start='top_of_file',                        &
    keytext_end='bottom_of_file',                       &
    plist=sfr_cond;column=9;action='replace'            &
    )

# -- This is for our own interest.
cl_mf.report_dependent_lists(file='report-sfr.dat')

'''
])

# %%
# run PLPROC
run.run_process(
    'plproc',
    path=preproc_ws,
    commands=['plproc_sfr.dat']
)

# %%
# Comment out kriging factors
replace_in_file(preproc_ws, 'plproc_sfr.dat', 'calc_linear_interp', '#calc_linear_interp')

# %% [markdown]
# Construct template file:

# %%
sfr_pps_tpl = copy.deepcopy(sfr_pps)

# %%
sfr_pps_tpl['cond'] = ['$sfrpp{:03d}$'.format(i) for i in range(1, len(sfr_pps_tpl) + 1)]

# %%
sfr_pps_tpl.to_csv(os.path.join(template_ws, 'sfrpp.tpl'), index=False, sep='\t')

# %%
line_prepender(os.path.join(template_ws, 'sfrpp.tpl'), 'ptf $')

# %% [markdown]
# #### Setup SFR covariance matrix

# %%
sfr_pps['zone'] = 1

# %%
sfr_pps = sfr_pps[['ppid', 'x', 'y', 'zone', 'cond']]

# %%
sfr_pps.to_csv( # Essentially a copy of sfrpp.dat but without column headers
    os.path.join(preproc_ws, 'mksfrpp.dat'),
    index=False,
    header=False,
    sep='\t',
)

# %%
# run MKPPSTAT
run.run_process(
    'mkppstat',
    path=preproc_ws,
    commands=['mksfrpp.dat', '10', '1.5', 'sfrppstat.dat']
)

# %%
# run PPCOV_SVA - pilot point covariance - spatially varying anisotropy
run.run_process(
    'ppcov_sva',
    path=preproc_ws,
    commands=['sfrppstat.dat', 'y', 0, 'x',  'cov_sfr.mat', '']
)

# %%
covmat_sfr = pyemu.Cov.from_ascii(os.path.join(preproc_ws, "cov_sfr.mat"))
plt.figure(figsize=(8, 8), dpi=100)
plt.imshow(covmat_sfr.as_2d)

# %% [markdown]
# #### Visualize SFR pps

# %%
fig = plt.figure(figsize=(10, 10), dpi=100)
ax = fig.add_subplot(1, 1, 1, aspect='equal')
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates
ax.set_title('SFR pilot point locations', fontsize=18)

mapview = flopy.plot.PlotMapView(gwf, layer=0)
linecollection = mapview.plot_grid(lw=0.25)

plt.scatter([float(i) for i in sfr_pps.x.values], [float(i) for i in sfr_pps.y.values], label='SFR PP')

plt.legend()
plt.show()

# %% [markdown]
# ### GHB using pilot points

# %% [markdown]
# Copy the file and make an "template" of an `old_file` (is this really a template in a PEST context?)

# %%
ghb_file = f'{ml_name}.ghb_stress_period_data_1.txt'
shutil.copyfile(os.path.join(model_ws, ghb_file), os.path.join(preproc_ws, ghb_file))

# %%
os.rename(
    os.path.join(preproc_ws, f'{ml_name}.ghb_stress_period_data_1.txt'),
    os.path.join(preproc_ws, f'{ml_name}.ghb_stress_period_data_1.tpl')
)

# %%
write_script(os.path.join(preproc_ws, 'plproc_ghb.dat'), [
f'''
# -- We read the MODFLOW 6 binary grid file. We read it as a 2D file.

cl_mf = read_mf6_grid_specs(file=../model/{ml_name}.disv.grb, &
                              dimensions=3,             &
                              slist_layernum = layer,   &
                              slist_idomain  = idomain)

# -- We now build an SLIST of drain cells to which we want interpolation to take place.

ghb_red_cells = cl_mf.find_cells_in_lists(file=../model/{ml_name}.ghb_stress_period_data_1.txt, model_type=mf6_disv, &
    list_col_start=1, keytext_start='top_of_file', keytext_end='2387  ghb_orange')
    
ghb_orange_cells = cl_mf.find_cells_in_lists(file=../model/{ml_name}.ghb_stress_period_data_1.txt, model_type=mf6_disv, &
    list_col_start=1, keytext_start='2387  ghb_red', keytext_end='2792  ghb_yellow')

ghb_yellow_cells = cl_mf.find_cells_in_lists(file=../model/{ml_name}.ghb_stress_period_data_1.txt, model_type=mf6_disv, &
    list_col_start=1, keytext_start='2800  ghb_orange', keytext_end='2802  ghb_limegreen')

ghb_limegreen_cells = cl_mf.find_cells_in_lists(file=../model/{ml_name}.ghb_stress_period_data_1.txt, model_type=mf6_disv, &
    list_col_start=1, keytext_start='3090  ghb_yellow', keytext_end='1  ghb_royalblue')

ghb_royalblue_cells = cl_mf.find_cells_in_lists(file=../model/{ml_name}.ghb_stress_period_data_1.txt, model_type=mf6_disv, &
    list_col_start=1, keytext_start='3057  ghb_limegreen', keytext_end='1  ghb_blueviolet')

ghb_blueviolet_cells = cl_mf.find_cells_in_lists(file=../model/{ml_name}.ghb_stress_period_data_1.txt, model_type=mf6_disv, &
    list_col_start=1, keytext_start='2802  ghb_royalblue', keytext_end='316  ghb_magenta')

ghb_magenta_cells = cl_mf.find_cells_in_lists(file=../model/{ml_name}.ghb_stress_period_data_1.txt, model_type=mf6_disv, &
    list_col_start=1, keytext_start='316  ghb_blueviolet', keytext_end='end_of_file')

# -- We next read the pilot points file and pilot point locations and values.

cl_pp = read_list_file(file='ghbpp.dat',                                          &
                       id_type='character',                                       &
                       dimensions=2,                                              &
                       skiprows=1,                                                &
                       plist='ghbcond_pp';column=4)

# -- Initialize the drain conductivity PLIST
ghbcond_mf=new_plist(reference_clist=cl_mf,value=0.0)


# -- We now interpolate from pilot points to the drain conductances.
#    We use inverse power of distance; but any interpolation method could be used.

ghbcond_mf(select=((ghb_red_cells.ne.0)&&(layer.eq.1)))=ghbcond_pp.ivd_interpolate_2d( &
                                        transform='log',                          &
                                        inv_power=2.0,                            &
                                        min_points=2,                             &
                                        max_points=20,                            &
                                        search_radius=1.0e20) # Perhaps too large?

ghbcond_mf(select=((ghb_orange_cells.ne.0)&&(layer.eq.1)))=ghbcond_pp.ivd_interpolate_2d( &
                                        transform='log',                          &
                                        inv_power=2.0,                            &
                                        min_points=2,                             &
                                        max_points=20,                            &
                                        search_radius=1.0e20)

ghbcond_mf(select=((ghb_yellow_cells.ne.0)&&(layer.eq.1)))=ghbcond_pp.ivd_interpolate_2d( &
                                        transform='log',                          &
                                        inv_power=2.0,                            &
                                        min_points=2,                             &
                                        max_points=20,                            &
                                        search_radius=1.0e20)

ghbcond_mf(select=((ghb_limegreen_cells.ne.0)&&(layer.eq.1)))=ghbcond_pp.ivd_interpolate_2d( &
                                        transform='log',                          &
                                        inv_power=2.0,                            &
                                        min_points=2,                             &
                                        max_points=20,                            &
                                        search_radius=1.0e20)

ghbcond_mf(select=((ghb_royalblue_cells.ne.0)&&(layer.eq.1)))=ghbcond_pp.ivd_interpolate_2d( &
                                        transform='log',                          &
                                        inv_power=2.0,                            &
                                        min_points=2,                             &
                                        max_points=20,                            &
                                        search_radius=1.0e20)

ghbcond_mf(select=((ghb_blueviolet_cells.ne.0)&&(layer.eq.1)))=ghbcond_pp.ivd_interpolate_2d( &
                                        transform='log',                          &
                                        inv_power=2.0,                            &
                                        min_points=2,                             &
                                        max_points=20,                            &
                                        search_radius=1.0e20)

ghbcond_mf(select=((ghb_magenta_cells.ne.0)&&(layer.eq.1)))=ghbcond_pp.ivd_interpolate_2d( &
                                        transform='log',                          &
                                        inv_power=2.0,                            &
                                        min_points=2,                             &
                                        max_points=20,                            &
                                        search_radius=1.0e20)

# -- A new model input file is written.

replace_cells_in_lists(old_file={ml_name}.ghb_stress_period_data_1.tpl,               &
                       new_file=../model/{ml_name}.ghb_stress_period_data_1.txt,      &
                       model_type=mf6_disv,                                       &
                       list_col_start=1,                                          &
                       keytext_start='top_of_file',                               &
                       keytext_end='bottom_of_file',                              &
                       plist=ghbcond_mf;column=4;action='replace')

# -- This is for our own interest.
#cl_mf6.report_dependent_lists(file='report-ghb.dat')
'''
])

# %%
# run PLPROC
run.run_process(
    'plproc',
    path=preproc_ws,
    commands=['plproc_ghb.dat']
)

# %% [markdown]
# #### GHB covmat

# %%
ghbpp_df = pd.read_csv(os.path.join(preproc_ws, 'ghbpp.dat'), sep='\t')

# %%
ghbpp_df['zone'] = 1

# %%
ghbpp_df = ghbpp_df[['ppid','x', 'y', 'zone', 'cond', 'bnames']]

# %%
# Create one pp derivative of each ghb boundname
for bname in ghbpp_df.bnames.unique():
    ghbpp_df.loc[ghbpp_df['bnames'] == bname].to_csv(
        os.path.join(preproc_ws, f'mkghb{bname}pp.dat'),
        index=False,
        header=False,
        sep='\t',
    )

# %%
for file in os.listdir(preproc_ws):
    if 'mkghb' in file:
        run.run_process(
            'mkppstat',
            path=preproc_ws,
            commands=[file, '10', '1.5', f'{file[2:-4]}_stat.dat']
        )

# %%
for file in os.listdir(preproc_ws):
    if 'ghb' in file and '_stat.dat' in file:
        filename = f'cov_{file[:6]}.mat'
        run.run_process(
            'ppcov_sva',
            path=preproc_ws,
            commands=[file, 'y', 1, 'x',  filename, '']
        )

# %% [markdown]
# #### Visualize GHB pps

# %%
fig = plt.figure(figsize=(10, 10), dpi=100)
ax = fig.add_subplot(1, 1, 1, aspect='equal')
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates
ax.set_title('GHB pilot point locations', fontsize=18)

mapview = flopy.plot.PlotMapView(gwf, layer=0)
linecollection = mapview.plot_grid(lw=0.25)

for bname in ghbpp_df['bnames'].unique():
    df = ghbpp_df.loc[ghbpp_df['bnames'] == bname]
    x = [float(i) for i in df.x.values]
    y = [float(i) for i in df.y.values]
    
    plt.scatter(x, y, color=bname, label=f'ghb_{bname}')

plt.legend()
plt.show()

# %% [markdown]
# ## Parameterize LUMPREM models

# %% [markdown]
# Parameters to be adjusted through history-matching are:
#
#
# | parameter | default | initial | upper bound | lower bound |
# | --------- |--------:|--------:|-------------| ------------|
# | maxvol    | 0.5     | 0.2     | 1           | 0.01        |
# | rdelay    | 5       | 5       | 10          | 1           |
# | mdelay    | 1       | 1       | 5           | 0           |
# | Ks        | 0.1     | 86.4    | 864.0       | 0.000864    |
# | m         | 0.5     | 1.0     | 2.0         | 0.01        |
# | l         | 0.5     | 0.5     | 1.0         | 0.0         |
# | mflowmax  | 0.1     | 0.1     | 0.2         | 0.01        |
# | f         | 0.5     | 0.5     | 0.9         | 0.01        |
# | γ         | 1.0     | 1.0     | 10.0        | 0.01        |
#
# - *maxvol* The volume of the soil moisture store.
# - *rdelay* Delay, in days, between water draining from the soil moisture store.
# - *mdelay* Delay, in days, between water leaving the soil moisture store.
# - *Ks* Hydraulic conductivity (meters per day). Initial: 86.4 (0.001 m/s)
# - *m* A parameter determining the shape of the drainage rate vs. stored water relationship.
# - *l* A pore-connectivity parameter (estimated by Mualem, 1976, to be about 0.5 for many soils).
# - *mflowmax* Maximum macropore recharge allowed per day.
# - *f* Crop factor.
# - *γ* A parameter determining the shape of the evaporation rate vs. stored water relationship.

# %%
def parameterize_lr_model(lr_template_file, lr_ml_name):
    # Read in the file
    with open(os.path.join(template_ws, lr_template_file), 'r') as file:
        lines = file.readlines()

    # Replace the target string
    lines[2] = f'$maxvol_{lr_ml_name}$  0 \n' #earth properties maxvolume & irrigvolfrac
    lines[3] = f'$rdelay_{lr_ml_name}$  $mdelay_{lr_ml_name}$ \n' #earth properties delay factors
    lines[4] = f'$ks_{lr_ml_name}$  $m_{lr_ml_name}$  $l_{lr_ml_name}$  $mfmax_{lr_ml_name}$  \n' #earth properties factors
    lines[24] = f'$crfac_{lr_ml_name}$  $gamma_{lr_ml_name}$  \n' #crop factor & gamma

    # Write the file out again
    with open(os.path.join(template_ws, lr_template_file), 'w') as file:
        for line in lines:
            file.write(line)

# %% [markdown]
# Parameterize recharge model:

# %%
parameterize_lr_model('lr_lu1.tpl', 'lu1')

# %% [markdown]
# Parameterize GHB models:

# %%
for file in os.listdir(template_ws):
    if 'lr_' in file and 'lu1' not in file:
        parameterize_lr_model(file, file[3:][:3])

# %% [markdown]
# Done.

# %% [markdown]
# ## Build partial PEST control file using TPL2PST

# %% [markdown]
# Write tpl2pst script:

# %%
write_script(os.path.join(template_ws, 'tpl2pst.in'), [
f'''
# An example TPL2PST input file

start template_file
  template_file     = pp3d_coarse.tpl
  model_input_file  = pp3d_coarse.dat
  transform         = log
  value             = 1.0
  lower_bound       = 0.1     
  upper_bound       = 10
  pargroup          = changethis
end template_file

start template_file
  template_file     = sfrpp.tpl
  model_input_file  = sfrpp.dat
  transform         = log
  value             = 86.4
  lower_bound       = 0.000864     
  upper_bound       = 864.0
  pargroup          = sfrc
end template_file

start template_file
  template_file     = ghbpp.tpl
  model_input_file  = ghbpp.dat
  transform         = log
  value             = 86.4
  lower_bound       = 0.000864     
  upper_bound       = 864.0
  pargroup          = ghbc
end template_file

start template_file
  template_file     = hagfors_1.sfr_perioddata_1.tpl
  model_input_file  = hagfors_1.sfr_perioddata_1.txt
  transform         = log
  value             = 15000
  lower_bound       = 100     
  upper_bound       = 40000
  pargroup          = sfrinfl1
end template_file

start template_file
  template_file     = lr_lu1.tpl 
  model_input_file  = lr_lu1.in
  transform         = log
  value             = 1 # change this
  lower_bound       = 0.1 # change this     
  upper_bound       = 10 # change this
  pargroup          = rch
end template_file

start template_file
  template_file     = lr_red.tpl 
  model_input_file  = lr_red.in
  transform         = log
  value             = 1 # change this
  lower_bound       = 0.1 # change this     
  upper_bound       = 10 # change this
  pargroup          = lrghbred
end template_file

start template_file
  template_file     = lr_orange.tpl 
  model_input_file  = lr_orange.in
  transform         = log
  value             = 1 # change this
  lower_bound       = 0.1 # change this     
  upper_bound       = 10 # change this
  pargroup          = lrghbora
end template_file

start template_file
  template_file     = lr_yellow.tpl 
  model_input_file  = lr_yellow.in
  transform         = log
  value             = 1 # change this
  lower_bound       = 0.1 # change this     
  upper_bound       = 10 # change this
  pargroup          = lrghbyel
end template_file

start template_file
  template_file     = lr_limegreen.tpl 
  model_input_file  = lr_limegreen.in
  transform         = log
  value             = 1 # change this
  lower_bound       = 0.1 # change this     
  upper_bound       = 10 # change this
  pargroup          = lrghblim
end template_file

start template_file
  template_file     = lr_royalblue.tpl 
  model_input_file  = lr_royalblue.in
  transform         = log
  value             = 1 # change this
  lower_bound       = 0.1 # change this     
  upper_bound       = 10 # change this
  pargroup          = lrghbroy
end template_file

start template_file
  template_file     = lr_blueviolet.tpl 
  model_input_file  = lr_blueviolet.in
  transform         = log
  value             = 1 # change this
  lower_bound       = 0.1 # change this     
  upper_bound       = 10 # change this
  pargroup          = lrghbblu
end template_file

start template_file
  template_file     = lr_magenta.tpl 
  model_input_file  = lr_magenta.in
  transform         = log
  value             = 1 # change this
  lower_bound       = 0.1 # change this     
  upper_bound       = 10 # change this
  pargroup          = lrghbmag
end template_file
'''
])

# %%
# run TPL2PST
run.run_process(
    'tpl2pst',
    path=template_ws,
    commands=['tpl2pst.in', 'param.pst']
)

# %% [markdown]
# running tpl2pst doesn't work for some reason. has to be run subprocess below:

# %%
import subprocess
p = subprocess.run(['tpl2pst', 'tpl2pst.in', 'param.pst'], cwd=template_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)

# %%
os.listdir(template_ws) # param.pst is now created

# %% [markdown]
# ### Make necessary changes to param.pst:

# %%
with open(os.path.join(template_ws, 'param.pst'), 'r') as file:
    pstfilep_param = file.readlines() #pestfile partial parameters

# %%
pstfilep_param

# %%
print('Relevant indices:') # print relevant indices of the pstfilep_param
print(pstfilep_param.index('* parameter groups\n'))
print(pstfilep_param.index('* parameter data\n'))
print(pstfilep_param.index('* observation groups\n'))

# %% [markdown]
# ### Change parameter data

# %% [markdown]
# Let's start by changing all the parameters marked with "changethis" (as suggested by calibration tutorial):

# %%
paramdata_start = pstfilep_param.index('* parameter data\n') + 1
paramdata_stop = pstfilep_param.index('* observation groups\n')

# %%
pardata_df = pd.DataFrame(pstfilep_param[paramdata_start:paramdata_stop]) # read df

# %%
pardata_df.iloc[:,0] = pardata_df.iloc[:,0].str.replace(r'\ (?= *?\ )', '') # clean up data structure

# %%
pardata_cols = ['PARNME', 'PARTRANS', 'PARCHGLIM', 'PARVAL1', 'PARLBND', 'PARUBND', 'PARGP', 'SCALE', 'OFFSET']

# %%
pardata_df[pardata_cols] = pardata_df[0].str.split(' ', 9, expand=True) # add columns

# %%
pardata_df = pardata_df[pardata_cols] # remove redundant column
display(pardata_df) # view df

# %% [markdown]
# Sort the dataframe based on parameters (as suggested by calibration tutorial):

# %%
pardata_df = pardata_df.sort_values(['PARNME', 'PARGP']).reset_index(drop=True)

# %% [markdown]
# Assign new parameter groups (PARGP) for each type of parameter:

# %%
parnme_pargrp = [
    'ghbcblu', 'ghbclim', 'ghbcmag', 'ghbcora', 'ghbcred', 
    'ghbcroy','ghbcyel', 'kh1pp', 'kh2pp', 'kh3pp', 'kv1pp',
    'kv2pp', 'kv3pp', 'sfrpp', 'ss1pp', 'ss2pp', 'ss3pp',
    'sy1pp', 'sy2pp', 'sy3pp'
]

# %%
for i in parnme_pargrp:
    pardata_df.loc[pardata_df['PARNME'].str.contains(i), 'PARGP'] = i

# %%
pardata_df

# %% [markdown]
# Assign new (initial) parameter value, lower and upper bounds for the non-linear pilot point parameters:

# %%
parval1 = {'kh': 86.4, 'kv': 8.64, 'sy': 0.2, 'ss': 0.000001}
parlbnd = {'kh': 8.64E-04, 'kv': 8.64E-05, 'sy': 0.05, 'ss': 0.00000001}
parubnd = {'kh': 864.0, 'kv': 864.0, 'sy': 0.35, 'ss': 0.001}

# %%
for d, col in zip([parval1, parlbnd, parubnd], ['PARVAL1', 'PARLBND', 'PARUBND']):
    for k,v in d.items():
        pardata_df.loc[pardata_df['PARGP'].str.contains(k), col] = v

# %%
display(pardata_df)

# %% [markdown]
# Assign new (initial) parameter value, lower and upper bounds for the **lumprem** parameters:

# %% [markdown]
# Extract data from df to list:

# %%
pardata_list = pardata_df.values.tolist()

# %%
pardata_new = []
for i in pardata_list:
    pardata_new.append(' '.join(str(v) for v in i))

# %% [markdown]
# This is the old parameter data:

# %%
display(pstfilep_param[paramdata_start:paramdata_stop])

# %% [markdown]
# Which will now be replaced by the new parameter data, which is this:

# %%
display(pardata_new) # show list

# %% [markdown]
# Create a temporary copy of the original `pstfilep_param`:

# %%
pstfilep_param_temp = pstfilep_param[:]

# %% [markdown]
# Replace the old parameter data with the changed pardata in the templist:

# %%
for (index, replacement) in zip([i for i in range(paramdata_start, paramdata_stop)], pardata_new):
    pstfilep_param_temp[index] = replacement

# %% [markdown]
# The parameter data has now been replaced:

# %%
display(pstfilep_param_temp)

# %% [markdown]
# ### Change parameter groups

# %% [markdown]
# Get relevant indices:

# %%
pargrp_start = pstfilep_param_temp.index('* parameter groups\n') + 1
pargrp_stop = pstfilep_param_temp.index('* parameter data\n')

# %% [markdown]
# Let's have a look at the current parameter grous config:

# %%
pargrp_df = pd.DataFrame(pstfilep_param_temp[pargrp_start:pargrp_stop])
pargrp_df.iloc[:,0] = pargrp_df.iloc[:,0].str.replace(r'\ (?= *?\ )', '')
pargrp_cols = ['PARGPNME', 'INCTYP', 'DERINC', 'DERINCLB', 'FORCEN', 'DERINCMUL', 'DERMTHD']
pargrp_df[pargrp_cols] = pargrp_df[0].str.split(' ', 7, expand=True)
pargrp_df = pargrp_df[pargrp_cols]
display(pargrp_df)

# %% [markdown]
# Let's recreate this data structure (no need to use a dataframe):

# %%
pargrp_new = [' '.join(str(v) for v in [i, 'relative', 0.015, 0.0, 'switch', 2, 'parabolic\n']) for i in pardata_df['PARGP'].unique()]
display(pargrp_new)

# %% [markdown]
# Make a new copy of the partial pestfile:

# %%
pstfilep_param_new = pstfilep_param_temp[:]

# %% [markdown]
# Replace the old parameter groups with the changed pargp in the temp2list:

# %%
pstfilep_param_new[pargrp_start:pargrp_stop] = pargrp_new

# %% [markdown]
# The parameter groups have now been changed:

# %%
display(pstfilep_param_new)

# %% [markdown]
# ### Change NPARGP (number of parameter groups)

# %% [markdown]
# This is the third column of the third index (number 3 below):

# %%
pstfilep_param_new[3]

# %%
temp_row = pstfilep_param_new[3].split()
display(temp_row)

# %%
npargp = len(pardata_df['PARGP'].unique()) # number of parameter groups
print(npargp)

# %%
temp_row[2] = str(npargp)
temp_row[-1] = '0\n'
display(temp_row)

# %%
new_row = ' '.join(temp_row)
display(new_row)

# %%
pstfilep_param_new[3] = new_row

# %%
display(pstfilep_param_new)

# %% [markdown]
# ### Write new partial pest parameter file:

# %%
with open(os.path.join(template_ws, 'partial_param.pst'), 'w') as file:
    for line in pstfilep_param_new:
        file.write(line)

# %% [markdown]
# ### Copy pestfile to pestdir

# %%
partial_pestfile = 'partial_param.pst'
shutil.copyfile(os.path.join(template_ws, partial_pestfile), os.path.join(pest_ws, partial_pestfile))

# %%
os.rename(
    os.path.join(pest_ws, 'partial_param.pst'),
    os.path.join(pest_ws, 'calib0.pst')
)

# %% [markdown]
# ### Fix model input/output

# %%
with open(os.path.join(pest_ws, 'calib0.pst'), 'r') as file:
    pstfilep_calib = file.readlines() #pestfile partial parameters

# %% [markdown]
# Get index:

# %%
ml_io_start = pstfilep_calib.index('* model input/output\n') + 1

# %%
pstfilep_calib[ml_io_start:]

# %%
prepend1, prepend2 = '.\\template\\', '..\\runmodel\\preproc\\'

# %%
new_ml_io = []
for i in pstfilep_calib[ml_io_start:]:
    for string, j in zip([prepend1, prepend2], i.split()):
        new_ml_io.append(string + j)

# %%
new_ml_io

# %%
new_ml_io = [' '.join(i) for i in zip(new_ml_io[0::2], new_ml_io[1::2])]

# %%
new_ml_io = [i+'\n' for i in new_ml_io]

# %%
new_ml_io

# %%
pstfilep_calib[ml_io_start:] = new_ml_io

# %% [markdown]
# Overwrite `calib0.pst`:

# %%
with open(os.path.join(pest_ws, 'calib0.pst'), 'w') as file:
    for line in pstfilep_calib:
        file.write(line)

# %%
hds_meas_lowpass
# Out:
#                          datetime      name       value   timedelta  td_match  \
# 0   2016-11-30 13:59:59.999971200      b2-1  137.048802  334.583333      True
# 1   2016-12-31 00:00:00.000000000      b2-1  137.040387  365.000000      True
# 2   2017-01-30 10:00:00.000028800      b2-1  137.022339  395.416667      True
# 3   2017-03-01 19:59:59.999971200      b2-1  136.991891  425.833333      True
# 4   2017-04-01 06:00:00.000000000      b2-1  136.978018  456.250000      True
# ..                            ...       ...         ...         ...       ...
# 344 2016-12-31 00:00:00.000000000  ni1501-3  136.730250  365.000000      True
# 345 2017-01-30 10:00:00.000028800  ni1501-3  136.723472  395.416667      True
# 346 2017-03-01 19:59:59.999971200  ni1501-3  136.760056  425.833333      True
# 347 2017-04-01 06:00:00.000000000  ni1501-3  136.783125  456.250000      True
# 348 2017-05-01 16:00:00.000028800  ni1501-3  136.769786  486.666667      True
#
#                            matchcol              obsgnme  weight      obsval
# 0        hds_usecol:b2-1_time:334.5      hds_usecol:b2-1     1.0  137.048802
# 1        hds_usecol:b2-1_time:365.0      hds_usecol:b2-1     1.0  137.040387
# 2        hds_usecol:b2-1_time:395.4      hds_usecol:b2-1     1.0  137.022339
# 3        hds_usecol:b2-1_time:425.8      hds_usecol:b2-1     1.0  136.991891
# 4        hds_usecol:b2-1_time:456.2      hds_usecol:b2-1     1.0  136.978018
# ..                              ...                  ...     ...         ...
# 344  hds_usecol:ni1501-3_time:365.0  hds_usecol:ni1501-3     1.0  136.730250
# 345  hds_usecol:ni1501-3_time:395.4  hds_usecol:ni1501-3     1.0  136.723472
# 346  hds_usecol:ni1501-3_time:425.8  hds_usecol:ni1501-3     1.0  136.760056
# 347  hds_usecol:ni1501-3_time:456.2  hds_usecol:ni1501-3     1.0  136.783125
# 348  hds_usecol:ni1501-3_time:486.6  hds_usecol:ni1501-3     1.0  136.769786
#
# [349 rows x 9 columns]

# %% [markdown]
# Parameters: kh, kx, sy, ss, sfrcond, ghbcond, lu1 lumprem recharge model (still tbd ghb lumprem models)

# %% [markdown]
# ### END OF NOTEBOOK

# %% [markdown]
# ---
