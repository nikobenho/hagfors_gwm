# %%
import os
import sys
import shutil
import subprocess
import pandas as pd
from lumpyrem import run
import flopy
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) # Suppress deprecation warnings

# %%
org_model_ws = os.path.join('..', 'temp_ml_obs')
os.listdir(org_model_ws)
# Out:
# ['pest', 'runmodel']

# %%
tmp_model_ws = os.path.join('..', 'temp_ml_calib') # Safe to delete
if os.path.exists(tmp_model_ws):
    shutil.rmtree(tmp_model_ws)
shutil.copytree(org_model_ws,tmp_model_ws)
os.listdir(tmp_model_ws)
# Out:
# ['pest', 'runmodel']

# %%
pest_ws = os.path.join(tmp_model_ws, 'pest')

# %%
def write_script(filename, lines):

    with open(filename, 'a') as f:
        for line in lines:
            f.write(line)
            f.write('\n')

# %% [markdown]
# #### Windows runmodel-script:

# %%
write_script(os.path.join(pest_ws, 'runmodel.bat'), [
'''
@echo off
Rem ###################################
Rem Some intermediate files are deleted as a precaution.
Rem Delete MF6 computed output
Rem ###################################
cd %~dp0..\\runmodel\\model
del /s *.csv
del /s ghb_new.ts
del /s rch_new.ts
Rem ###################################
Rem Do not remove sfr_reach1_inflow.ts!
Rem ###################################

Rem ###################################
Rem Delete Luprem computed output
Rem ###################################
cd %~dp0..\\runmodel\\lumprem
del /s *.out
del /s *.ts

Rem ###################################
Rem Run LUMPREM and copy files into MF6 rundir
Rem ###################################
lumprem2 lr_lu1.in lr_lu1.out
lumprem2 lr_red.in lr_red.out
lumprem2 lr_yellow.in lr_yellow.out
lumprem2 lr_green.in lr_green.out
lumprem2 lr_blue.in lr_blue.out

echo rch.ts.in | lr2series
echo ghb.ts.in | lr2series

ts6proc ts6ghb.in
ts6proc ts6rch.in

copy ghb_new.ts "..\model"
copy rch_new.ts "..\model"

Rem ###################################
Rem PLPROC assigns parameters from ppoints
Rem ###################################
cd %~dp0..\\runmodel\\preproc\\
plproc plproc_kh.dat
plproc plproc_sy.dat
plproc plproc_rchmul.dat
plproc plproc_sfr.dat
plproc plproc_ghb.dat
python sfr_rtpmodel.py
python ghb_multiplier.py
python sfr_rainf_evapo_multiplier.py

Rem ###################################
Rem The MF6 model is run
Rem ###################################
cd %~dp0..\\runmodel\\model\\
mf6 mfsim.nam

Rem ###################################
Rem The observations are postprocessed
Rem ###################################
cd  %~dp0..\\runmodel\\postproc\\
olproc olproc.in 1
olproc olproc-pred.in 1

Rem ###################################
Rem Return the command line to the working folder
Rem ###################################
cd %~dp0.\\

'''
])

# %%
write_script(os.path.join(pest_ws, 'runmodel.sh'), [
'''
#!/bin/bash
# Remove old MF6 files
cd ${0%/*}./runmodel/model
rm -f *.csv
rm -f ghb_new.ts
rm -f rch_new.ts
# Do not remove sfr_reach1_inflow.ts!

# Remove old LR files
cd ../lumprem
rm -f *.out
rm -f *.ts

# Run LUMPREM models
./lumprem2 lr_lu1.in lr_lu1.out
./lumprem2 lr_red.in lr_red.out
./lumprem2 lr_yellow.in lr_yellow.out
./lumprem2 lr_green.in lr_green.out
./lumprem2 lr_blue.in lr_blue.out

# Convert LR output to TS
echo rch.ts.in | ./lr2series
echo ghb.ts.in | ./lr2series

# Postprocess TS using TS6PROC
./ts6proc ts6ghb.in
./ts6proc ts6rch.in

# Copy TS-files to MF6 dir
cp ghb_new.ts ../model
cp rch_new.ts ../model

# Run PLPROC
cd ../preproc
./plproc plproc_kh.dat
./plproc plproc_sy.dat
./plproc plproc_rchmul.dat
./plproc plproc_sfr.dat
./plproc plproc_ghb.dat
python3 sfr_rtpmodel.py
python3 ghb_multiplier.py
python3 sfr_rainf_evapo_multiplier.py

# Run MF6 model
cd ../model
./mf6 mfsim.nam

# Postprocess observations
# Run MF6 model
cd ../postproc
./olproc olproc.in 1
./olproc olproc-pred.in 1

#Rem ###################################
#Rem Return the command line to the working folder
#Rem ###################################
#cd %~dp0.\\
# is this necessary on linux?

'''
])

# %% [markdown]
# ### Make copy of calibration file

# %%
os.listdir(tmp_model_ws)
# Out:
# ['pest', 'runmodel']

# %%
with open(os.path.join(pest_ws, 'calib0.pst'), 'r') as file:
    calib1 = file.readlines()

# %% [markdown]
# ### Change NOPTMAX from 50 to 0:

# %%
temp_row = calib1[8].split()
display(temp_row)
# Out:
# ['50', '0.005', '4', '4', '0.005', '4']

# %%
temp_row[0] = '0'
temp_row[-1] = f'{temp_row[-1]}\n'
display(temp_row)
# Out:
# ['0', '0.005', '4', '4', '0.005', '4\n']

# %%
new_row = ' '.join(temp_row)
display(new_row)
# Out:
# '0 0.005 4 4 0.005 4\n'

# %%
calib1[8] = new_row

# %% [markdown]
# ### Add model command line

# %%
mlcl_strt = calib1.index('* model command line\n') + 1
mlcl_stop = calib1.index('* model input/output\n')

# %%
calib1[mlcl_strt:mlcl_stop] = 'runmodel.bat\n'

# %% [markdown]
# ### Write file

# %%
# Write the file out again
with open(os.path.join(pest_ws, 'calib1.pst'), 'w') as file:
    for line in calib1:
        file.write(line)

# %% [markdown]
# ### Run model once to weight for visibility

# %% [markdown]
# Copy relevant binaries:

# %%
bins_pth = os.path.join('..', 'bins', 'win') if 'nt' in os.name else os.path.join('..', 'bins', 'linux') # Binaries

# %%
os.listdir(bins_pth)
# Out:
# ['agent_hp.exe',
#  'gridgen.exe',
#  'libiomp5md.dll',
#  'mf6.exe',
#  'pestpp-ies.exe',
#  'pest_hp_mkl.exe',
#  'triangle.exe']

# %%
copyfiles = ['agent_hp.exe', 'libiomp5md.dll', 'pest_hp_mkl.exe', 'mf6.exe']

# %%
for file in copyfiles:
    shutil.copyfile(os.path.join(bins_pth, file), os.path.join(pest_ws, file))

# %%
agent_dir = os.path.join(tmp_model_ws ,'agent_dir')
if os.path.exists(agent_dir):
    shutil.rmtree(agent_dir)
os.mkdir(agent_dir)

# %%
agent0_dir = os.path.join(agent_dir ,'agent0')
if os.path.exists(agent0_dir):
    shutil.rmtree(agent0_dir)

# %%
for folder in ['pest', 'runmodel']:
    shutil.copytree(os.path.join(tmp_model_ws, folder), os.path.join(agent0_dir, folder), dirs_exist_ok=True)

# %%
p = subprocess.run(['i64pestchek', 'calib1.pst'], cwd=pest_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
#  PESTCHEK Version 17.3. Watermark Numerical Computing.
#
#  Errors ----->
#  No errors encountered.
#
#  Warnings ----->
#  NOPTMAX provided as zero. No optimisation iterations will be carried out;
#    objective function and residuals will be recorded for initial parameter
#    estimates only.
#  MAXSING in the singular value decomposition section is greater than the
#    number of adjustable parameters.

# %% [markdown]
# ---

# %% [markdown]
# Manually run `pest_hp_mkl calib1.pst /h :4004` in pest_ws

# %% [markdown]
# Manually run `agent_hp calib1.pst /h %computername%:4004` in agent0_dir

# %% [markdown]
# local path (my machine): `set PATH=%PATH%;C:\Users\nat12nho\Documents\Development\repos\hagfors_gwm\bins\win`

# %% [markdown]
# ---

# %%
agent_ml, ml_name = os.path.join(agent0_dir, 'runmodel', 'model'), 'hagfors_1'
sim_agent = flopy.mf6.MFSimulation.load(ml_name, 'mf6', os.path.join(bins_pth, 'mf6'), agent_ml)
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package disv...
# WARNING: Unable to resolve dimension of ('gwf6', 'disv', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
#     loading package rch...
#     loading package sto...
#     loading package oc...
#     loading package npf...
#     loading package ic...
#     loading package sfr...
#     loading package obs...
#     loading package ghb...
#   loading ims package hagfors_1...

# %%
gwf = sim_agent.get_model(ml_name)

# %%
# get the specific discharge from the cell budget file
cbb_file = os.path.join(agent_ml, f'{ml_name}.cbb')
cbb = flopy.utils.CellBudgetFile(cbb_file)

# get the head from the head file
head_file = os.path.join(agent_ml, f'{ml_name}.hds')
head = flopy.utils.HeadFile(head_file)
hdata = head.get_alldata()

# %%
spd = 1

fig = plt.figure(figsize=(12, 12), dpi=90)
ax = fig.add_subplot(1, 1, 1, aspect='equal')
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates

mapview = flopy.plot.PlotMapView(gwf, layer=0)
linecollection = mapview.plot_grid(lw=0.25, color='k')
quadmesh = mapview.plot_array(a=hdata[spd], alpha=0.9, masked_values=[1e30])
plt.colorbar(quadmesh, shrink=0.4);

levels = np.arange(130, 145, 1.0)
contour_set = mapview.contour_array(hdata[spd], levels=levels, colors='white')
plt.clabel(contour_set, fmt="%.1f", colors='white', fontsize=11)


plt.title(f'Heads (spd: {spd})')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
hdata[0][0][0]
# Out:
# array([133.58938697, 133.68575474, 133.70320244, ..., 137.38422946,
#        137.47277332, 137.61261466])

# %%
(gwf.disv.top.get_data() - hdata[200][0][0]).min()
# Out:
# -0.024284260398957258

# %% [markdown]
# Weight for visibility (lumpyrem.run process does not seem to work with tpl2pst, tempchek, pestchek, pest_hp, pwtadj1. Use `subprocess` instead):

# %%
p = subprocess.run(['pwtadj1', 'calib1.pst', 'calib1-wt.pst', '1000'], cwd=pest_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
#  PWTADJ1 version 17.3. Watermark Numerical Computing.
#
#  - reading PEST control file calib1.pst for first time...
#  - file calib1.pst read ok.
#
#  - reading PEST run record file calib1.rec...
#  - file calib1.rec read ok.
#
#  - re-reading file calib1.pst and writing file calib1-wt.pst...
#  - file calib1.pst read ok.
#  - file calib1-wt.pst written ok.
#
#  Warning: an adjustment factor cannot not be computed for members of
#  obsevation group ">@dts" as contribution to objective function of this
#  group is zero.
#  Warning: an adjustment factor cannot not be computed for members of
#  obsevation group ">@of" as contribution to objective function of this
#  group is zero.
#  Warning: an adjustment factor cannot not be computed for members of
#  obsevation group "pfluxb" as contribution to objective function of this
#  group is zero.
#  Warning: an adjustment factor cannot not be computed for members of
#  obsevation group "pofb" as contribution to objective function of this
#  group is zero.
#  Warning: an adjustment factor cannot not be computed for members of
#  obsevation group "pfluxr" as contribution to objective function of this
#  group is zero.
#  Warning: an adjustment factor cannot not be computed for members of
#  obsevation group "pofr" as contribution to objective function of this
#  group is zero.

# %% [markdown]
# Change NOPTMAX from 50 to 0:

# %%
with open(os.path.join(pest_ws, 'calib1-wt.pst'), 'r') as file:
    calib1_wt = file.readlines()

# %%
temp_row = calib1_wt[8].split()
display(temp_row)
temp_row[0] = '0'
temp_row[-1] = f'{temp_row[-1]}\n'
display(temp_row)
new_row = ' '.join(temp_row)
display(new_row)
calib1_wt[8] = new_row
# Out:
# ['50', '0.005', '4', '4', '0.005', '4']
# ['0', '0.005', '4', '4', '0.005', '4\n']
# '0 0.005 4 4 0.005 4\n'

# %%
# Write the file out again
with open(os.path.join(pest_ws, 'calib1-wt.pst'), 'w') as file:
    for line in calib1_wt:
        file.write(line)

# %% [markdown]
# Copy `calib1-wt.pst` to agent0:

# %%
shutil.copyfile(os.path.join(pest_ws, 'calib1-wt.pst'), os.path.join(agent0_dir, 'pest', 'calib1-wt.pst'))
# Out:
# '..\\temp_ml_calib\\agent_dir\\agent0\\pest\\calib1-wt.pst'

# %%
p = subprocess.run(['i64pestchek', 'calib1-wt.pst'], cwd=pest_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
#  PESTCHEK Version 17.3. Watermark Numerical Computing.
#
#  Errors ----->
#  No errors encountered.
#
#  Warnings ----->
#  NOPTMAX provided as zero. No optimisation iterations will be carried out;
#    objective function and residuals will be recorded for initial parameter
#    estimates only.
#  MAXSING in the singular value decomposition section is greater than the
#    number of adjustable parameters.

# %% [markdown]
# Manually add weight for dts

# %% [markdown]
# ---

# %% [markdown]
# Manually run `pest_hp_mkl calib1-wt.pst /h :4004` in pest_ws

# %% [markdown]
# Manually run `agent_hp calib1-wt.pst /h %computername%:4004` in agent0_dir

# %% [markdown]
# ---

# %% [markdown]
# ### Adding Tikhonov Regularization

# %%
p = subprocess.run(['addreg1', 'calib1-wt.pst', 'calib1-wt-reg.pst'], cwd=pest_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
#  ADDREG1 version 17.3. Watermark Numerical Computing.
#  - file calib1-wt.pst read ok.
#  - file calib1-wt-reg.pst written ok.

# %%
p = subprocess.run(['i64pestchek', 'calib1-wt-reg.pst'], cwd=pest_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)

# %% [markdown]
# #### ADD COVARIANCE MATRICES

# %%
with open(os.path.join(pest_ws, 'calib1-wt-reg.pst'), 'r') as file:
    pestfile = file.readlines()

# %%
pestfile
# Out:
# ['pcf\n',
#  '* control data\n',
#  'restart regularisation\n',
#  '    1719  172899      28    1719      43\n',
#  '13 15 single point\n',
#  ' 10.0  -3.0  0.3  0.03  10  lamforgive\n',
#  ' 10.0  10.0  0.001\n',
#  ' 0.1\n',
#  '0 0.005 4 4 0.005 4\n',
#  ' 0  0  0\n',
#  '* singular value decomposition\n',
#  '1\n',
#  '  5000  5e-7\n',
#  '0\n',
#  '* parameter groups\n',
#  'ghbcbl relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcgr relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcre relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcye relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbmul relative 0.015 0.0 switch 2 parabolic\n',
#  'khpp relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_cf relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_f1 relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_f2 relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_gam relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_ks relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_m relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_mvl relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_off relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_pow relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_vol relative 0.015 0.0 switch 2 parabolic\n',
#  'rchmul relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrbth relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrgrd relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrinf relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrman relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrrhk relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtpe relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtpo relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtps relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrwid relative 0.015 0.0 switch 2 parabolic\n',
#  'sr1mul relative 0.015 0.0 switch 2 parabolic\n',
#  'sypp relative 0.015 0.0 switch 2 parabolic\n',
#  '* parameter data\n',
#  'ghbcblupp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp16 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp17 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp18 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp19 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcgrepp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcredpp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcyelpp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp16 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp17 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp18 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbbluemult log factor 1.0000000E-02 1.0000000E-03 1.000000 ghbmul 1.0 0.0\n',
#  'ghbyellomult log factor 1.0000000E-02 1.0000000E-03 1.000000 ghbmul 1.0 0.0\n',
#  'khpp001 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp002 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp003 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp004 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp005 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp006 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp007 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp008 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp009 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp010 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp011 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp012 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp013 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp014 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp015 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp016 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp017 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp018 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp019 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp020 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp021 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp022 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp023 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp024 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp025 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp026 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp027 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp028 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp029 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp030 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp031 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp032 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp033 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp034 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp035 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp036 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp037 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp038 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp039 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp040 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp041 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp042 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp043 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp044 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp045 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp046 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp047 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp048 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp049 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp050 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp051 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp052 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp053 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp054 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp055 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp056 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp057 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp058 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp059 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp060 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp061 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp062 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp063 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp064 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp065 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp066 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp067 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp068 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp069 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp070 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp071 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp072 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp073 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp074 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp075 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp076 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp077 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp078 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp079 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp080 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp081 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp082 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp083 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp084 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp085 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp086 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp087 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp088 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp089 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp090 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp091 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp092 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp093 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp094 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp095 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp096 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp097 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp098 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp099 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp100 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp101 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp102 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp103 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp104 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp105 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp106 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp107 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp108 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp109 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp110 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp111 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp112 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp113 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp114 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp115 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp116 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp117 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp118 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp119 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp120 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp121 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp122 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp123 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp124 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp125 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp126 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp127 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp128 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp129 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp130 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp131 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp132 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp133 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp134 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp135 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp136 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp137 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp138 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp139 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp140 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp141 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp142 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp143 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp144 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp145 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp146 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp147 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp148 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp149 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp150 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp151 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp152 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp153 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp154 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp155 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp156 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp157 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp158 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp159 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp160 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp161 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp162 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp163 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp164 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp165 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp166 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp167 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp168 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp169 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp170 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp171 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp172 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp173 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp174 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp175 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp176 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp177 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp178 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp179 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp180 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp181 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp182 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp183 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp184 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp185 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp186 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp187 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp188 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp189 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp190 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp191 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp192 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp193 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp194 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp195 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp196 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp197 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp198 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp199 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp200 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp201 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp202 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp203 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp204 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp205 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp206 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp207 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp208 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp209 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp210 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp211 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp212 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp213 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp214 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp215 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp216 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp217 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp218 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp219 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp220 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp221 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp222 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp223 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp224 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp225 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp226 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp227 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp228 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp229 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp230 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp231 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp232 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp233 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp234 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp235 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp236 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp237 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp238 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp239 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp240 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp241 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp242 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp243 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp244 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp245 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp246 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp247 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp248 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp249 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp250 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp251 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp252 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp253 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp254 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp255 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp256 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp257 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp258 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp259 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp260 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp261 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp262 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp263 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp264 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp265 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp266 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp267 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp268 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp269 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp270 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp271 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp272 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp273 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp274 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp275 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp276 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp277 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp278 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp279 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp280 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp281 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp282 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp283 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp284 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp285 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp286 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp287 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp288 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp289 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp290 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp291 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp292 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp293 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp294 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp295 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp296 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp297 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp298 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp299 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp300 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp301 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp302 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp303 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp304 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp305 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp306 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp307 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp308 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp309 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp310 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp311 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp312 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp313 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp314 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp315 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp316 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp317 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp318 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp319 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp320 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp321 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp322 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp323 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp324 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp325 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp326 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp327 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp328 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp329 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp330 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp331 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp332 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp333 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp334 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp335 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp336 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp337 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp338 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp339 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp340 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp341 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp342 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp343 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp344 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp345 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp346 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp347 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp348 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp349 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp350 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp351 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp352 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp353 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp354 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp355 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp356 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp357 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp358 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp359 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp360 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp361 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp362 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp363 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp364 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp365 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp366 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp367 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp368 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp369 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp370 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp371 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp372 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp373 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp374 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp375 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp376 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp377 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp378 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp379 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp380 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp381 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp382 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp383 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp384 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp385 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp386 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp387 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp388 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp389 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp390 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp391 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp392 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp393 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp394 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp395 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp396 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp397 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp398 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp399 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp400 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp401 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp402 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp403 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp404 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp405 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp406 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp407 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp408 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp409 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp410 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp411 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp412 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp413 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp414 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp415 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp416 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp417 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp418 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp419 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp420 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp421 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp422 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp423 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp424 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp425 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp426 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp427 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp428 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp429 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp430 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp431 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp432 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp433 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp434 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp435 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp436 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp437 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp438 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp439 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp440 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp441 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp442 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp443 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp444 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp445 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp446 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp447 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp448 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp449 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp450 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp451 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp452 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp453 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp454 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp455 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp456 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp457 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp458 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp459 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp460 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp461 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp462 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp463 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp464 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp465 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp466 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp467 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp468 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp469 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp470 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp471 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp472 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp473 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp474 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp475 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp476 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp477 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp478 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp479 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp480 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp481 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp482 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp483 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp484 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp485 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp486 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp487 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp488 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp489 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp490 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp491 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp492 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp493 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp494 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp495 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp496 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp497 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp498 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp499 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp500 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp501 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp502 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp503 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp504 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp505 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp506 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp507 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp508 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp509 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp510 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp511 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp512 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp513 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp514 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp515 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp516 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp517 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp518 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp519 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp520 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp521 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp522 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp523 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp524 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp525 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp526 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp527 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp528 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp529 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp530 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp531 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp532 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp533 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp534 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp535 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp536 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp537 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp538 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp539 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp540 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp541 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp542 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp543 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp544 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp545 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp546 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp547 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp548 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp549 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp550 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp551 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp552 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp553 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp554 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp555 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp556 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp557 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp558 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp559 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp560 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp561 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp562 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp563 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp564 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp565 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp566 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp567 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp568 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp569 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp570 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp571 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp572 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp573 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp574 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp575 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp576 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp577 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp578 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp579 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp580 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp581 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp582 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp583 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp584 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp585 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp586 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp587 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
# ...
#  'khpp622 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp623 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp624 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp625 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp626 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp627 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp628 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp629 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp630 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp631 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp632 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp633 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp634 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp635 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp636 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp637 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp638 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp639 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp640 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp641 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp642 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp643 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp644 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp645 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp646 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp647 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp648 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp649 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp650 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp651 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp652 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp653 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp654 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp655 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp656 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp657 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp658 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp659 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp660 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp661 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp662 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp663 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp664 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp665 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp666 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp667 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp668 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp669 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp670 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp671 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp672 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp673 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp674 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp675 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp676 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp677 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp678 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp679 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp680 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'crfac_blu log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_gre log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_lu1 log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_red log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_yel log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'f1_blu log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_gre log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_red log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_yel log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f2_blu log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_gre log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_red log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_yel log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'gamma_blu log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_gre log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_lu1 log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_red log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_yel log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'ks_blu log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_gre log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_lu1 log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_red log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_yel log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'm_blu log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_gre log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_lu1 log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_red log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_yel log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'mvol_blu log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_gre log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_lu1 log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_red log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_yel log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'of_blu log factor 1.0 0.1 5.0 lr_off 1.0 135.0\n',
#  'of_gre log factor 4.6 0.1 8.0 lr_off 1.0 128.0\n',
#  'of_red log factor 3.0 0.1 6.5 lr_off 1.0 137.5\n',
#  'of_yel log factor 3.0 0.1 6.0 lr_off 1.0 136.0\n',
#  'p_blu log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_gre log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_red log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_yel log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'vol_blu log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_gre log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_lu1 log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_red log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_yel log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'rchmulpp001 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp002 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp003 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp004 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp005 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp006 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp007 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp008 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp009 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp010 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp011 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp012 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp013 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp014 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp015 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp016 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp017 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp018 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp019 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp020 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp021 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp022 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp023 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp024 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp025 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp026 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp027 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp028 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp029 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp030 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp031 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp032 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp033 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp034 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp035 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp036 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp037 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp038 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp039 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp040 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp041 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp042 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp043 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp044 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp045 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp046 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp047 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp048 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp049 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp050 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp051 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp052 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp053 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp054 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp055 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp056 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp057 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp058 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp059 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp060 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp061 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp062 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp063 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp064 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp065 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp066 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp067 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp068 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp069 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp070 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp071 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp072 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp073 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp074 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp075 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp076 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp077 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp078 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp079 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp080 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp081 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp082 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp083 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp084 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp085 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp086 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp087 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp088 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp089 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp090 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp091 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp092 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp093 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp094 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp095 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp096 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp097 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp098 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp099 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp100 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp101 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp102 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp103 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp104 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp105 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp106 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp107 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp108 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp109 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp110 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp111 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp112 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp113 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp114 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp115 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp116 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp117 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp118 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp119 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp120 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp121 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp122 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp123 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp124 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp125 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp126 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp127 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp128 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp129 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp130 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp131 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp132 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp133 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp134 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp135 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp136 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp137 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp138 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp139 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp140 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp141 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp142 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp143 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp144 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp145 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp146 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp147 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp148 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp149 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp150 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp151 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp152 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp153 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp154 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp155 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp156 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp157 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp158 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp159 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp160 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp161 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp162 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp163 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  ...]

# %%
priordata_start = pestfile.index('* prior information\n') + 1
priordata_stop = pestfile.index('* regularisation\n')

# %%
priordata_df = pd.DataFrame(pestfile[priordata_start:priordata_stop]) # read df

# %% [markdown]
# Extract all regularization OBGNME from the priordata section:

# %%
regul_obgnme = pd.Series([i.split()[-1] for i in priordata_df.iloc[:,0]]).unique()

# %%
print(regul_obgnme)
# Out:
# ['regul_ghbcbl' 'regul_ghbcgr' 'regul_ghbcre' 'regul_ghbcye'
#  'regul_ghbmul' 'regul_khpp' 'regul_lr_cf' 'regul_lr_f1' 'regul_lr_f2'
#  'regul_lr_gam' 'regul_lr_ks' 'regul_lr_m' 'regul_lr_mvl' 'regul_lr_off'
#  'regul_lr_pow' 'regul_lr_vol' 'regul_rchmul' 'regul_sfrbth'
#  'regul_sfrgrd' 'regul_sfrinf' 'regul_sfrman' 'regul_sfrrhk'
#  'regul_sfrtpe' 'regul_sfrtpo' 'regul_sfrtps' 'regul_sfrwid'
#  'regul_sr1mul' 'regul_sypp']

# %% [markdown]
# Print all covariance matrices:

# %%
preproc_ws = os.path.join(tmp_model_ws, 'runmodel', 'preproc')

# %%
for file in os.listdir(preproc_ws):
    if '.mat' in file:
        print(file)
# Out:
# cov_cond.mat
# cov_ghb_blue.mat
# cov_ghb_green.mat
# cov_ghb_red.mat
# cov_ghb_yellow.mat
# cov_sfr.mat
# cov_sfr_inf1.mat
# cov_sy_rchmul.mat

# %% [markdown]
# Use covariance matrices with regularisation groups for spatial parameters:

# %%
write_script(os.path.join(pest_ws, 'covmatfile.in'), [
'''
regul_ghbcye ..\\runmodel\\preproc\\cov_ghb_yellow.mat
regul_ghbcbl ..\\runmodel\\preproc\\cov_ghb_blue.mat
regul_ghbcgr ..\\runmodel\\preproc\\cov_ghb_green.mat
regul_ghbcre ..\\runmodel\\preproc\\cov_ghb_red.mat
regul_sfrwid ..\\runmodel\\preproc\\cov_sfr.mat
regul_sfrgrd ..\\runmodel\\preproc\\cov_sfr.mat
regul_sfrbth ..\\runmodel\\preproc\\cov_sfr.mat
regul_sfrrhk ..\\runmodel\\preproc\\cov_sfr.mat
regul_sfrman ..\\runmodel\\preproc\\cov_sfr.mat
regul_khpp ..\\runmodel\\preproc\\cov_cond.mat
regul_sypp ..\\runmodel\\preproc\\cov_sy_rchmul.mat
regul_rchmul ..\\runmodel\\preproc\\cov_sy_rchmul.mat
regul_sfrinf ..\\runmodel\\preproc\\cov_sfr_inf1.mat
'''
])

# %%
p = subprocess.run(['addcovmat', 'calib1-wt-reg.pst', 'covmatfile.in', 'calib1-wt-cov.pst'], cwd=pest_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
# ADDCOVMAT Version 17.3. Watermark Numerical Computing.
#
# - 13 observation groups featured in file
# - file calib1-wt-reg.pst read ok.
# - file calib1-wt-cov.pst written ok.

# %%
p = subprocess.run(['i64pestchek', 'calib1-wt-cov.pst'], cwd=pest_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
#  PESTCHEK Version 17.3. Watermark Numerical Computing.
#
#  Errors ----->
#  No errors encountered.
#
#  Warnings ----->
#  NOPTMAX provided as zero. No optimisation iterations will be carried out;
#    objective function and residuals will be recorded for initial parameter
#    estimates only.
#  MAXSING in the singular value decomposition section is greater than the
#    number of adjustable parameters.

# %% [markdown]
# ### Set UPTESTMIN to 20
# When using PEST_HP it is recommended that the UPTESTMIN variable be set to 20 or higher. This ensures that PEST_HP carries out at least 20 model runs when testing parameter upgrades. If PEST_HP has more than 20 CPU cores at its disposal, it will automatically use all of them to carry out more lambda-testing model runs.

# %% [markdown]
# If iteration-specific inversion results are saved, a user can retrieve parameter values obtained at the end of the iteration at which the objective function started to flatten out, but at which the parameter field was more reasonable. Adding the PARSAVEITN and REISAVEITN variables to the “control data” section of a control file activates this behaviour

# %% [markdown]
# run process does not seem to work with tpl2pst, tempchek, pestchek, pest_hp, pwtadj1

# %% [markdown]
# ## Model specific pest-file settings
#
# ### Use LSQR over SVD
# A benefit of LSQR over singular value decomposition is its speed. If parameters number
# more than a couple of thousand, singular value decomposition can become very slow. This is
# not the case for LSQR which can happily handle tens of thousands of parameters and
# hundreds of thousands of observations. The cost of this speed is a slight approximation in
# separating solution and null subspaces; but this rarely matters.
#
# Where parameters number in the thousands and observations number in the tens of thousands, the LSQR solution process may take a few minutes. (Nevertheless it is far faster than singular value decomposition).

# %% [markdown]
# Unfortunately, if PEST_HP is run in “regularisation” mode (as it should be when estimating many parameters), the linearized inverse problem may need to be solved many times during each iteration of the overall inversion process in order to estimate the optimal regularisation weight factor for use during that iteration. This can add considerably to the overall length of the inversion process. To make matters worse, parallel run agents are standing idle while repeated solution of the linearized inverse problem is taking place to refine the regularisation weight factor.
# This process can be hastened by using looser convergence criteria for calculation of the best regularisation weight factor to use during each iteration of the inversion process; see PEST documentation of the WFFAC and WFTOL regularisation control settings. Alternatively, or as well, PEST_HP can be asked to use looser LSQR settings when undertaking linearized testing of a regularisation weight factor than when actually solving for a parameter upgrade.
#
# Experience has shown that a suitable value for **WFFAC is about 1.3**; it must be greater than
# 1.0. WFTOL is best set at somewhere between 1E-3 and 1E-2. However if there are many
# adjustable parameters and PEST consumes a large amount of time in determining the optimal
# weight factor, **a tolerance of somewhat higher than 1E-2 may prove suitable**.

# %% [markdown]
# ---
# settings
# *lsqr
# 1
# 1.0E-4	1.0E-4	1000.0	13928 alt_regwt 1.0E-4 1.0E-4 100 1000 4
# 1
#
# ---
# körningen startade kl 15:29 och kl 15:38:30 hade modellen körts 3482 gånger (1 manager 199 agents). Kl 15:40 börjar managern beräknana optimal regularisation weight factor. Kl 15:41 har den nått Re-calculated regularisation weight factor               :  0.45517 **samt** New starting objective function for this itn. (ie. phi)  :   12000. samt talar om Contribution to phi from observation group följt av samtliga observationsgrupper.
#
# Därefter idlar den. Är den klar men scriptet slutar inte, eller vadå?
#
# Nej, kl 15:51 (tio minuter senare) säger den: Parallelisation of lambda search: running model up to 140 times.....
#
# Därefter är den klar.
#
# ### resultat
# 10 minuter för att köra npar gånger (3482) - Detta kan förbättras genom att snabba upp modellen
# 10 minuter för att beräkna optimal regulariseringsfaktor - Detta kan förbättras m.h.a. WFFAC, WFTOL eller eventuellt PHIMLIM
#
# total slurmtid var 00:22:45 med -N 10 och --tasks-per-node 20

# %% [markdown]
# 16:38 nåddes 3482 körningar (iter2). 16:39 påbörjades beräkning av optimal regulariseringsviktfaktor. 16:51 påbörjas lambdakaberäkning. 16:52 är körningen klar.
#
# 2 iterationer = 00:46:19

# %% [markdown]
#         param "kh1pp096" frozen: gradient and update vectors out of bounds
#         param "kh1pp195" frozen: gradient and update vectors out of bounds
#         param "kh1pp267" frozen: gradient and update vectors out of bounds
#         param "kh1pp179" frozen: - update vector out of bounds

# %% [markdown]
# #### Turn off SVD:

# %%
with open(os.path.join(pest_ws, 'calib1-wt-cov.pst'), 'r') as file:
    pestfile = file.readlines()

# %%
svd_mode_index = pestfile.index('* singular value decomposition\n') + 1

# %%
pestfile[svd_mode_index]
# Out:
# '1\n'

# %%
pestfile[svd_mode_index] = '0\n'

# %%
pestfile[svd_mode_index]
# Out:
# '0\n'

# %% [markdown]
# #### Add LSQR:

# %%
temp_row = pestfile[3].split()
display(temp_row)
# Out:
# ['1719', '172899', '28', '1719', '43']

# %%
npar = int(temp_row[0])
npar
# Out:
# 1719

# %%
LSQR_ITNLIM = str(npar*4)
LSQR_ITNLIM
# Out:
# '6876'

# %%
lsqr_row3 = f'1.0E-4 1.0E-4 1000.0 {LSQR_ITNLIM}\n'

# %%
lsqr_row3
# Out:
# '1.0E-4 1.0E-4 1000.0 6876\n'

# %%
lsqr = ['* lsqr\n', '1\n', lsqr_row3, '1\n']

# %%
pestfile
# Out:
# ['pcf\n',
#  '* control data\n',
#  'restart regularisation\n',
#  '    1719  172899      28    1719      43\n',
#  '13 15 single point\n',
#  ' 10.0  -3.0  0.3  0.03  10  lamforgive\n',
#  ' 10.0  10.0  0.001\n',
#  ' 0.1\n',
#  '0 0.005 4 4 0.005 4\n',
#  ' 0  0  0\n',
#  '* singular value decomposition\n',
#  '0\n',
#  '  5000  5e-7\n',
#  '0\n',
#  '* parameter groups\n',
#  'ghbcbl relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcgr relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcre relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcye relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbmul relative 0.015 0.0 switch 2 parabolic\n',
#  'khpp relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_cf relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_f1 relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_f2 relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_gam relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_ks relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_m relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_mvl relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_off relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_pow relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_vol relative 0.015 0.0 switch 2 parabolic\n',
#  'rchmul relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrbth relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrgrd relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrinf relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrman relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrrhk relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtpe relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtpo relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtps relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrwid relative 0.015 0.0 switch 2 parabolic\n',
#  'sr1mul relative 0.015 0.0 switch 2 parabolic\n',
#  'sypp relative 0.015 0.0 switch 2 parabolic\n',
#  '* parameter data\n',
#  'ghbcblupp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp16 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp17 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp18 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp19 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcgrepp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcredpp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcyelpp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp16 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp17 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp18 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbbluemult log factor 1.0000000E-02 1.0000000E-03 1.000000 ghbmul 1.0 0.0\n',
#  'ghbyellomult log factor 1.0000000E-02 1.0000000E-03 1.000000 ghbmul 1.0 0.0\n',
#  'khpp001 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp002 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp003 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp004 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp005 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp006 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp007 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp008 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp009 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp010 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp011 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp012 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp013 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp014 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp015 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp016 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp017 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp018 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp019 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp020 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp021 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp022 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp023 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp024 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp025 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp026 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp027 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp028 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp029 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp030 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp031 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp032 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp033 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp034 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp035 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp036 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp037 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp038 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp039 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp040 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp041 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp042 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp043 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp044 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp045 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp046 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp047 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp048 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp049 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp050 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp051 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp052 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp053 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp054 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp055 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp056 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp057 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp058 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp059 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp060 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp061 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp062 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp063 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp064 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp065 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp066 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp067 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp068 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp069 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp070 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp071 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp072 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp073 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp074 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp075 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp076 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp077 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp078 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp079 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp080 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp081 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp082 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp083 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp084 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp085 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp086 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp087 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp088 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp089 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp090 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp091 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp092 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp093 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp094 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp095 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp096 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp097 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp098 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp099 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp100 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp101 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp102 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp103 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp104 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp105 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp106 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp107 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp108 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp109 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp110 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp111 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp112 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp113 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp114 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp115 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp116 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp117 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp118 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp119 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp120 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp121 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp122 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp123 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp124 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp125 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp126 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp127 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp128 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp129 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp130 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp131 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp132 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp133 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp134 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp135 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp136 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp137 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp138 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp139 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp140 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp141 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp142 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp143 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp144 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp145 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp146 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp147 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp148 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp149 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp150 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp151 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp152 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp153 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp154 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp155 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp156 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp157 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp158 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp159 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp160 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp161 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp162 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp163 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp164 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp165 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp166 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp167 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp168 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp169 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp170 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp171 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp172 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp173 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp174 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp175 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp176 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp177 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp178 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp179 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp180 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp181 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp182 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp183 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp184 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp185 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp186 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp187 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp188 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp189 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp190 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp191 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp192 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp193 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp194 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp195 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp196 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp197 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp198 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp199 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp200 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp201 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp202 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp203 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp204 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp205 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp206 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp207 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp208 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp209 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp210 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp211 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp212 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp213 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp214 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp215 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp216 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp217 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp218 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp219 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp220 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp221 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp222 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp223 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp224 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp225 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp226 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp227 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp228 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp229 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp230 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp231 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp232 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp233 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp234 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp235 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp236 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp237 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp238 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp239 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp240 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp241 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp242 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp243 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp244 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp245 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp246 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp247 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp248 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp249 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp250 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp251 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp252 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp253 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp254 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp255 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp256 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp257 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp258 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp259 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp260 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp261 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp262 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp263 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp264 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp265 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp266 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp267 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp268 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp269 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp270 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp271 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp272 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp273 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp274 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp275 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp276 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp277 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp278 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp279 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp280 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp281 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp282 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp283 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp284 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp285 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp286 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp287 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp288 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp289 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp290 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp291 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp292 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp293 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp294 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp295 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp296 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp297 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp298 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp299 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp300 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp301 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp302 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp303 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp304 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp305 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp306 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp307 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp308 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp309 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp310 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp311 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp312 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp313 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp314 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp315 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp316 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp317 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp318 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp319 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp320 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp321 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp322 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp323 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp324 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp325 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp326 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp327 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp328 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp329 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp330 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp331 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp332 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp333 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp334 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp335 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp336 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp337 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp338 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp339 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp340 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp341 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp342 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp343 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp344 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp345 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp346 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp347 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp348 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp349 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp350 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp351 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp352 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp353 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp354 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp355 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp356 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp357 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp358 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp359 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp360 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp361 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp362 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp363 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp364 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp365 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp366 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp367 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp368 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp369 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp370 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp371 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp372 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp373 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp374 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp375 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp376 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp377 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp378 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp379 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp380 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp381 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp382 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp383 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp384 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp385 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp386 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp387 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp388 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp389 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp390 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp391 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp392 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp393 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp394 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp395 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp396 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp397 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp398 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp399 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp400 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp401 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp402 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp403 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp404 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp405 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp406 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp407 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp408 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp409 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp410 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp411 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp412 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp413 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp414 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp415 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp416 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp417 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp418 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp419 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp420 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp421 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp422 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp423 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp424 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp425 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp426 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp427 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp428 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp429 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp430 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp431 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp432 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp433 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp434 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp435 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp436 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp437 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp438 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp439 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp440 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp441 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp442 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp443 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp444 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp445 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp446 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp447 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp448 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp449 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp450 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp451 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp452 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp453 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp454 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp455 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp456 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp457 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp458 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp459 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp460 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp461 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp462 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp463 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp464 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp465 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp466 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp467 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp468 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp469 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp470 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp471 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp472 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp473 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp474 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp475 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp476 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp477 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp478 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp479 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp480 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp481 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp482 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp483 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp484 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp485 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp486 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp487 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp488 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp489 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp490 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp491 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp492 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp493 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp494 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp495 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp496 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp497 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp498 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp499 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp500 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp501 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp502 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp503 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp504 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp505 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp506 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp507 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp508 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp509 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp510 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp511 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp512 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp513 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp514 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp515 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp516 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp517 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp518 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp519 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp520 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp521 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp522 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp523 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp524 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp525 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp526 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp527 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp528 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp529 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp530 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp531 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp532 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp533 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp534 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp535 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp536 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp537 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp538 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp539 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp540 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp541 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp542 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp543 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp544 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp545 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp546 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp547 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp548 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp549 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp550 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp551 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp552 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp553 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp554 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp555 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp556 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp557 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp558 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp559 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp560 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp561 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp562 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp563 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp564 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp565 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp566 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp567 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp568 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp569 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp570 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp571 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp572 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp573 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp574 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp575 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp576 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp577 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp578 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp579 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp580 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp581 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp582 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp583 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp584 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp585 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp586 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp587 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
# ...
#  'khpp622 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp623 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp624 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp625 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp626 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp627 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp628 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp629 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp630 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp631 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp632 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp633 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp634 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp635 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp636 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp637 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp638 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp639 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp640 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp641 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp642 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp643 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp644 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp645 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp646 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp647 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp648 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp649 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp650 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp651 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp652 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp653 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp654 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp655 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp656 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp657 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp658 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp659 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp660 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp661 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp662 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp663 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp664 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp665 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp666 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp667 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp668 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp669 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp670 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp671 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp672 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp673 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp674 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp675 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp676 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp677 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp678 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp679 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp680 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'crfac_blu log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_gre log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_lu1 log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_red log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_yel log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'f1_blu log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_gre log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_red log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_yel log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f2_blu log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_gre log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_red log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_yel log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'gamma_blu log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_gre log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_lu1 log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_red log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_yel log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'ks_blu log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_gre log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_lu1 log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_red log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_yel log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'm_blu log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_gre log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_lu1 log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_red log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_yel log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'mvol_blu log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_gre log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_lu1 log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_red log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_yel log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'of_blu log factor 1.0 0.1 5.0 lr_off 1.0 135.0\n',
#  'of_gre log factor 4.6 0.1 8.0 lr_off 1.0 128.0\n',
#  'of_red log factor 3.0 0.1 6.5 lr_off 1.0 137.5\n',
#  'of_yel log factor 3.0 0.1 6.0 lr_off 1.0 136.0\n',
#  'p_blu log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_gre log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_red log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_yel log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'vol_blu log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_gre log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_lu1 log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_red log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_yel log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'rchmulpp001 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp002 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp003 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp004 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp005 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp006 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp007 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp008 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp009 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp010 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp011 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp012 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp013 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp014 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp015 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp016 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp017 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp018 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp019 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp020 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp021 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp022 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp023 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp024 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp025 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp026 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp027 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp028 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp029 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp030 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp031 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp032 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp033 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp034 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp035 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp036 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp037 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp038 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp039 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp040 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp041 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp042 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp043 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp044 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp045 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp046 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp047 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp048 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp049 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp050 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp051 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp052 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp053 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp054 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp055 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp056 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp057 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp058 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp059 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp060 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp061 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp062 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp063 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp064 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp065 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp066 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp067 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp068 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp069 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp070 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp071 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp072 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp073 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp074 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp075 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp076 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp077 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp078 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp079 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp080 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp081 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp082 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp083 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp084 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp085 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp086 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp087 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp088 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp089 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp090 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp091 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp092 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp093 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp094 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp095 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp096 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp097 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp098 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp099 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp100 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp101 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp102 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp103 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp104 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp105 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp106 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp107 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp108 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp109 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp110 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp111 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp112 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp113 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp114 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp115 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp116 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp117 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp118 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp119 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp120 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp121 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp122 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp123 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp124 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp125 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp126 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp127 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp128 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp129 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp130 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp131 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp132 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp133 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp134 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp135 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp136 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp137 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp138 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp139 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp140 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp141 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp142 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp143 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp144 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp145 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp146 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp147 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp148 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp149 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp150 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp151 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp152 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp153 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp154 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp155 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp156 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp157 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp158 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp159 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp160 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp161 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp162 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp163 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  ...]

# %%
lsqr_strt, lsqr_stop = pestfile.index('* parameter groups\n'), pestfile.index('* parameter groups\n')

# %%
pestfile[lsqr_strt:lsqr_stop] = lsqr

# %%
pestfile
# Out:
# ['pcf\n',
#  '* control data\n',
#  'restart regularisation\n',
#  '    1719  172899      28    1719      43\n',
#  '13 15 single point\n',
#  ' 10.0  -3.0  0.3  0.03  10  lamforgive\n',
#  ' 10.0  10.0  0.001\n',
#  ' 0.1\n',
#  '0 0.005 4 4 0.005 4\n',
#  ' 0  0  0\n',
#  '* singular value decomposition\n',
#  '0\n',
#  '  5000  5e-7\n',
#  '0\n',
#  '* lsqr\n',
#  '1\n',
#  '1.0E-4 1.0E-4 1000.0 6876\n',
#  '1\n',
#  '* parameter groups\n',
#  'ghbcbl relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcgr relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcre relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbcye relative 0.015 0.0 switch 2 parabolic\n',
#  'ghbmul relative 0.015 0.0 switch 2 parabolic\n',
#  'khpp relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_cf relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_f1 relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_f2 relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_gam relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_ks relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_m relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_mvl relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_off relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_pow relative 0.015 0.0 switch 2 parabolic\n',
#  'lr_vol relative 0.015 0.0 switch 2 parabolic\n',
#  'rchmul relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrbth relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrgrd relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrinf relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrman relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrrhk relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtpe relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtpo relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrtps relative 0.015 0.0 switch 2 parabolic\n',
#  'sfrwid relative 0.015 0.0 switch 2 parabolic\n',
#  'sr1mul relative 0.015 0.0 switch 2 parabolic\n',
#  'sypp relative 0.015 0.0 switch 2 parabolic\n',
#  '* parameter data\n',
#  'ghbcblupp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp16 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp17 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp18 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcblupp19 log factor 86.40000 1.0000000E-05 10000.00 ghbcbl 1.0 0.0\n',
#  'ghbcgrepp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcgrepp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcgr 1.0 0.0\n',
#  'ghbcredpp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcredpp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcre 1.0 0.0\n',
#  'ghbcyelpp01 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp02 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp03 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp04 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp05 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp06 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp07 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp08 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp09 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp10 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp11 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp12 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp13 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp14 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp15 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp16 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp17 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbcyelpp18 log factor 86.40000 1.0000000E-05 10000.00 ghbcye 1.0 0.0\n',
#  'ghbbluemult log factor 1.0000000E-02 1.0000000E-03 1.000000 ghbmul 1.0 0.0\n',
#  'ghbyellomult log factor 1.0000000E-02 1.0000000E-03 1.000000 ghbmul 1.0 0.0\n',
#  'khpp001 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp002 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp003 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp004 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp005 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp006 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp007 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp008 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp009 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp010 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp011 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp012 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp013 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp014 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp015 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp016 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp017 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp018 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp019 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp020 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp021 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp022 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp023 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp024 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp025 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp026 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp027 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp028 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp029 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp030 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp031 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp032 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp033 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp034 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp035 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp036 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp037 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp038 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp039 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp040 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp041 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp042 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp043 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp044 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp045 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp046 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp047 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp048 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp049 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp050 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp051 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp052 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp053 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp054 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp055 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp056 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp057 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp058 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp059 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp060 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp061 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp062 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp063 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp064 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp065 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp066 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp067 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp068 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp069 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp070 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp071 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp072 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp073 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp074 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp075 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp076 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp077 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp078 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp079 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp080 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp081 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp082 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp083 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp084 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp085 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp086 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp087 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp088 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp089 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp090 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp091 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp092 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp093 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp094 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp095 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp096 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp097 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp098 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp099 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp100 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp101 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp102 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp103 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp104 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp105 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp106 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp107 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp108 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp109 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp110 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp111 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp112 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp113 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp114 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp115 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp116 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp117 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp118 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp119 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp120 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp121 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp122 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp123 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp124 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp125 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp126 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp127 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp128 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp129 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp130 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp131 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp132 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp133 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp134 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp135 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp136 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp137 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp138 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp139 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp140 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp141 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp142 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp143 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp144 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp145 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp146 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp147 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp148 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp149 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp150 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp151 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp152 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp153 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp154 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp155 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp156 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp157 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp158 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp159 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp160 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp161 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp162 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp163 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp164 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp165 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp166 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp167 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp168 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp169 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp170 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp171 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp172 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp173 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp174 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp175 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp176 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp177 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp178 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp179 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp180 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp181 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp182 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp183 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp184 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp185 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp186 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp187 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp188 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp189 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp190 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp191 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp192 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp193 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp194 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp195 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp196 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp197 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp198 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp199 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp200 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp201 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp202 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp203 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp204 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp205 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp206 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp207 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp208 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp209 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp210 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp211 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp212 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp213 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp214 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp215 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp216 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp217 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp218 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp219 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp220 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp221 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp222 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp223 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp224 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp225 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp226 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp227 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp228 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp229 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp230 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp231 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp232 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp233 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp234 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp235 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp236 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp237 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp238 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp239 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp240 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp241 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp242 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp243 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp244 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp245 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp246 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp247 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp248 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp249 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp250 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp251 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp252 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp253 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp254 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp255 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp256 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp257 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp258 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp259 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp260 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp261 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp262 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp263 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp264 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp265 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp266 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp267 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp268 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp269 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp270 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp271 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp272 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp273 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp274 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp275 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp276 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp277 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp278 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp279 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp280 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp281 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp282 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp283 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp284 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp285 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp286 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp287 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp288 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp289 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp290 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp291 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp292 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp293 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp294 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp295 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp296 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp297 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp298 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp299 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp300 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp301 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp302 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp303 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp304 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp305 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp306 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp307 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp308 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp309 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp310 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp311 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp312 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp313 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp314 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp315 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp316 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp317 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp318 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp319 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp320 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp321 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp322 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp323 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp324 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp325 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp326 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp327 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp328 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp329 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp330 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp331 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp332 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp333 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp334 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp335 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp336 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp337 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp338 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp339 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp340 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp341 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp342 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp343 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp344 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp345 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp346 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp347 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp348 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp349 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp350 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp351 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp352 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp353 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp354 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp355 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp356 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp357 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp358 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp359 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp360 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp361 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp362 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp363 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp364 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp365 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp366 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp367 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp368 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp369 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp370 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp371 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp372 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp373 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp374 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp375 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp376 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp377 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp378 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp379 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp380 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp381 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp382 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp383 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp384 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp385 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp386 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp387 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp388 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp389 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp390 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp391 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp392 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp393 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp394 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp395 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp396 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp397 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp398 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp399 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp400 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp401 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp402 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp403 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp404 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp405 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp406 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp407 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp408 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp409 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp410 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp411 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp412 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp413 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp414 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp415 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp416 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp417 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp418 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp419 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp420 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp421 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp422 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp423 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp424 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp425 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp426 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp427 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp428 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp429 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp430 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp431 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp432 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp433 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp434 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp435 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp436 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp437 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp438 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp439 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp440 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp441 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp442 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp443 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp444 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp445 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp446 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp447 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp448 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp449 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp450 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp451 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp452 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp453 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp454 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp455 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp456 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp457 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp458 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp459 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp460 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp461 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp462 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp463 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp464 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp465 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp466 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp467 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp468 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp469 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp470 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp471 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp472 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp473 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp474 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp475 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp476 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp477 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp478 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp479 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp480 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp481 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp482 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp483 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp484 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp485 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp486 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp487 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp488 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp489 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp490 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp491 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp492 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp493 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp494 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp495 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp496 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp497 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp498 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp499 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp500 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp501 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp502 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp503 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp504 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp505 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp506 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp507 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp508 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp509 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp510 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp511 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp512 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp513 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp514 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp515 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp516 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp517 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp518 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp519 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp520 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp521 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp522 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp523 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp524 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp525 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp526 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp527 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp528 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp529 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp530 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp531 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp532 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp533 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp534 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp535 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp536 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp537 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp538 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp539 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp540 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp541 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp542 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp543 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp544 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp545 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp546 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp547 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp548 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp549 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp550 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp551 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp552 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp553 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp554 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp555 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp556 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp557 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp558 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp559 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp560 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp561 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp562 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp563 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp564 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp565 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp566 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp567 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp568 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp569 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp570 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp571 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp572 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp573 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp574 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp575 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp576 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp577 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp578 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp579 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp580 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp581 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp582 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp583 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp584 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp585 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp586 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
# ...
#  'khpp618 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp619 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp620 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp621 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp622 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp623 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp624 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp625 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp626 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp627 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp628 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp629 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp630 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp631 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp632 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp633 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp634 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp635 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp636 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp637 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp638 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp639 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp640 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp641 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp642 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp643 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp644 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp645 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp646 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp647 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp648 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp649 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp650 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp651 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp652 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp653 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp654 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp655 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp656 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp657 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp658 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp659 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp660 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp661 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp662 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp663 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp664 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp665 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp666 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp667 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp668 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp669 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp670 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp671 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp672 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp673 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp674 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp675 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp676 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp677 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp678 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp679 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'khpp680 log factor 86.40000 1.0000000E-05 10000.00 khpp 1.0 0.0\n',
#  'crfac_blu log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_gre log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_lu1 log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_red log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'crfac_yel log factor 2.207 0.01 10.0 lr_cf 1.0 0.0\n',
#  'f1_blu log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_gre log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_red log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f1_yel log factor 1.06 0.1 50.0 lr_f1 1.0 0.0\n',
#  'f2_blu log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_gre log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_red log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'f2_yel log factor 0.83 0.01 100.0 lr_f2 1.0 0.0\n',
#  'gamma_blu log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_gre log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_lu1 log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_red log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'gamma_yel log factor 2.07 0.01 100.0 lr_gam 1.0 0.0\n',
#  'ks_blu log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_gre log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_lu1 log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_red log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'ks_yel log factor 153.0 0.001 1000.0 lr_ks 1.0 0.0\n',
#  'm_blu log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_gre log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_lu1 log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_red log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'm_yel log factor 0.17 0.01 2.0 lr_m 1.0 0.0\n',
#  'mvol_blu log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_gre log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_lu1 log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_red log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'mvol_yel log factor 0.54 0.35 1.0 lr_mvl 1.0 0.0\n',
#  'of_blu log factor 1.0 0.1 5.0 lr_off 1.0 135.0\n',
#  'of_gre log factor 4.6 0.1 8.0 lr_off 1.0 128.0\n',
#  'of_red log factor 3.0 0.1 6.5 lr_off 1.0 137.5\n',
#  'of_yel log factor 3.0 0.1 6.0 lr_off 1.0 136.0\n',
#  'p_blu log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_gre log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_red log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'p_yel log factor 0.72 0.01 100.0 lr_pow 1.0 0.0\n',
#  'vol_blu log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_gre log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_lu1 log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_red log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'vol_yel log factor 0.268 0.01 0.35 lr_vol 1.0 0.0\n',
#  'rchmulpp001 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp002 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp003 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp004 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp005 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp006 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp007 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp008 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp009 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp010 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp011 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp012 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp013 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp014 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp015 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp016 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp017 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp018 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp019 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp020 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp021 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp022 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp023 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp024 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp025 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp026 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp027 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp028 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp029 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp030 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp031 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp032 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp033 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp034 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp035 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp036 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp037 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp038 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp039 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp040 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp041 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp042 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp043 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp044 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp045 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp046 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp047 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp048 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp049 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp050 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp051 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp052 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp053 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp054 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp055 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp056 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp057 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp058 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp059 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp060 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp061 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp062 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp063 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp064 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp065 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp066 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp067 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp068 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp069 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp070 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp071 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp072 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp073 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp074 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp075 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp076 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp077 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp078 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp079 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp080 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp081 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp082 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp083 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp084 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp085 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp086 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp087 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp088 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp089 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp090 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp091 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp092 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp093 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp094 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp095 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp096 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp097 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp098 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp099 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp100 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp101 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp102 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp103 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp104 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp105 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp106 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp107 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp108 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp109 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp110 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp111 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp112 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp113 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp114 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp115 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp116 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp117 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp118 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp119 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp120 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp121 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp122 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp123 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp124 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp125 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp126 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp127 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp128 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp129 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp130 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp131 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp132 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp133 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp134 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp135 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp136 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp137 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp138 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp139 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp140 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp141 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp142 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp143 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp144 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp145 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp146 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp147 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp148 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp149 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp150 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp151 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp152 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp153 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp154 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp155 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp156 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp157 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp158 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  'rchmulpp159 log factor 1.0 0.1 10.0 rchmul 1.0 0.0\n',
#  ...]

# %% [markdown]
# #### Adjust uptestmin:

# %%
temp_row = pestfile[5].split()
display(temp_row)
# Out:
# ['10.0', '-3.0', '0.3', '0.03', '10', 'lamforgive']

# %%
temp_row.append('uptestmin=30\n') #why 30?

# %%
temp_row
# Out:
# ['10.0', '-3.0', '0.3', '0.03', '10', 'lamforgive', 'uptestmin=30\n']

# %%
new_row = ' '.join(temp_row)
display(new_row)
# Out:
# '10.0 -3.0 0.3 0.03 10 lamforgive uptestmin=30\n'

# %%
pestfile[5] = new_row

# %% [markdown]
# #### Adjust output settings:

# %%
temp_row = pestfile[9].split()
display(temp_row)
# Out:
# ['0', '0', '0']

# %%
temp_row.append('parsaveitn')
temp_row.append('reisaveitn\n')

# %%
temp_row
# Out:
# ['0', '0', '0', 'parsaveitn', 'reisaveitn\n']

# %%
new_row = ' '.join(temp_row)
display(new_row)
# Out:
# '0 0 0 parsaveitn reisaveitn\n'

# %%
pestfile[9] = new_row

# %% [markdown]
# Temporariliy save the pestfile so that we can run `/hpstart` before porting to Linux for sure:

# %%
with open(os.path.join(pest_ws, 'calib1-wt-cov-linux.pst'), 'w') as file:
    for line in pestfile:
        file.write(line)

# %% [markdown]
# Copy calib1-wt-cov-linux.pst to agent0:

# %%
shutil.copyfile(os.path.join(pest_ws, 'calib1-wt-cov-linux.pst'), os.path.join(agent0_dir, 'pest', 'calib1-wt-cov-linux.pst'))
# Out:
# '..\\temp_ml_calib\\agent_dir\\agent0\\pest\\calib1-wt-cov-linux.pst'

# %%
p = subprocess.run(['i64pestchek', 'calib1-wt-cov-linux.pst'], cwd=pest_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
#  PESTCHEK Version 17.3. Watermark Numerical Computing.
#
#  Errors ----->
#  No errors encountered.
#
#  Warnings ----->
#  Only PEST_HP, or PEST when run with the "/hpstart" command line switch, can
#    accept a value for the UPTESTMIN control variable.
#  NOPTMAX provided as zero. No optimisation iterations will be carried out;
#    objective function and residuals will be recorded for initial parameter
#    estimates only.
#
#  Special warning ----->
#  The PEST control file appears to contain comments and/or lines that employ
#    PEST++ or PEST_HP input protocol. If a particular PEST utility program
#    objects to this file, strip the file of these features using the PSTCLEAN
#    utility.

# %% [markdown]
# Manually run `pest_hp_mkl calib1-wt-cov-linux.pst /h :4004` in pest_ws
#
# Manually run `agent_hp calib1-wt-cov-linux.pst /h %computername%:4004` in agent0_dir

# %% [markdown]
# #### Adjust model run command:

# %%
mlrun_index = pestfile.index('* model command line\n') + 1
pestfile[mlrun_index]
# Out:
# 'runmodel.bat\n'

# %%
pestfile[mlrun_index] = './runmodel.sh\n'

# %%
pestfile[mlrun_index]
# Out:
# './runmodel.sh\n'

# %% [markdown]
# #### Adapt model input/output to Linux format:

# %%
mlio_strt_index = pestfile.index('* model input/output\n') + 1

# %%
mlio_stop_index = pestfile.index('* prior information\n')

# %%
model_io = pestfile[mlio_strt_index:mlio_stop_index]
model_io
# Out:
# ['.\\template\\pps_cond.tpl ..\\runmodel\\preproc\\pps_cond.dat\n',
#  '.\\template\\pps_sy_rchmul.tpl ..\\runmodel\\preproc\\pps_sy_rchmul.dat\n',
#  '.\\template\\pps_sfr.tpl ..\\runmodel\\preproc\\pps_sfr.dat\n',
#  '.\\template\\pps_ghb.tpl ..\\runmodel\\preproc\\pps_ghb.dat\n',
#  '.\\template\\ghb_multiplier.tpl ..\\runmodel\\preproc\\ghb_multiplier.py\n',
#  '.\\template\\sfr_rainf_evapo_multiplier.tpl ..\\runmodel\\preproc\\sfr_rainf_evapo_multiplier.py\n',
#  '.\\template\\sfr_rtpmodel.tpl ..\\runmodel\\preproc\\sfr_rtpmodel.py\n',
#  '.\\template\\sfr_reach1_inflow.tpl ..\\runmodel\\model\\sfr_reach1_inflow.ts\n',
#  '.\\template\\lr_lu1.tpl ..\\runmodel\\lumprem\\lr_lu1.in\n',
#  '.\\template\\lr_red.tpl ..\\runmodel\\lumprem\\lr_red.in\n',
#  '.\\template\\lr_yellow.tpl ..\\runmodel\\lumprem\\lr_yellow.in\n',
#  '.\\template\\lr_green.tpl ..\\runmodel\\lumprem\\lr_green.in\n',
#  '.\\template\\lr_blue.tpl ..\\runmodel\\lumprem\\lr_blue.in\n',
#  '.\\instruction\\m_obs-head-all_ssf.ins ..\\runmodel\\postproc\\m_obs-head-all_ssf.ssf\n',
#  '.\\instruction\\m_obs-stage_ssf.ins ..\\runmodel\\postproc\\m_obs-stage_ssf.ssf\n',
#  '.\\instruction\\m_obs-gage1_ssf.ins ..\\runmodel\\postproc\\m_obs-gage1_ssf.ssf\n',
#  '.\\instruction\\m_obs-gage2_ssf.ins ..\\runmodel\\postproc\\m_obs-gage2_ssf.ssf\n',
#  '.\\instruction\\m_dh-head-stage1_ssf.ins ..\\runmodel\\postproc\\m_dh-head-stage1_ssf.ssf\n',
#  '.\\instruction\\m_obs-dts-synthetic_ssf.ins ..\\runmodel\\postproc\\m_obs-dts-synthetic_ssf.ssf\n',
#  '.\\instruction\\m_obs-of-synthetic_ssf.ins ..\\runmodel\\postproc\\m_obs-of-synthetic_ssf.ssf\n',
#  '.\\instruction\\m_obs-head-all_ssf_d.ins ..\\runmodel\\postproc\\m_obs-head-all_ssf_d.ssf\n',
#  '.\\instruction\\m_obs-stage_ssf_d.ins ..\\runmodel\\postproc\\m_obs-stage_ssf_d.ssf\n',
#  '.\\instruction\\m_obs-gage1_ssf_d.ins ..\\runmodel\\postproc\\m_obs-gage1_ssf_d.ssf\n',
#  '.\\instruction\\m_obs-gage2_ssf_d.ins ..\\runmodel\\postproc\\m_obs-gage2_ssf_d.ssf\n',
#  '.\\instruction\\m_pred-flux_ssf.ins ..\\runmodel\\postproc\\m_pred-flux_ssf.ssf\n',
#  '.\\instruction\\m_pred-outflow_ssf.ins ..\\runmodel\\postproc\\m_pred-outflow_ssf.ssf\n',
#  '.\\instruction\\m_flux-all_ssf.ins ..\\runmodel\\postproc\\m_flux-all_ssf.ssf\n',
#  '.\\instruction\\m_of-all_ssf.ins ..\\runmodel\\postproc\\m_of-all_ssf.ssf\n']

# %%
model_io_linux = [i.replace('\\', '/') for i in model_io]
model_io_linux
# Out:
# ['./template/pps_cond.tpl ../runmodel/preproc/pps_cond.dat\n',
#  './template/pps_sy_rchmul.tpl ../runmodel/preproc/pps_sy_rchmul.dat\n',
#  './template/pps_sfr.tpl ../runmodel/preproc/pps_sfr.dat\n',
#  './template/pps_ghb.tpl ../runmodel/preproc/pps_ghb.dat\n',
#  './template/ghb_multiplier.tpl ../runmodel/preproc/ghb_multiplier.py\n',
#  './template/sfr_rainf_evapo_multiplier.tpl ../runmodel/preproc/sfr_rainf_evapo_multiplier.py\n',
#  './template/sfr_rtpmodel.tpl ../runmodel/preproc/sfr_rtpmodel.py\n',
#  './template/sfr_reach1_inflow.tpl ../runmodel/model/sfr_reach1_inflow.ts\n',
#  './template/lr_lu1.tpl ../runmodel/lumprem/lr_lu1.in\n',
#  './template/lr_red.tpl ../runmodel/lumprem/lr_red.in\n',
#  './template/lr_yellow.tpl ../runmodel/lumprem/lr_yellow.in\n',
#  './template/lr_green.tpl ../runmodel/lumprem/lr_green.in\n',
#  './template/lr_blue.tpl ../runmodel/lumprem/lr_blue.in\n',
#  './instruction/m_obs-head-all_ssf.ins ../runmodel/postproc/m_obs-head-all_ssf.ssf\n',
#  './instruction/m_obs-stage_ssf.ins ../runmodel/postproc/m_obs-stage_ssf.ssf\n',
#  './instruction/m_obs-gage1_ssf.ins ../runmodel/postproc/m_obs-gage1_ssf.ssf\n',
#  './instruction/m_obs-gage2_ssf.ins ../runmodel/postproc/m_obs-gage2_ssf.ssf\n',
#  './instruction/m_dh-head-stage1_ssf.ins ../runmodel/postproc/m_dh-head-stage1_ssf.ssf\n',
#  './instruction/m_obs-dts-synthetic_ssf.ins ../runmodel/postproc/m_obs-dts-synthetic_ssf.ssf\n',
#  './instruction/m_obs-of-synthetic_ssf.ins ../runmodel/postproc/m_obs-of-synthetic_ssf.ssf\n',
#  './instruction/m_obs-head-all_ssf_d.ins ../runmodel/postproc/m_obs-head-all_ssf_d.ssf\n',
#  './instruction/m_obs-stage_ssf_d.ins ../runmodel/postproc/m_obs-stage_ssf_d.ssf\n',
#  './instruction/m_obs-gage1_ssf_d.ins ../runmodel/postproc/m_obs-gage1_ssf_d.ssf\n',
#  './instruction/m_obs-gage2_ssf_d.ins ../runmodel/postproc/m_obs-gage2_ssf_d.ssf\n',
#  './instruction/m_pred-flux_ssf.ins ../runmodel/postproc/m_pred-flux_ssf.ssf\n',
#  './instruction/m_pred-outflow_ssf.ins ../runmodel/postproc/m_pred-outflow_ssf.ssf\n',
#  './instruction/m_flux-all_ssf.ins ../runmodel/postproc/m_flux-all_ssf.ssf\n',
#  './instruction/m_of-all_ssf.ins ../runmodel/postproc/m_of-all_ssf.ssf\n']

# %%
pestfile[mlio_strt_index:mlio_stop_index] = model_io_linux

# %% [markdown]
# #### Adapt model covariance matrix references to Linux format:

# %%
obsgrp_strt_index = pestfile.index('* observation groups\n') + 1
obsgrp_stop_index = pestfile.index('* observation data\n')
obsgrp = pestfile[obsgrp_strt_index:obsgrp_stop_index]
obsgrp
# Out:
# ['heads\n',
#  'stage1\n',
#  'gage1\n',
#  'gage2\n',
#  'dh_hedstg\n',
#  '>@dts\n',
#  '>@of\n',
#  'heads_d\n',
#  'stage1_d\n',
#  'gage1_d\n',
#  'gage2_d\n',
#  'pfluxb\n',
#  'pofb\n',
#  'pfluxr\n',
#  'pofr\n',
#  ' regul_ghbcbl ..\\runmodel\\preproc\\cov_ghb_blue.mat\n',
#  ' regul_ghbcgr ..\\runmodel\\preproc\\cov_ghb_green.mat\n',
#  ' regul_ghbcre ..\\runmodel\\preproc\\cov_ghb_red.mat\n',
#  ' regul_ghbcye ..\\runmodel\\preproc\\cov_ghb_yellow.mat\n',
#  'regul_ghbmul\n',
#  ' regul_khpp   ..\\runmodel\\preproc\\cov_cond.mat\n',
#  'regul_lr_cf\n',
#  'regul_lr_f1\n',
#  'regul_lr_f2\n',
#  'regul_lr_gam\n',
#  'regul_lr_ks\n',
#  'regul_lr_m\n',
#  'regul_lr_mvl\n',
#  'regul_lr_off\n',
#  'regul_lr_pow\n',
#  'regul_lr_vol\n',
#  ' regul_rchmul ..\\runmodel\\preproc\\cov_sy_rchmul.mat\n',
#  ' regul_sfrbth ..\\runmodel\\preproc\\cov_sfr.mat\n',
#  ' regul_sfrgrd ..\\runmodel\\preproc\\cov_sfr.mat\n',
#  ' regul_sfrinf ..\\runmodel\\preproc\\cov_sfr_inf1.mat\n',
#  ' regul_sfrman ..\\runmodel\\preproc\\cov_sfr.mat\n',
#  ' regul_sfrrhk ..\\runmodel\\preproc\\cov_sfr.mat\n',
#  'regul_sfrtpe\n',
#  'regul_sfrtpo\n',
#  'regul_sfrtps\n',
#  ' regul_sfrwid ..\\runmodel\\preproc\\cov_sfr.mat\n',
#  'regul_sr1mul\n',
#  ' regul_sypp   ..\\runmodel\\preproc\\cov_sy_rchmul.mat\n']

# %%
obsgrp_linux = [i.replace('\\', '/') for i in obsgrp]
obsgrp_linux
# Out:
# ['heads\n',
#  'stage1\n',
#  'gage1\n',
#  'gage2\n',
#  'dh_hedstg\n',
#  '>@dts\n',
#  '>@of\n',
#  'heads_d\n',
#  'stage1_d\n',
#  'gage1_d\n',
#  'gage2_d\n',
#  'pfluxb\n',
#  'pofb\n',
#  'pfluxr\n',
#  'pofr\n',
#  ' regul_ghbcbl ../runmodel/preproc/cov_ghb_blue.mat\n',
#  ' regul_ghbcgr ../runmodel/preproc/cov_ghb_green.mat\n',
#  ' regul_ghbcre ../runmodel/preproc/cov_ghb_red.mat\n',
#  ' regul_ghbcye ../runmodel/preproc/cov_ghb_yellow.mat\n',
#  'regul_ghbmul\n',
#  ' regul_khpp   ../runmodel/preproc/cov_cond.mat\n',
#  'regul_lr_cf\n',
#  'regul_lr_f1\n',
#  'regul_lr_f2\n',
#  'regul_lr_gam\n',
#  'regul_lr_ks\n',
#  'regul_lr_m\n',
#  'regul_lr_mvl\n',
#  'regul_lr_off\n',
#  'regul_lr_pow\n',
#  'regul_lr_vol\n',
#  ' regul_rchmul ../runmodel/preproc/cov_sy_rchmul.mat\n',
#  ' regul_sfrbth ../runmodel/preproc/cov_sfr.mat\n',
#  ' regul_sfrgrd ../runmodel/preproc/cov_sfr.mat\n',
#  ' regul_sfrinf ../runmodel/preproc/cov_sfr_inf1.mat\n',
#  ' regul_sfrman ../runmodel/preproc/cov_sfr.mat\n',
#  ' regul_sfrrhk ../runmodel/preproc/cov_sfr.mat\n',
#  'regul_sfrtpe\n',
#  'regul_sfrtpo\n',
#  'regul_sfrtps\n',
#  ' regul_sfrwid ../runmodel/preproc/cov_sfr.mat\n',
#  'regul_sr1mul\n',
#  ' regul_sypp   ../runmodel/preproc/cov_sy_rchmul.mat\n']

# %%
pestfile[obsgrp_strt_index:obsgrp_stop_index] = obsgrp_linux

# %% [markdown]
# That should be it...

# %%
with open(os.path.join(pest_ws, 'calib1-wt-cov-linux.pst'), 'w') as file:
    for line in pestfile:
        file.write(line)

# %% [markdown]
# ### TODO
#
# Set JACUPDATE to positive integer (or to 999) see pestman to activate broyden updating.

# %% [markdown]
# Add Linux binaries

# %% [markdown]
# ## Manually change prior information pertaining to LUMPREM parameters
# Must be copied and pasted (overwrite) in the pestfile. Note that values may change if parameterization is changed.

# %%
'''
crfac_lu1     1.0 * log(crfac_lu1) =  0.3438023      1.0 regul_lr_cf
crfac_red     1.0 * log(crfac_red) - 1.0 * log(crfac_lu1) =  0.0      1.0 regul_lr_cf
crfac_yel     1.0 * log(crfac_yel) - 1.0 * log(crfac_lu1) =  0.0      1.0 regul_lr_cf
crfac_gre     1.0 * log(crfac_gre) - 1.0 * log(crfac_lu1) =  0.0      1.0 regul_lr_cf
crfac_blu     1.0 * log(crfac_blu) - 1.0 * log(crfac_lu1) =  0.0      1.0 regul_lr_cf
f1_red        1.0 * log(f1_red) =  2.5305865E-02  1.0 regul_lr_f1
f1_yel        1.0 * log(f1_yel) - 1.0 * log(f1_red) =  0.0  1.0 regul_lr_f1
f1_gre        1.0 * log(f1_gre) - 1.0 * log(f1_red) =  0.0  1.0 regul_lr_f1
f1_blu        1.0 * log(f1_blu) - 1.0 * log(f1_red) =  0.0  1.0 regul_lr_f1
f2_red        1.0 * log(f2_red) = -8.0921908E-02  1.0 regul_lr_f2
f2_yel        1.0 * log(f2_yel) - 1.0 * log(f2_red) = 0.0  1.0 regul_lr_f2
f2_gre        1.0 * log(f2_gre) - 1.0 * log(f2_red) = 0.0  1.0 regul_lr_f2
f2_blu        1.0 * log(f2_blu) - 1.0 * log(f2_red) = 0.0  1.0 regul_lr_f2
gamma_lu1     1.0 * log(gamma_lu1) =  0.3159703      1.0 regul_lr_gam
gamma_red     1.0 * log(gamma_red) - 1.0 * log(gamma_lu1) =  0.0      1.0 regul_lr_gam
gamma_yel     1.0 * log(gamma_yel) - 1.0 * log(gamma_lu1) =  0.0      1.0 regul_lr_gam
gamma_gre     1.0 * log(gamma_gre) - 1.0 * log(gamma_lu1) =  0.0      1.0 regul_lr_gam
gamma_blu     1.0 * log(gamma_blu) - 1.0 * log(gamma_lu1) =  0.0      1.0 regul_lr_gam
ks_lu1        1.0 * log(ks_lu1) =   2.184691      1.0 regul_lr_ks
ks_red        1.0 * log(ks_red) - 1.0 * log(ks_lu1) =   0.0      1.0 regul_lr_ks
ks_yel        1.0 * log(ks_yel) - 1.0 * log(ks_lu1) =   0.0      1.0 regul_lr_ks
ks_gre        1.0 * log(ks_gre) - 1.0 * log(ks_lu1) =   0.0      1.0 regul_lr_ks
ks_blu        1.0 * log(ks_blu) - 1.0 * log(ks_lu1) =   0.0      1.0 regul_lr_ks
m_lu1         1.0 * log(m_lu1) = -0.7695511      1.0 regul_lr_m
m_red         1.0 * log(m_red) - 1.0 * log(m_lu1) = 0.0      1.0 regul_lr_m
m_yel         1.0 * log(m_yel) - 1.0 * log(m_lu1) = 0.0      1.0 regul_lr_m
m_gre         1.0 * log(m_gre) - 1.0 * log(m_lu1) = 0.0      1.0 regul_lr_m
m_blu         1.0 * log(m_blu) - 1.0 * log(m_lu1) = 0.0      1.0 regul_lr_m
mvol_lu1      1.0 * log(mvol_lu1) = -0.2676062      1.0 regul_lr_mvl
mvol_red      1.0 * log(mvol_red) - 1.0 * log(mvol_lu1) = 0.0      1.0 regul_lr_mvl
mvol_yel      1.0 * log(mvol_yel) - 1.0 * log(mvol_lu1) = 0.0      1.0 regul_lr_mvl
mvol_gre      1.0 * log(mvol_gre) - 1.0 * log(mvol_lu1) = 0.0      1.0 regul_lr_mvl
mvol_blu      1.0 * log(mvol_blu) - 1.0 * log(mvol_lu1) = 0.0      1.0 regul_lr_mvl
of_red        1.0 * log(of_red) =  0.4771213      1.0 regul_lr_off
of_yel        1.0 * log(of_yel) =  0.4771213      1.0 regul_lr_off
of_gre        1.0 * log(of_gre) =  0.6627578      1.0 regul_lr_off
of_blu        1.0 * log(of_blu) =   0.000000      1.0 regul_lr_off
p_red         1.0 * log(p_red) = -0.1426675      1.0 regul_lr_pow
p_yel         1.0 * log(p_yel) - 1.0 * log(p_red) = 0.0      1.0 regul_lr_pow
p_gre         1.0 * log(p_gre) - 1.0 * log(p_red) = 0.0      1.0 regul_lr_pow
p_blu         1.0 * log(p_blu) - 1.0 * log(p_red) = 0.0      1.0 regul_lr_pow
vol_lu1       1.0 * log(vol_lu1) = -0.5718652      1.0 regul_lr_vol
vol_red       1.0 * log(vol_red) - 1.0 * log(vol_lu1) = 0.0      1.0 regul_lr_vol
vol_yel       1.0 * log(vol_yel) - 1.0 * log(vol_lu1) = 0.0      1.0 regul_lr_vol
vol_gre       1.0 * log(vol_gre) - 1.0 * log(vol_lu1) = 0.0      1.0 regul_lr_vol
vol_blu       1.0 * log(vol_blu) - 1.0 * log(vol_lu1) = 0.0      1.0 regul_lr_vol
'''
