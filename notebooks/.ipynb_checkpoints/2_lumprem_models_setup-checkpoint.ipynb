# %%
import os
import shutil
import subprocess
import numpy as np
import pandas as pd
import flopy
import pyemu
import lumpyrem as lr
from lumpyrem import run
from lumpyrem.lr2series import TimeSeries
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# c:\users\nat12nho\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
bins_pth = os.path.join('..', 'bins', 'win') if 'nt' in os.name else os.path.join('..', 'bins', 'linux') # Binaries

# %%
lr_ws = os.path.join('..', 'temp_lr_prep') # Lumprem model workspace.  Safe to delete.

# %%
lumprem_input_pth = os.path.join('..', 'data', 'lumprem_input') # Input data curated in a previous notebook
os.listdir(lumprem_input_pth)
# Out:
# ['evapot.dat', 'rainfall.dat']

# %%
if os.path.exists(lr_ws):
    shutil.rmtree(lr_ws)
os.mkdir(lr_ws)

# %%
for file in os.listdir(lumprem_input_pth):
    shutil.copyfile(lumprem_input_pth+'\\'+file, lr_ws+'\\'+file) #Works for Windows. Does it work for Linux?

# %%
os.listdir(lr_ws)
# Out:
# ['evapot.dat', 'rainfall.dat']

# %% [markdown]
# ## Setup recharge model
# What about EVT?

# %%
# initiate the model and write the in files. What about rbuf & mbuf?
# landuse model for recharge, evap
lr_lu1 = lr.lumprem.Model(
    model_name = 'lu1',
    workspace = lr_ws,
    irrigvolfrac = 0.0,
    rainfile = 'rainfall.dat',
    epotfile = 'evapot.dat',
    vol = 0.11,
    ks = 86.4
)

# %%
lr_lu1.write_model(
    start_date = '01/01/2016',
    end_date = '01/01/2020',
    noutdays = 208,
    nstep = 100,
    mxiter = 1000,
    tol = 1e-9,
)
lr_lu1.run_model(version=2)
# Out:
# LUMPREM model input file written to:
# ..\temp_lr_prep\lr_lu1.in
# PEST template file written to:
# ..\temp_lr_prep\lr_lu1.tpl
#
#  Enter name of LUMPREM input file:  Enter name for LUMPREM tabular output file:  Enter name for CSV output file (<Enter> if none):
#  - file lr_lu1.in read ok.
#  - file lumprem_variables.rec written ok.
#  - file rainfall.dat read ok.
#  - file evapot.dat read ok.
#  - file lr_lu1.out written ok.
#  - file lr_lu1.csv written ok.

# %%
# get model results
results = lr_lu1.get_results()
display(results.head())
# Out:
#    days  vol_upper  vol_lower  vol_drain  vol_macro  del_vol_upper  \
# 0     0   0.110000        0.0   0.000000        0.0       0.000000
# 1     7   0.066078        0.0   0.020938        0.0      -0.043922
# 2    14   0.060171        0.0   0.010483        0.0      -0.005906
# 3    21   0.052139        0.0   0.005112        0.0      -0.008032
# 4    28   0.062491        0.0   0.005603        0.0       0.010352
#
#    del_vol_lower  del_vol_drain  del_vol_macro  rainfall  ...  \
# 0            0.0       0.000000            0.0    0.0000  ...
# 1            0.0       0.020938            0.0    0.0044  ...
# 2            0.0      -0.010455            0.0    0.0090  ...
# 3            0.0      -0.005371            0.0    0.0000  ...
# 4            0.0       0.000491            0.0    0.0176  ...
#
#          workspace  maxvol_br  extravol_br  gamma_br  ks_br  m_br  l_br  \
# 0  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
# 1  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
# 2  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
# 3  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
# 4  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
#
#    vol_br  epotfile_br  epot_br_all
# 0     NaN          NaN          NaN
# 1     NaN          NaN          NaN
# 2     NaN          NaN          NaN
# 3     NaN          NaN          NaN
# 4     NaN          NaN          NaN
#
# [5 rows x 58 columns]

# %%
display(results.tail())
# Out:
#      days  vol_upper  vol_lower  vol_drain  vol_macro  del_vol_upper  \
# 204  1432   0.064140        0.0   0.017250        0.0      -0.001155
# 205  1439   0.079124        0.0   0.019147        0.0       0.014983
# 206  1446   0.065309        0.0   0.014572        0.0      -0.013814
# 207  1453   0.059402        0.0   0.009144        0.0      -0.005907
# 208  1461   0.056544        0.0   0.007061        0.0      -0.002858
#
#      del_vol_lower  del_vol_drain  del_vol_macro  rainfall  ...  \
# 204            0.0       0.004541            0.0    0.0242  ...
# 205            0.0       0.001898            0.0    0.0383  ...
# 206            0.0      -0.004575            0.0    0.0102  ...
# 207            0.0      -0.005428            0.0    0.0076  ...
# 208            0.0      -0.002083            0.0    0.0093  ...
#
#            workspace  maxvol_br  extravol_br  gamma_br  ks_br  m_br  l_br  \
# 204  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
# 205  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
# 206  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
# 207  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
# 208  ..\temp_lr_prep        NaN          NaN       NaN    NaN   NaN   NaN
#
#      vol_br  epotfile_br  epot_br_all
# 204     NaN          NaN          NaN
# 205     NaN          NaN          NaN
# 206     NaN          NaN          NaN
# 207     NaN          NaN          NaN
# 208     NaN          NaN          NaN
#
# [5 rows x 58 columns]

# %%
display(results.columns)
# Out:
# Index(['days', 'vol_upper', 'vol_lower', 'vol_drain', 'vol_macro',
#        'del_vol_upper', 'del_vol_lower', 'del_vol_drain', 'del_vol_macro',
#        'rainfall', 'irrigation', 'drain_upper', 'macro_upper', 'drain_lower',
#        'overflow_lower', 'total_rech', 'gw_withdrawal', 'net_recharge',
#        'runoff', 'pot_evap_upper', 'evap_upper', 'pot_evap_lower',
#        'evap_lower', 'gw_pot_evap', 'balance', 'elevation', 'depth-to-water',
#        'lumprem_model_name', 'rainfile', 'epotfile', 'vegfile', 'irrigfile',
#        'maxvol', 'irrigvolfrac', 'rdelay', 'mdelay', 'ks', 'M', 'L',
#        'mflowmax', 'offset', 'factor1', 'factor2', 'power', 'elevmin',
#        'elevmax', 'surface', 'vol', 'workspace', 'maxvol_br', 'extravol_br',
#        'gamma_br', 'ks_br', 'm_br', 'l_br', 'vol_br', 'epotfile_br',
#        'epot_br_all'],
#       dtype='object')

# %%
sum(results['evap_upper'])
# Out:
# 0.08687461247999999

# %%
sum(results['rainfall'])
# Out:
# 2.663600000000001

# %%
fig = plt.figure(figsize=(10, 6), dpi=50)
ax = fig.add_subplot(1, 1, 1)
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates
ax.set_title('lr_lu1 model', fontsize=18)

results.plot('days','net_recharge', ax=ax)
results.plot('days', 'gw_pot_evap', ax=ax)

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10, 6), dpi=50)
ax = fig.add_subplot(1, 1, 1)
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates
ax.set_title('lr_lu1 model', fontsize=18)

results.plot('days','rainfall', ax=ax)
results.plot('days', 'evap_upper', ax=ax)

plt.legend()
plt.show()

# %% [markdown]
# ## Setup GHB models

# %% [markdown]
# GHB Models:

# %%
initial_ghb_bheads = {
    'red': 140.0,
    'yellow': 139.0,
    'green': 133.0,
    'blue': 136.0,
}

# %%
lr_ghb_red = lr.lumprem.Model(
    model_name = 'red',
    workspace = lr_ws,
    factor1 = 10.0,
    factor2 = 1.0,
    power = 1.0,
    offset = 140.0, # Measured head in nearby well
    vol = 0.07,
    ks = 86.4,
    irrigvolfrac=0.0,
    rainfile = 'rainfall.dat',
    epotfile = 'evapot.dat',
)

# %%
lr_ghb_yellow = lr.lumprem.Model(
    model_name = 'yellow',
    workspace = lr_ws,
    factor1 = 10.0,
    factor2 = 1.0,
    power = 1.0,
    offset = 139.0,
    vol = 0.07,
    ks = 86.4,
    irrigvolfrac=0.0,
    rainfile = 'rainfall.dat',
    epotfile = 'evapot.dat',
)

# %%
lr_ghb_green = lr.lumprem.Model(
    model_name = 'green',
    workspace = lr_ws,
    factor1 = 10.0,
    factor2 = 1.0,
    power = 1.0,
    offset = 133.0,
    vol = 0.08,
    ks = 86.4,
    irrigvolfrac=0.0,
    rainfile = 'rainfall.dat',
    epotfile = 'evapot.dat',
)

# %%
lr_ghb_blue = lr.lumprem.Model(
    model_name = 'blue',
    workspace = lr_ws,
    factor1 = 10.0,
    factor2 = 1.0,
    power = 1,
    offset = 136.0,
    vol = 0.08,
    ks = 86.4,
    irrigvolfrac=0.0,
    rainfile = 'rainfall.dat',
    epotfile = 'evapot.dat',
)

# %%
ghb_models = [lr_ghb_red, lr_ghb_yellow, lr_ghb_green, lr_ghb_blue]
for model in ghb_models:
    model.write_model(
        start_date = '01/01/2016',
        end_date = '01/01/2020',
        noutdays=208,
        nstep = 100,
        mxiter = 1000,
        tol = 1e-9,
    )
    model.run_model(version=2)
# Out:
# LUMPREM model input file written to:
# ..\temp_lr_prep\lr_red.in
# PEST template file written to:
# ..\temp_lr_prep\lr_red.tpl
#
#  Enter name of LUMPREM input file:  Enter name for LUMPREM tabular output file:  Enter name for CSV output file (<Enter> if none):
#  - file lr_red.in read ok.
#  - file lumprem_variables.rec written ok.
#  - file rainfall.dat read ok.
#  - file evapot.dat read ok.
#  - file lr_red.out written ok.
#  - file lr_red.csv written ok.
#
# LUMPREM model input file written to:
# ..\temp_lr_prep\lr_yellow.in
# PEST template file written to:
# ..\temp_lr_prep\lr_yellow.tpl
#
#  Enter name of LUMPREM input file:  Enter name for LUMPREM tabular output file:  Enter name for CSV output file (<Enter> if none):
#  - file lr_yellow.in read ok.
#  - file lumprem_variables.rec written ok.
#  - file rainfall.dat read ok.
#  - file evapot.dat read ok.
#  - file lr_yellow.out written ok.
#  - file lr_yellow.csv written ok.
#
# LUMPREM model input file written to:
# ..\temp_lr_prep\lr_green.in
# PEST template file written to:
# ..\temp_lr_prep\lr_green.tpl
#
#  Enter name of LUMPREM input file:  Enter name for LUMPREM tabular output file:  Enter name for CSV output file (<Enter> if none):
#  - file lr_green.in read ok.
#  - file lumprem_variables.rec written ok.
#  - file rainfall.dat read ok.
#  - file evapot.dat read ok.
#  - file lr_green.out written ok.
#  - file lr_green.csv written ok.
#
# LUMPREM model input file written to:
# ..\temp_lr_prep\lr_blue.in
# PEST template file written to:
# ..\temp_lr_prep\lr_blue.tpl
#
#  Enter name of LUMPREM input file:  Enter name for LUMPREM tabular output file:  Enter name for CSV output file (<Enter> if none):
#  - file lr_blue.in read ok.
#  - file lumprem_variables.rec written ok.
#  - file rainfall.dat read ok.
#  - file evapot.dat read ok.
#  - file lr_blue.out written ok.
#  - file lr_blue.csv written ok.

# %%
lr_ghb_red_df = lr_ghb_red.get_results()

# %%
# plot the model results
import seaborn as sb
sb.lineplot(data=lr_ghb_red_df, x='days',y='elevation', alpha=0.5, label='o=136.0');

# %% [markdown]
# # load the simulation

# %%
org_model_ws = os.path.join('..', 'base_model_files')
os.listdir(org_model_ws)
# Out:
# ['ghbpp.dat',
#  'ghbpp.tpl',
#  'hagfors_1.cbb',
#  'hagfors_1.disv',
#  'hagfors_1.disv.grb',
#  'hagfors_1.disv_botm.txt',
#  'hagfors_1.disv_cell2d.txt',
#  'hagfors_1.disv_top.txt',
#  'hagfors_1.disv_vertices.txt',
#  'hagfors_1.ghb',
#  'hagfors_1.ghb_stress_period_data_1.txt',
#  'hagfors_1.hds',
#  'hagfors_1.ic',
#  'hagfors_1.ic_strt.txt',
#  'hagfors_1.ims',
#  'hagfors_1.lst',
#  'hagfors_1.nam',
#  'hagfors_1.npf',
#  'hagfors_1.npf_icelltype.txt',
#  'hagfors_1.npf_k.txt',
#  'hagfors_1.npf_k33.txt',
#  'hagfors_1.obs',
#  'hagfors_1.oc',
#  'hagfors_1.rch',
#  'hagfors_1.rch_stress_period_data_1.txt',
#  'hagfors_1.sfr',
#  'hagfors_1.sfr.bud',
#  'hagfors_1.sfr.obs',
#  'hagfors_1.sto',
#  'hagfors_1.sto_iconvert.txt',
#  'hagfors_1.sto_ss.txt',
#  'hagfors_1.sto_sy.txt',
#  'hagfors_1.tdis',
#  'head.obs.csv',
#  'mfsim.lst',
#  'mfsim.nam',
#  'sfr_gage.obs.csv',
#  'sfr_pred_leak.obs.csv',
#  'sfr_reach1_inflow.ts',
#  'sfr_reach_evaporation.ts',
#  'sfr_reach_rainfall.ts',
#  'sfr_rtp_initial.csv',
#  'sfr_segfile.dat',
#  'sfr_stage.obs.csv']

# %%
tmp_model_ws = os.path.join('..', 'temp_flopy_lumprem') # Safe to delete
if os.path.exists(tmp_model_ws):
    shutil.rmtree(tmp_model_ws)
shutil.copytree(org_model_ws,tmp_model_ws)
os.listdir(tmp_model_ws)
# Out:
# ['ghbpp.dat',
#  'ghbpp.tpl',
#  'hagfors_1.cbb',
#  'hagfors_1.disv',
#  'hagfors_1.disv.grb',
#  'hagfors_1.disv_botm.txt',
#  'hagfors_1.disv_cell2d.txt',
#  'hagfors_1.disv_top.txt',
#  'hagfors_1.disv_vertices.txt',
#  'hagfors_1.ghb',
#  'hagfors_1.ghb_stress_period_data_1.txt',
#  'hagfors_1.hds',
#  'hagfors_1.ic',
#  'hagfors_1.ic_strt.txt',
#  'hagfors_1.ims',
#  'hagfors_1.lst',
#  'hagfors_1.nam',
#  'hagfors_1.npf',
#  'hagfors_1.npf_icelltype.txt',
#  'hagfors_1.npf_k.txt',
#  'hagfors_1.npf_k33.txt',
#  'hagfors_1.obs',
#  'hagfors_1.oc',
#  'hagfors_1.rch',
#  'hagfors_1.rch_stress_period_data_1.txt',
#  'hagfors_1.sfr',
#  'hagfors_1.sfr.bud',
#  'hagfors_1.sfr.obs',
#  'hagfors_1.sto',
#  'hagfors_1.sto_iconvert.txt',
#  'hagfors_1.sto_ss.txt',
#  'hagfors_1.sto_sy.txt',
#  'hagfors_1.tdis',
#  'head.obs.csv',
#  'mfsim.lst',
#  'mfsim.nam',
#  'sfr_gage.obs.csv',
#  'sfr_pred_leak.obs.csv',
#  'sfr_reach1_inflow.ts',
#  'sfr_reach_evaporation.ts',
#  'sfr_reach_rainfall.ts',
#  'sfr_rtp_initial.csv',
#  'sfr_segfile.dat',
#  'sfr_stage.obs.csv']

# %%
ml_name = 'hagfors_1'

# %%
sim = flopy.mf6.MFSimulation.load(ml_name, 'mf6', os.path.join(bins_pth, 'mf6'), tmp_model_ws)
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package disv...
# WARNING: Unable to resolve dimension of ('gwf6', 'disv', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
#     loading package rch...
#     loading package ghb...
#     loading package sto...
#     loading package oc...
#     loading package npf...
#     loading package ic...
#     loading package sfr...
#     loading package obs...
#   loading ims package hagfors_1...

# %%
sim.run_simulation()
# Out:
# FloPy is using the following executable to run the model: ..\bins\win\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 01/22/2022
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Jan 22 2022 02:25:10 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.5.0
#                              Build 20211109_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/02/02 10:53:09
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     2    Time step:     2
#     Solving:  Stress period:     2    Time step:     3
#     Solving:  Stress period:     2    Time step:     4
#     Solving:  Stress period:     2    Time step:     5
#     Solving:  Stress period:     2    Time step:     6
#     Solving:  Stress period:     2    Time step:     7
#     Solving:  Stress period:     2    Time step:     8
#     Solving:  Stress period:     2    Time step:     9
#     Solving:  Stress period:     2    Time step:    10
#     Solving:  Stress period:     2    Time step:    11
#     Solving:  Stress period:     2    Time step:    12
#     Solving:  Stress period:     2    Time step:    13
#     Solving:  Stress period:     2    Time step:    14
#     Solving:  Stress period:     2    Time step:    15
#     Solving:  Stress period:     2    Time step:    16
#     Solving:  Stress period:     2    Time step:    17
#     Solving:  Stress period:     2    Time step:    18
#     Solving:  Stress period:     2    Time step:    19
#     Solving:  Stress period:     2    Time step:    20
#     Solving:  Stress period:     2    Time step:    21
#     Solving:  Stress period:     2    Time step:    22
#     Solving:  Stress period:     2    Time step:    23
#     Solving:  Stress period:     2    Time step:    24
#     Solving:  Stress period:     2    Time step:    25
#     Solving:  Stress period:     2    Time step:    26
#     Solving:  Stress period:     2    Time step:    27
#     Solving:  Stress period:     2    Time step:    28
#     Solving:  Stress period:     2    Time step:    29
#     Solving:  Stress period:     2    Time step:    30
#     Solving:  Stress period:     2    Time step:    31
#     Solving:  Stress period:     2    Time step:    32
#     Solving:  Stress period:     2    Time step:    33
#     Solving:  Stress period:     2    Time step:    34
#     Solving:  Stress period:     2    Time step:    35
#     Solving:  Stress period:     2    Time step:    36
#     Solving:  Stress period:     2    Time step:    37
#     Solving:  Stress period:     2    Time step:    38
#     Solving:  Stress period:     2    Time step:    39
#     Solving:  Stress period:     2    Time step:    40
#     Solving:  Stress period:     2    Time step:    41
#     Solving:  Stress period:     2    Time step:    42
#     Solving:  Stress period:     2    Time step:    43
#     Solving:  Stress period:     2    Time step:    44
#     Solving:  Stress period:     2    Time step:    45
#     Solving:  Stress period:     2    Time step:    46
#     Solving:  Stress period:     2    Time step:    47
#     Solving:  Stress period:     2    Time step:    48
#     Solving:  Stress period:     2    Time step:    49
#     Solving:  Stress period:     2    Time step:    50
#     Solving:  Stress period:     2    Time step:    51
#     Solving:  Stress period:     2    Time step:    52
#     Solving:  Stress period:     2    Time step:    53
#     Solving:  Stress period:     2    Time step:    54
#     Solving:  Stress period:     2    Time step:    55
#     Solving:  Stress period:     2    Time step:    56
#     Solving:  Stress period:     2    Time step:    57
#     Solving:  Stress period:     2    Time step:    58
#     Solving:  Stress period:     2    Time step:    59
#     Solving:  Stress period:     2    Time step:    60
#     Solving:  Stress period:     2    Time step:    61
#     Solving:  Stress period:     2    Time step:    62
#     Solving:  Stress period:     2    Time step:    63
#     Solving:  Stress period:     2    Time step:    64
#     Solving:  Stress period:     2    Time step:    65
#     Solving:  Stress period:     2    Time step:    66
#     Solving:  Stress period:     2    Time step:    67
#     Solving:  Stress period:     2    Time step:    68
#     Solving:  Stress period:     2    Time step:    69
#     Solving:  Stress period:     2    Time step:    70
#     Solving:  Stress period:     2    Time step:    71
#     Solving:  Stress period:     2    Time step:    72
#     Solving:  Stress period:     2    Time step:    73
#     Solving:  Stress period:     2    Time step:    74
#     Solving:  Stress period:     2    Time step:    75
#     Solving:  Stress period:     2    Time step:    76
#     Solving:  Stress period:     2    Time step:    77
#     Solving:  Stress period:     2    Time step:    78
#     Solving:  Stress period:     2    Time step:    79
#     Solving:  Stress period:     2    Time step:    80
#     Solving:  Stress period:     2    Time step:    81
#     Solving:  Stress period:     2    Time step:    82
#     Solving:  Stress period:     2    Time step:    83
#     Solving:  Stress period:     2    Time step:    84
#     Solving:  Stress period:     2    Time step:    85
#     Solving:  Stress period:     2    Time step:    86
#     Solving:  Stress period:     2    Time step:    87
#     Solving:  Stress period:     2    Time step:    88
#     Solving:  Stress period:     2    Time step:    89
#     Solving:  Stress period:     2    Time step:    90
#     Solving:  Stress period:     2    Time step:    91
#     Solving:  Stress period:     2    Time step:    92
#     Solving:  Stress period:     2    Time step:    93
#     Solving:  Stress period:     2    Time step:    94
#     Solving:  Stress period:     2    Time step:    95
#     Solving:  Stress period:     2    Time step:    96
#     Solving:  Stress period:     2    Time step:    97
#     Solving:  Stress period:     2    Time step:    98
#     Solving:  Stress period:     2    Time step:    99
#     Solving:  Stress period:     2    Time step:   100
#     Solving:  Stress period:     2    Time step:   101
#     Solving:  Stress period:     2    Time step:   102
#     Solving:  Stress period:     2    Time step:   103
#     Solving:  Stress period:     2    Time step:   104
#     Solving:  Stress period:     2    Time step:   105
#     Solving:  Stress period:     2    Time step:   106
#     Solving:  Stress period:     2    Time step:   107
#     Solving:  Stress period:     2    Time step:   108
#     Solving:  Stress period:     2    Time step:   109
#     Solving:  Stress period:     2    Time step:   110
#     Solving:  Stress period:     2    Time step:   111
#     Solving:  Stress period:     2    Time step:   112
#     Solving:  Stress period:     2    Time step:   113
#     Solving:  Stress period:     2    Time step:   114
#     Solving:  Stress period:     2    Time step:   115
#     Solving:  Stress period:     2    Time step:   116
#     Solving:  Stress period:     2    Time step:   117
#     Solving:  Stress period:     2    Time step:   118
#     Solving:  Stress period:     2    Time step:   119
#     Solving:  Stress period:     2    Time step:   120
#     Solving:  Stress period:     2    Time step:   121
#     Solving:  Stress period:     2    Time step:   122
#     Solving:  Stress period:     2    Time step:   123
#     Solving:  Stress period:     2    Time step:   124
#     Solving:  Stress period:     2    Time step:   125
#     Solving:  Stress period:     2    Time step:   126
#     Solving:  Stress period:     2    Time step:   127
#     Solving:  Stress period:     2    Time step:   128
#     Solving:  Stress period:     2    Time step:   129
#     Solving:  Stress period:     2    Time step:   130
#     Solving:  Stress period:     2    Time step:   131
#     Solving:  Stress period:     2    Time step:   132
#     Solving:  Stress period:     2    Time step:   133
#     Solving:  Stress period:     2    Time step:   134
#     Solving:  Stress period:     2    Time step:   135
#     Solving:  Stress period:     2    Time step:   136
#     Solving:  Stress period:     2    Time step:   137
#     Solving:  Stress period:     2    Time step:   138
#     Solving:  Stress period:     2    Time step:   139
#     Solving:  Stress period:     2    Time step:   140
#     Solving:  Stress period:     2    Time step:   141
#     Solving:  Stress period:     2    Time step:   142
#     Solving:  Stress period:     2    Time step:   143
#     Solving:  Stress period:     2    Time step:   144
#     Solving:  Stress period:     2    Time step:   145
#     Solving:  Stress period:     2    Time step:   146
#     Solving:  Stress period:     2    Time step:   147
#     Solving:  Stress period:     2    Time step:   148
#     Solving:  Stress period:     2    Time step:   149
#     Solving:  Stress period:     2    Time step:   150
#     Solving:  Stress period:     2    Time step:   151
#     Solving:  Stress period:     2    Time step:   152
#     Solving:  Stress period:     2    Time step:   153
#     Solving:  Stress period:     2    Time step:   154
#     Solving:  Stress period:     2    Time step:   155
#     Solving:  Stress period:     2    Time step:   156
#     Solving:  Stress period:     2    Time step:   157
#     Solving:  Stress period:     2    Time step:   158
#     Solving:  Stress period:     2    Time step:   159
#     Solving:  Stress period:     2    Time step:   160
#     Solving:  Stress period:     2    Time step:   161
#     Solving:  Stress period:     2    Time step:   162
#     Solving:  Stress period:     2    Time step:   163
#     Solving:  Stress period:     2    Time step:   164
#     Solving:  Stress period:     2    Time step:   165
#     Solving:  Stress period:     2    Time step:   166
#     Solving:  Stress period:     2    Time step:   167
#     Solving:  Stress period:     2    Time step:   168
#     Solving:  Stress period:     2    Time step:   169
#     Solving:  Stress period:     2    Time step:   170
#     Solving:  Stress period:     2    Time step:   171
#     Solving:  Stress period:     2    Time step:   172
#     Solving:  Stress period:     2    Time step:   173
#     Solving:  Stress period:     2    Time step:   174
#     Solving:  Stress period:     2    Time step:   175
#     Solving:  Stress period:     2    Time step:   176
#     Solving:  Stress period:     2    Time step:   177
#     Solving:  Stress period:     2    Time step:   178
#     Solving:  Stress period:     2    Time step:   179
#     Solving:  Stress period:     2    Time step:   180
#     Solving:  Stress period:     2    Time step:   181
#     Solving:  Stress period:     2    Time step:   182
#     Solving:  Stress period:     2    Time step:   183
#     Solving:  Stress period:     2    Time step:   184
#     Solving:  Stress period:     2    Time step:   185
#     Solving:  Stress period:     2    Time step:   186
#     Solving:  Stress period:     2    Time step:   187
#     Solving:  Stress period:     2    Time step:   188
#     Solving:  Stress period:     2    Time step:   189
#     Solving:  Stress period:     2    Time step:   190
#     Solving:  Stress period:     2    Time step:   191
#     Solving:  Stress period:     2    Time step:   192
#     Solving:  Stress period:     2    Time step:   193
#     Solving:  Stress period:     2    Time step:   194
#     Solving:  Stress period:     2    Time step:   195
#     Solving:  Stress period:     2    Time step:   196
#     Solving:  Stress period:     2    Time step:   197
#     Solving:  Stress period:     2    Time step:   198
#     Solving:  Stress period:     2    Time step:   199
#     Solving:  Stress period:     2    Time step:   200
#     Solving:  Stress period:     2    Time step:   201
#     Solving:  Stress period:     2    Time step:   202
#     Solving:  Stress period:     2    Time step:   203
#     Solving:  Stress period:     2    Time step:   204
#     Solving:  Stress period:     2    Time step:   205
#     Solving:  Stress period:     2    Time step:   206
#     Solving:  Stress period:     2    Time step:   207
#     Solving:  Stress period:     2    Time step:   208
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2022/02/02 10:53:20
#  Elapsed run time: 10.588 Seconds
#
#  Normal termination of simulation.
# (True, [])

# %%
gwf = sim.get_model(ml_name)

# %%
disv = gwf.get_package('disv')
rch = gwf.get_package('rch')
ghb = gwf.get_package('ghb')
sfr = gwf.get_package('sfr')

# %% [markdown]
# ## Prepare recharge (RCH) timeseries input

# %%
rch_ts = lr.lr2series.TimeSeries(
    ts_file='rch.ts',
    workspace=lr_ws,
    lr_models=[lr_lu1],
    ts_names=['rch'],
    lumprem_output_cols=['net_recharge'],
    methods=['linearend'],
    div_delta_t=True
)

# %%
rch_ts.write_ts()
# Out:
# MF6 timeseries file ..\temp_lr_prep\rch.ts.in written to:
# ..\temp_lr_prep\rch.ts.in
#  Enter name of LR2SERIES control file:
#  - reading file rch.ts.in...
#
#  - reading LUMPREM output file lr_lu1.out...
#  - file lr_lu1.out read ok.
#  - writing file rch.ts...
#  - file rch.ts written ok.
#
#  - file rch.ts.in read ok.

# %% [markdown]
# ### Manipulate RCH ts-file to time-average the first (steady state) output using TS6PROC

# %%
def write_script(filename, lines):

    with open(filename, 'a') as f:
        for line in lines:
            f.write(line)
            f.write('\n')

# %%
write_script(os.path.join(lr_ws, 'ts6rch.in'), [
'''
# Here is a comment

BEGIN FILES
  FILEIN  rch.ts
  FILEOUT rch_new.ts
END FILES

BEGIN PARAMETERS
END PARAMETERS

BEGIN PROCESSING

  avg = time_average_over_interval(rch_lu1,none,1.0,99999.0)
  
  rch_lu1 = assign_terms(rch_lu1, avg, 0.0, 0.0)

END PROCESSING

'''
])

# %%
p = subprocess.run(['ts6proc', 'ts6rch.in'], cwd=lr_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
#  TS6PROC Version 1.00. Watermark Numerical Computing.
#
#  - reading file rch.ts...
#  - file rch.ts read ok.
#
#  Processing: avg = time_average_over_interval(rch_...
#  Processing: rch_lu1 = assign_terms(rch_lu1, avg, ...
#
#  - writing file rch_new.ts...
#  - file rch_new.ts written ok.

# %% [markdown]
# Select non-ghb cells (cells can't both be rch and ghb):

# %%
#ghb_cell_ids cells in ghb cant be part of rch (will cause fortran error)
ghb_cell_ids = [i[0][1] for i in ghb.stress_period_data.data[0]]

# %% [markdown]
# Create rch TS for all non-ghb cells:

# %%
rchcells = np.array(list(range(disv.ncpl.data)), dtype=int)
rchcells[ghb_cell_ids] = -1
rch_spd = [
    ((0, rchcells[i]), 'rch_lu1', 1, 'rch') for i in range(disv.ncpl.data) if rchcells[i] > 0
]
rch_spd = {0: rch_spd}

# %% [markdown]
# Display the data-structure of the old recharge package:

# %%
rch.stress_period_data.data
# Out:
# {0: rec.array([((0, 23), 0.00054795, 1., 'rch'),
#             ((0, 24), 0.00054795, 1., 'rch'),
#             ((0, 25), 0.00054795, 1., 'rch'), ...,
#             ((0, 3007), 0.00054795, 1., 'rch'),
#             ((0, 3008), 0.00054795, 1., 'rch'),
#             ((0, 3009), 0.00054795, 1., 'rch')],
#            dtype=[('cellid', 'O'), ('recharge', '<f8'), ('multiplier', '<f8'), ('boundname', 'O')])}

# %% [markdown]
# Let's take a more detailed look at one of the stress periods:

# %%
rch.stress_period_data.data[0][:10]
# Current data structure is cellid, recharge
# Out:
# rec.array([((0, 23), 0.00054795, 1., 'rch'),
#            ((0, 24), 0.00054795, 1., 'rch'),
#            ((0, 25), 0.00054795, 1., 'rch'),
#            ((0, 26), 0.00054795, 1., 'rch'),
#            ((0, 27), 0.00054795, 1., 'rch'),
#            ((0, 28), 0.00054795, 1., 'rch'),
#            ((0, 29), 0.00054795, 1., 'rch'),
#            ((0, 30), 0.00054795, 1., 'rch'),
#            ((0, 31), 0.00054795, 1., 'rch'),
#            ((0, 32), 0.00054795, 1., 'rch')],
#           dtype=[('cellid', 'O'), ('recharge', '<f8'), ('multiplier', '<f8'), ('boundname', 'O')])

# %% [markdown]
# Remove old recharge package:

# %%
gwf.remove_package('rch')

# %% [markdown]
# Clean up stale files associated with the rch package:

# %%
for file in os.listdir(tmp_model_ws):
    if '.rch' in file:
        os.remove(os.path.join(tmp_model_ws, file))

# %% [markdown]
# Instantiate new recharge package:

# %%
rch = flopy.mf6.ModflowGwfrch(
    gwf,
    filename='{}.rch'.format(ml_name), 
    pname='rch',
    fixed_cell=True,
    auxiliary='MULTIPLIER',
    auxmultname='MULTIPLIER',
    print_input=True,
    print_flows=True, 
    save_flows=True,
    boundnames=True,
    stress_period_data=rch_spd
)

# %% [markdown]
# Display the data-structure of the **new** recharge package, using TS-file and multiplier:

# %%
rch.stress_period_data.data[0][:10]
# Current data structure is cellid, recharge
# Out:
# rec.array([((0, 23), 'rch_lu1', 1., 'rch'),
#            ((0, 24), 'rch_lu1', 1., 'rch'),
#            ((0, 25), 'rch_lu1', 1., 'rch'),
#            ((0, 26), 'rch_lu1', 1., 'rch'),
#            ((0, 27), 'rch_lu1', 1., 'rch'),
#            ((0, 28), 'rch_lu1', 1., 'rch'),
#            ((0, 29), 'rch_lu1', 1., 'rch'),
#            ((0, 30), 'rch_lu1', 1., 'rch'),
#            ((0, 31), 'rch_lu1', 1., 'rch'),
#            ((0, 32), 'rch_lu1', 1., 'rch')],
#           dtype=[('cellid', 'O'), ('recharge', 'O'), ('MULTIPLIER', '<f8'), ('boundname', 'O')])

# %% [markdown]
# Initialize TS-file:

# %%
# Initialize ts-file
rch.ts.initialize(filename='rch_new.ts')

# %% [markdown]
# ## Prepare streamflow routing (SFR) timeseries input
# Two TS-files will be created; reach rainfall input and reach evaporation. Both will be using data from the rch_lu1 model.

# %%
sfr_rain_ts = lr.lr2series.TimeSeries(
    ts_file='sfr_reach_rainfall.ts',
    workspace=lr_ws,
    lr_models=[lr_lu1],
    ts_names=['rainf'],
    lumprem_output_cols=['rainfall'],
    methods=['linearend'], # Not sure whether to use linearend or linear
    div_delta_t=True
)

# %%
sfr_evapo_ts = lr.lr2series.TimeSeries(
    ts_file='sfr_reach_evaporation.ts',
    workspace=lr_ws,
    lr_models=[lr_lu1],
    ts_names=['evapo'],
    lumprem_output_cols=['evap_upper'],
    methods=['linearend'], # Not sure whether to use linearend or linear
    div_delta_t=True
)

# %%
for ts_file in [sfr_rain_ts, sfr_evapo_ts]:
    ts_file.write_ts()
# Out:
# MF6 timeseries file ..\temp_lr_prep\sfr_reach_rainfall.ts.in written to:
# ..\temp_lr_prep\sfr_reach_rainfall.ts.in
#  Enter name of LR2SERIES control file:
#  - reading file sfr_reach_rainfall.ts.in...
#
#  - reading LUMPREM output file lr_lu1.out...
#  - file lr_lu1.out read ok.
#  - writing file sfr_reach_rainfall.ts...
#  - file sfr_reach_rainfall.ts written ok.
#
#  - file sfr_reach_rainfall.ts.in read ok.
#
# MF6 timeseries file ..\temp_lr_prep\sfr_reach_evaporation.ts.in written to:
# ..\temp_lr_prep\sfr_reach_evaporation.ts.in
#  Enter name of LR2SERIES control file:
#  - reading file sfr_reach_evaporation.ts.in...
#
#  - reading LUMPREM output file lr_lu1.out...
#  - file lr_lu1.out read ok.
#  - writing file sfr_reach_evaporation.ts...
#  - file sfr_reach_evaporation.ts written ok.
#
#  - file sfr_reach_evaporation.ts.in read ok.

# %% [markdown]
# Change the package data file so that TS files are called:

# %%
sfr_df = pd.DataFrame(sfr.perioddata.data[0])

# %%
sfr_df.loc[sfr_df['sfrsetting'] == 'rainfall', 'sfrsetting_data'] = 'rainf_lu1'
sfr_df.loc[sfr_df['sfrsetting'] == 'evaporation', 'sfrsetting_data'] = 'evapo_lu1'

# %%
sfr.perioddata = {0: sfr_df.to_records(index=None)}

# %% [markdown]
# Remove the ts files created in the previous notebook (the new ones will take their place):

# %%
os.remove(os.path.join(tmp_model_ws, 'sfr_reach_rainfall.ts'))
os.remove(os.path.join(tmp_model_ws, 'sfr_reach_evaporation.ts'))

# %% [markdown]
# ## Prepare general head boundary (GHB) timeseries input

# %% [markdown]
# Extend lumpyrem TimeSeries class (ugly hack but gets the job done):

# %%
class GHB_TS(TimeSeries):
    def write_ts(self):
        """Writes the MODFLOW6 timeseries file.

        Parameters
        ----------
        """
        #number of columns to include in the ts file
        count = len(self.ts_names)
        ts_file = os.path.join(self.workspace, self.ts_file+'.in')

        with open(ts_file, 'w') as f:
            for model in self.lr_models:
                model_name = model.lumprem_model_name
                f.write('READ_LUMPREM_OUTPUT_FILE lr_'+model_name+'.out '+str(count)+'\n')
                f.write('#  my_name     LUMPREM_name      divide_by_delta_t?\n\n')

                for col in range(count):
                    f.write("\t{0}\t\t{1}\t\t{2}".format('ghb_'+model_name, self.lumprem_output_cols[col],self.div_delta[col]+'\n'))
                f.write('\n\n')

            f.write('WRITE_MF6_TIME_SERIES_FILE '+self.ts_file+' '+str(count*len(self.lr_models))+' '+str(self.timeoffset)+'\n')
            f.write("#\t{0}\t\t{1}\t\t{2}\t\t{3}\t\t{4}".format('ts_name','scale','offset','mf6method','time_offset_method\n\n'))
            for model in self.lr_models:
                model_name = model.lumprem_model_name
                for col in range(count):
                        f.write("\t{0}\t\t{1}\t\t{2}\t\t{3}\t{4}\t{5}".format('ghb_'+model_name, self.scales[col],self.offsets[col],self.methods[col], self.time_offset_method[col], '#'+model_name+'\n'))

        f.close()
        print('MF6 timeseries file '+ts_file+' written to:\n'+ts_file)
        
        #write ts file
        filename = self.ts_file
        path = self.workspace
        run.run_process('lr2series', commands=[filename+'.in'],path=path)

# %% [markdown]
# Write TS-file:

# %%
ghb_ts = GHB_TS(
    ts_file='ghb.ts',
    workspace=lr_ws,
    lr_models=ghb_models,
    ts_names=['ghb'],
    lumprem_output_cols=['elevation'],
    methods=['linear'],
    div_delta_t=False
)

# %%
ghb_ts.write_ts()
# Out:
# MF6 timeseries file ..\temp_lr_prep\ghb.ts.in written to:
# ..\temp_lr_prep\ghb.ts.in
#  Enter name of LR2SERIES control file:
#  - reading file ghb.ts.in...
#
#  - reading LUMPREM output file lr_red.out...
#  - file lr_red.out read ok.
#  - reading LUMPREM output file lr_yellow.out...
#  - file lr_yellow.out read ok.
#  - reading LUMPREM output file lr_green.out...
#  - file lr_green.out read ok.
#  - reading LUMPREM output file lr_blue.out...
#  - file lr_blue.out read ok.
#  - writing file ghb.ts...
#  - file ghb.ts written ok.
#
#  - file ghb.ts.in read ok.

# %% [markdown]
# ### Manipulate GHB ts-file to time-average the first (steady state) output using TS6PROC

# %%
write_script(os.path.join(lr_ws, 'ts6ghb.in'), [
'''
# Here is a comment

BEGIN FILES
  FILEIN  ghb.ts
  FILEOUT ghb_new.ts
END FILES

BEGIN PARAMETERS
END PARAMETERS

BEGIN PROCESSING

  avg_red = time_average_over_interval(ghb_red,none,1.0,99999.0)
  avg_yellow = time_average_over_interval(ghb_yellow,none,1.0,99999.0)
  avg_green = time_average_over_interval(ghb_green,none,1.0,99999.0)
  avg_blue = time_average_over_interval(ghb_blue,none,1.0,99999.0)
  
  ghb_red = assign_terms(ghb_red, avg_red, 0.0, 0.0)
  ghb_yellow = assign_terms(ghb_yellow, avg_yellow, 0.0, 0.0)
  ghb_green = assign_terms(ghb_green, avg_green, 0.0, 0.0)
  ghb_blue = assign_terms(ghb_blue, avg_blue, 0.0, 0.0)

END PROCESSING

'''
])

# %%
p = subprocess.run(['ts6proc', 'ts6ghb.in'], cwd=lr_ws, stdout=subprocess.PIPE, text=True)
for row in p.stdout.split('\n'):
    print(row)
# Out:
#  TS6PROC Version 1.00. Watermark Numerical Computing.
#
#  - reading file ghb.ts...
#  - file ghb.ts read ok.
#
#  Processing: avg_red = time_average_over_interval(...
#  Processing: avg_yellow = time_average_over_interv...
#  Processing: avg_green = time_average_over_interva...
#  Processing: avg_blue = time_average_over_interval...
#  Processing: ghb_red = assign_terms(ghb_red, avg_r...
#  Processing: ghb_yellow = assign_terms(ghb_yellow,...
#  Processing: ghb_green = assign_terms(ghb_green, a...
#  Processing: ghb_blue = assign_terms(ghb_blue, avg...
#
#  - writing file ghb_new.ts...
#  - file ghb_new.ts written ok.

# %% [markdown]
# Make elevation/bhead a multiplier of the TS-data...?????!?!?!?!?

# %% [markdown]
# Display the data-structure of the old GHB package:

# %%
# Current data structure is cellid, bhead, cond, boundname
ghb.stress_period_data.data
# Out:
# {0: rec.array([((0, 343), 142.5, 86.4, 1.        , 'red'),
#             ((0, 344), 142.5, 86.4, 1.        , 'red'),
#             ((0, 427), 142.5, 86.4, 1.        , 'red'),
#             ((0, 428), 142.5, 86.4, 1.        , 'red'),
#             ((0, 503), 142.5, 86.4, 1.        , 'red'),
#             ((0, 504), 142.5, 86.4, 1.        , 'red'),
#             ((0, 583), 142.5, 86.4, 1.        , 'red'),
#             ((0, 584), 142.5, 86.4, 1.        , 'red'),
#             ((0, 664), 142.5, 86.4, 1.        , 'red'),
#             ((0, 665), 142.5, 86.4, 1.        , 'red'),
#             ((0, 746), 142.5, 86.4, 1.        , 'red'),
#             ((0, 747), 142.5, 86.4, 1.        , 'red'),
#             ((0, 829), 142.5, 86.4, 1.        , 'red'),
#             ((0, 830), 142.5, 86.4, 1.        , 'red'),
#             ((0, 913), 142.5, 86.4, 1.        , 'red'),
#             ((0, 999), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1081), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1165), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1254), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1348), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1435), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1533), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1627), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1744), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1827), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1900), 142.5, 86.4, 1.        , 'red'),
#             ((0, 1975), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2049), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2122), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2191), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2262), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2368), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2476), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2559), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2644), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2645), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2710), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2711), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2774), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2775), 142.5, 86.4, 1.        , 'red'),
#             ((0, 2767), 140. , 86.4, 1.        , 'yellow'),
#             ((0, 2768), 140. , 86.4, 0.98322034, 'yellow'),
#             ((0, 2769), 140. , 86.4, 0.96644068, 'yellow'),
#             ((0, 2770), 140. , 86.4, 0.94966102, 'yellow'),
#             ((0, 2771), 140. , 86.4, 0.93288136, 'yellow'),
#             ((0, 2772), 140. , 86.4, 0.91610169, 'yellow'),
#             ((0, 2773), 140. , 86.4, 0.89932203, 'yellow'),
#             ((0, 2840), 140. , 86.4, 0.88254237, 'yellow'),
#             ((0, 2841), 140. , 86.4, 0.86576271, 'yellow'),
#             ((0, 2842), 140. , 86.4, 0.84898305, 'yellow'),
#             ((0, 2898), 140. , 86.4, 0.83220339, 'yellow'),
#             ((0, 2899), 140. , 86.4, 0.81542373, 'yellow'),
#             ((0, 2900), 140. , 86.4, 0.79864407, 'yellow'),
#             ((0, 2902), 140. , 86.4, 0.78186441, 'yellow'),
#             ((0, 2951), 140. , 86.4, 0.76508475, 'yellow'),
#             ((0, 2952), 140. , 86.4, 0.74830508, 'yellow'),
#             ((0, 2953), 140. , 86.4, 0.73152542, 'yellow'),
#             ((0, 2954), 140. , 86.4, 0.71474576, 'yellow'),
#             ((0, 2988), 140. , 86.4, 0.6979661 , 'yellow'),
#             ((0, 2989), 140. , 86.4, 0.68118644, 'yellow'),
#             ((0, 2990), 140. , 86.4, 0.66440678, 'yellow'),
#             ((0, 2991), 140. , 86.4, 0.64762712, 'yellow'),
#             ((0, 2992), 140. , 86.4, 0.63084746, 'yellow'),
#             ((0, 2998), 140. , 86.4, 0.6140678 , 'yellow'),
#             ((0, 2999), 140. , 86.4, 0.59728814, 'yellow'),
#             ((0, 3000), 140. , 86.4, 0.58050847, 'yellow'),
#             ((0, 3001), 140. , 86.4, 0.56372881, 'yellow'),
#             ((0, 3002), 140. , 86.4, 0.54694915, 'yellow'),
#             ((0, 3003), 140. , 86.4, 0.53016949, 'yellow'),
#             ((0, 3004), 140. , 86.4, 0.51338983, 'yellow'),
#             ((0, 3010), 140. , 86.4, 0.49661017, 'yellow'),
#             ((0, 3011), 140. , 86.4, 0.47983051, 'yellow'),
#             ((0, 3012), 140. , 86.4, 0.46305085, 'yellow'),
#             ((0, 3013), 140. , 86.4, 0.44627119, 'yellow'),
#             ((0, 3014), 140. , 86.4, 0.42949153, 'yellow'),
#             ((0, 3015), 140. , 86.4, 0.41271186, 'yellow'),
#             ((0, 3016), 140. , 86.4, 0.3959322 , 'yellow'),
#             ((0, 3017), 140. , 86.4, 0.37915254, 'yellow'),
#             ((0, 3018), 140. , 86.4, 0.36237288, 'yellow'),
#             ((0, 3019), 140. , 86.4, 0.34559322, 'yellow'),
#             ((0, 3020), 140. , 86.4, 0.32881356, 'yellow'),
#             ((0, 3021), 140. , 86.4, 0.3120339 , 'yellow'),
#             ((0, 3022), 140. , 86.4, 0.29525424, 'yellow'),
#             ((0, 3023), 140. , 86.4, 0.27847458, 'yellow'),
#             ((0, 3024), 140. , 86.4, 0.26169492, 'yellow'),
#             ((0, 3025), 140. , 86.4, 0.24491525, 'yellow'),
#             ((0, 3026), 140. , 86.4, 0.22813559, 'yellow'),
#             ((0, 3027), 140. , 86.4, 0.21135593, 'yellow'),
#             ((0, 3028), 140. , 86.4, 0.19457627, 'yellow'),
#             ((0, 3029), 140. , 86.4, 0.17779661, 'yellow'),
#             ((0, 3030), 140. , 86.4, 0.16101695, 'yellow'),
#             ((0, 3031), 140. , 86.4, 0.14423729, 'yellow'),
#             ((0, 3032), 140. , 86.4, 0.12745763, 'yellow'),
#             ((0, 3033), 140. , 86.4, 0.11067797, 'yellow'),
#             ((0, 3034), 140. , 86.4, 0.09389831, 'yellow'),
#             ((0, 3035), 140. , 86.4, 0.07711864, 'yellow'),
#             ((0, 3036), 140. , 86.4, 0.06033898, 'yellow'),
#             ((0, 3037), 140. , 86.4, 0.04355932, 'yellow'),
#             ((0, 3038), 140. , 86.4, 0.02677966, 'yellow'),
#             ((0, 3039), 140. , 86.4, 0.01      , 'yellow'),
#             ((0, 0), 133.5, 86.4, 0.01      , 'green'),
#             ((0, 21), 133.5, 86.4, 0.02375   , 'green'),
#             ((0, 22), 133.5, 86.4, 0.0375    , 'green'),
#             ((0, 49), 133.5, 86.4, 0.05125   , 'green'),
#             ((0, 50), 133.5, 86.4, 0.065     , 'green'),
#             ((0, 82), 133.5, 86.4, 0.07875   , 'green'),
#             ((0, 83), 133.5, 86.4, 0.0925    , 'green'),
#             ((0, 114), 133.5, 86.4, 0.10625   , 'green'),
#             ((0, 115), 133.5, 86.4, 0.12      , 'green'),
#             ((0, 148), 133.5, 86.4, 0.13375   , 'green'),
#             ((0, 149), 133.5, 86.4, 0.1475    , 'green'),
#             ((0, 184), 133.5, 86.4, 0.16125   , 'green'),
#             ((0, 185), 133.5, 86.4, 0.175     , 'green'),
#             ((0, 222), 133.5, 86.4, 0.18875   , 'green'),
#             ((0, 223), 133.5, 86.4, 0.2025    , 'green'),
#             ((0, 262), 133.5, 86.4, 0.21625   , 'green'),
#             ((0, 263), 133.5, 86.4, 0.23      , 'green'),
#             ((0, 345), 133.5, 86.4, 0.24375   , 'green'),
#             ((0, 429), 133.5, 86.4, 0.2575    , 'green'),
#             ((0, 505), 133.5, 86.4, 0.27125   , 'green'),
#             ((0, 585), 133.5, 86.4, 0.285     , 'green'),
#             ((0, 666), 133.5, 86.4, 0.29875   , 'green'),
#             ((0, 748), 133.5, 86.4, 0.3125    , 'green'),
#             ((0, 831), 133.5, 86.4, 0.32625   , 'green'),
#             ((0, 914), 133.5, 86.4, 0.34      , 'green'),
#             ((0, 915), 133.5, 86.4, 0.35375   , 'green'),
#             ((0, 1000), 133.5, 86.4, 0.3675    , 'green'),
#             ((0, 1001), 133.5, 86.4, 0.38125   , 'green'),
#             ((0, 1082), 133.5, 86.4, 0.395     , 'green'),
#             ((0, 1083), 133.5, 86.4, 0.40875   , 'green'),
#             ((0, 1166), 133.5, 86.4, 0.4225    , 'green'),
#             ((0, 1167), 133.5, 86.4, 0.43625   , 'green'),
#             ((0, 1255), 133.5, 86.4, 0.45      , 'green'),
#             ((0, 1256), 133.5, 86.4, 0.46375   , 'green'),
#             ((0, 1349), 133.5, 86.4, 0.4775    , 'green'),
#             ((0, 1350), 133.5, 86.4, 0.49125   , 'green'),
#             ((0, 1436), 133.5, 86.4, 0.505     , 'green'),
#             ((0, 1437), 133.5, 86.4, 0.51875   , 'green'),
#             ((0, 1534), 133.5, 86.4, 0.5325    , 'green'),
#             ((0, 1535), 133.5, 86.4, 0.54625   , 'green'),
#             ((0, 1628), 133.5, 86.4, 0.56      , 'green'),
#             ((0, 1629), 133.5, 86.4, 0.57375   , 'green'),
#             ((0, 1745), 133.5, 86.4, 0.5875    , 'green'),
#             ((0, 1746), 133.5, 86.4, 0.60125   , 'green'),
#             ((0, 1828), 133.5, 86.4, 0.615     , 'green'),
#             ((0, 1829), 133.5, 86.4, 0.62875   , 'green'),
#             ((0, 1901), 133.5, 86.4, 0.6425    , 'green'),
#             ((0, 1902), 133.5, 86.4, 0.65625   , 'green'),
#             ((0, 1976), 133.5, 86.4, 0.67      , 'green'),
#             ((0, 1977), 133.5, 86.4, 0.68375   , 'green'),
#             ((0, 2050), 133.5, 86.4, 0.6975    , 'green'),
#             ((0, 2051), 133.5, 86.4, 0.71125   , 'green'),
#             ((0, 2123), 133.5, 86.4, 0.725     , 'green'),
#             ((0, 2124), 133.5, 86.4, 0.73875   , 'green'),
#             ((0, 2192), 133.5, 86.4, 0.7525    , 'green'),
#             ((0, 2193), 133.5, 86.4, 0.76625   , 'green'),
#             ((0, 2263), 133.5, 86.4, 0.78      , 'green'),
#             ((0, 2264), 133.5, 86.4, 0.79375   , 'green'),
#             ((0, 2369), 133.5, 86.4, 0.8075    , 'green'),
#             ((0, 2370), 133.5, 86.4, 0.82125   , 'green'),
#             ((0, 2477), 133.5, 86.4, 0.835     , 'green'),
#             ((0, 2478), 133.5, 86.4, 0.84875   , 'green'),
#             ((0, 2560), 133.5, 86.4, 0.8625    , 'green'),
#             ((0, 2561), 133.5, 86.4, 0.87625   , 'green'),
#             ((0, 2646), 133.5, 86.4, 0.89      , 'green'),
#             ((0, 2647), 133.5, 86.4, 0.90375   , 'green'),
#             ((0, 2712), 133.5, 86.4, 0.9175    , 'green'),
#             ((0, 2713), 133.5, 86.4, 0.93125   , 'green'),
#             ((0, 2776), 133.5, 86.4, 0.945     , 'green'),
#             ((0, 2777), 133.5, 86.4, 0.95875   , 'green'),
#             ((0, 2843), 133.5, 86.4, 0.9725    , 'green'),
#             ((0, 2844), 133.5, 86.4, 0.98625   , 'green'),
#             ((0, 2901), 133.5, 86.4, 1.        , 'green'),
#             ((0, 1), 136.5, 86.4, 1.        , 'blue'),
#             ((0, 2), 136.5, 86.4, 0.98544118, 'blue'),
#             ((0, 3), 136.5, 86.4, 0.97088235, 'blue'),
#             ((0, 4), 136.5, 86.4, 0.95632353, 'blue'),
#             ((0, 5), 136.5, 86.4, 0.94176471, 'blue'),
#             ((0, 6), 136.5, 86.4, 0.92720588, 'blue'),
#             ((0, 7), 136.5, 86.4, 0.91264706, 'blue'),
#             ((0, 8), 136.5, 86.4, 0.89808824, 'blue'),
#             ((0, 9), 136.5, 86.4, 0.88352941, 'blue'),
#             ((0, 10), 136.5, 86.4, 0.86897059, 'blue'),
#             ((0, 11), 136.5, 86.4, 0.85441176, 'blue'),
#             ((0, 12), 136.5, 86.4, 0.83985294, 'blue'),
#             ((0, 13), 136.5, 86.4, 0.82529412, 'blue'),
#             ((0, 14), 136.5, 86.4, 0.81073529, 'blue'),
#             ((0, 15), 136.5, 86.4, 0.79617647, 'blue'),
#             ((0, 16), 136.5, 86.4, 0.78161765, 'blue'),
#             ((0, 17), 136.5, 86.4, 0.76705882, 'blue'),
#             ((0, 18), 136.5, 86.4, 0.7525    , 'blue'),
#             ((0, 19), 136.5, 86.4, 0.73794118, 'blue'),
#             ((0, 20), 136.5, 86.4, 0.72338235, 'blue'),
#             ((0, 47), 136.5, 86.4, 0.70882353, 'blue'),
#             ((0, 48), 136.5, 86.4, 0.69426471, 'blue'),
#             ((0, 80), 136.5, 86.4, 0.67970588, 'blue'),
#             ((0, 81), 136.5, 86.4, 0.66514706, 'blue'),
#             ((0, 112), 136.5, 86.4, 0.65058824, 'blue'),
#             ((0, 113), 136.5, 86.4, 0.63602941, 'blue'),
#             ((0, 146), 136.5, 86.4, 0.62147059, 'blue'),
#             ((0, 147), 136.5, 86.4, 0.60691176, 'blue'),
#             ((0, 182), 136.5, 86.4, 0.59235294, 'blue'),
#             ((0, 183), 136.5, 86.4, 0.57779412, 'blue'),
#             ((0, 220), 136.5, 86.4, 0.56323529, 'blue'),
#             ((0, 221), 136.5, 86.4, 0.54867647, 'blue'),
#             ((0, 260), 136.5, 86.4, 0.53411765, 'blue'),
#             ((0, 261), 136.5, 86.4, 0.51955882, 'blue'),
#             ((0, 308), 136.5, 86.4, 0.505     , 'blue'),
#             ((0, 309), 136.5, 86.4, 0.49044118, 'blue'),
#             ((0, 310), 136.5, 86.4, 0.47588235, 'blue'),
#             ((0, 311), 136.5, 86.4, 0.46132353, 'blue'),
#             ((0, 312), 136.5, 86.4, 0.44676471, 'blue'),
#             ((0, 313), 136.5, 86.4, 0.43220588, 'blue'),
#             ((0, 314), 136.5, 86.4, 0.41764706, 'blue'),
#             ((0, 315), 136.5, 86.4, 0.40308824, 'blue'),
#             ((0, 316), 136.5, 86.4, 0.38852941, 'blue'),
#             ((0, 317), 136.5, 86.4, 0.37397059, 'blue'),
#             ((0, 318), 136.5, 86.4, 0.35941176, 'blue'),
#             ((0, 319), 136.5, 86.4, 0.34485294, 'blue'),
#             ((0, 320), 136.5, 86.4, 0.33029412, 'blue'),
#             ((0, 321), 136.5, 86.4, 0.31573529, 'blue'),
#             ((0, 322), 136.5, 86.4, 0.30117647, 'blue'),
#             ((0, 323), 136.5, 86.4, 0.28661765, 'blue'),
#             ((0, 324), 136.5, 86.4, 0.27205882, 'blue'),
#             ((0, 325), 136.5, 86.4, 0.2575    , 'blue'),
#             ((0, 326), 136.5, 86.4, 0.24294118, 'blue'),
#             ((0, 327), 136.5, 86.4, 0.22838235, 'blue'),
#             ((0, 328), 136.5, 86.4, 0.21382353, 'blue'),
#             ((0, 329), 136.5, 86.4, 0.19926471, 'blue'),
#             ((0, 330), 136.5, 86.4, 0.18470588, 'blue'),
#             ((0, 331), 136.5, 86.4, 0.17014706, 'blue'),
#             ((0, 332), 136.5, 86.4, 0.15558824, 'blue'),
#             ((0, 333), 136.5, 86.4, 0.14102941, 'blue'),
#             ((0, 334), 136.5, 86.4, 0.12647059, 'blue'),
#             ((0, 335), 136.5, 86.4, 0.11191176, 'blue'),
#             ((0, 336), 136.5, 86.4, 0.09735294, 'blue'),
#             ((0, 337), 136.5, 86.4, 0.08279412, 'blue'),
#             ((0, 338), 136.5, 86.4, 0.06823529, 'blue'),
#             ((0, 339), 136.5, 86.4, 0.05367647, 'blue'),
#             ((0, 340), 136.5, 86.4, 0.03911765, 'blue'),
#             ((0, 341), 136.5, 86.4, 0.02455882, 'blue'),
#             ((0, 342), 136.5, 86.4, 0.01      , 'blue')],
#            dtype=[('cellid', 'O'), ('bhead', '<f8'), ('cond', '<f8'), ('multiplier', '<f8'), ('boundname', 'O')])}

# %% [markdown]
# Construct new GHB stress period data:

# %%
bhead = ['ghb_'+i for i in ghb.stress_period_data.data[0].boundname]
cond = [86.4 for i in ghb.stress_period_data.data[0].boundname]
bname = [i for i in ghb.stress_period_data.data[0].boundname]

# %%
# Kanske behöver vara tuple
ghb_new_data = [[(0, cell_id), bhead, cond, 1., bname] for cell_id, bhead, cond, bname in zip(ghb_cell_ids, bhead, cond, bname)]

# %%
ghb_new_spd = {0: ghb_new_data}

# %%
ghb_new_spd
# Out:
# {0: [[(0, 343), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 344), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 427), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 428), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 503), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 504), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 583), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 584), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 664), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 665), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 746), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 747), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 829), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 830), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 913), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 999), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1081), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1165), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1254), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1348), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1435), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1533), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1627), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1744), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1827), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1900), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 1975), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2049), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2122), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2191), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2262), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2368), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2476), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2559), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2644), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2645), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2710), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2711), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2774), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2775), 'ghb_red', 86.4, 1.0, 'red'],
#   [(0, 2767), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2768), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2769), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2770), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2771), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2772), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2773), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2840), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2841), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2842), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2898), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2899), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2900), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2902), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2951), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2952), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2953), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2954), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2988), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2989), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2990), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2991), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2992), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2998), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 2999), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3000), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3001), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3002), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3003), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3004), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3010), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3011), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3012), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3013), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3014), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3015), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3016), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3017), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3018), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3019), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3020), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3021), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3022), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3023), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3024), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3025), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3026), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3027), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3028), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3029), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3030), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3031), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3032), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3033), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3034), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3035), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3036), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3037), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3038), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 3039), 'ghb_yellow', 86.4, 1.0, 'yellow'],
#   [(0, 0), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 21), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 22), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 49), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 50), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 82), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 83), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 114), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 115), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 148), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 149), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 184), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 185), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 222), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 223), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 262), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 263), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 345), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 429), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 505), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 585), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 666), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 748), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 831), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 914), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 915), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1000), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1001), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1082), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1083), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1166), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1167), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1255), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1256), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1349), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1350), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1436), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1437), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1534), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1535), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1628), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1629), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1745), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1746), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1828), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1829), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1901), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1902), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1976), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1977), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2050), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2051), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2123), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2124), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2192), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2193), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2263), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2264), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2369), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2370), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2477), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2478), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2560), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2561), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2646), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2647), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2712), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2713), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2776), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2777), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2843), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2844), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 2901), 'ghb_green', 86.4, 1.0, 'green'],
#   [(0, 1), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 2), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 3), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 4), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 5), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 6), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 7), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 8), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 9), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 10), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 11), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 12), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 13), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 14), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 15), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 16), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 17), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 18), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 19), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 20), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 47), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 48), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 80), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 81), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 112), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 113), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 146), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 147), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 182), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 183), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 220), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 221), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 260), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 261), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 308), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 309), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 310), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 311), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 312), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 313), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 314), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 315), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 316), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 317), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 318), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 319), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 320), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 321), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 322), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 323), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 324), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 325), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 326), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 327), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 328), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 329), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 330), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 331), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 332), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 333), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 334), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 335), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 336), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 337), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 338), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 339), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 340), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 341), 'ghb_blue', 86.4, 1.0, 'blue'],
#   [(0, 342), 'ghb_blue', 86.4, 1.0, 'blue']]}

# %% [markdown]
# Remove old GHB package:

# %%
gwf.remove_package('ghb')

# %% [markdown]
# Clean up stale files associated with the GHB package:

# %%
for file in os.listdir(tmp_model_ws):
    if '.ghb' in file:
        os.remove(os.path.join(tmp_model_ws, file))

# %% [markdown]
# Instantiate new GHB package:

# %%
ghb = flopy.mf6.modflow.mfgwfghb.ModflowGwfghb(
    gwf,
    print_input=True,
    print_flows=True,
    save_flows=True,
    boundnames=True, 
    auxiliary='MULTIPLIER',
    auxmultname='MULTIPLIER',
    pname='ghb',
    stress_period_data=ghb_new_spd
)

# %% [markdown]
# Display the new data structure:

# %%
ghb.stress_period_data.data
# Out:
# {0: rec.array([((0, 343), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 344), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 427), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 428), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 503), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 504), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 583), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 584), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 664), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 665), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 746), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 747), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 829), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 830), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 913), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 999), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1081), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1165), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1254), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1348), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1435), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1533), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1627), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1744), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1827), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1900), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 1975), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2049), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2122), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2191), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2262), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2368), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2476), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2559), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2644), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2645), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2710), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2711), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2774), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2775), 'ghb_red', 86.4, 1., 'red'),
#             ((0, 2767), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2768), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2769), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2770), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2771), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2772), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2773), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2840), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2841), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2842), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2898), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2899), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2900), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2902), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2951), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2952), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2953), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2954), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2988), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2989), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2990), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2991), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2992), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2998), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 2999), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3000), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3001), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3002), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3003), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3004), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3010), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3011), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3012), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3013), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3014), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3015), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3016), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3017), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3018), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3019), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3020), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3021), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3022), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3023), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3024), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3025), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3026), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3027), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3028), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3029), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3030), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3031), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3032), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3033), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3034), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3035), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3036), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3037), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3038), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 3039), 'ghb_yellow', 86.4, 1., 'yellow'),
#             ((0, 0), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 21), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 22), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 49), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 50), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 82), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 83), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 114), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 115), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 148), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 149), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 184), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 185), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 222), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 223), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 262), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 263), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 345), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 429), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 505), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 585), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 666), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 748), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 831), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 914), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 915), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1000), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1001), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1082), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1083), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1166), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1167), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1255), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1256), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1349), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1350), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1436), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1437), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1534), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1535), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1628), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1629), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1745), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1746), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1828), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1829), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1901), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1902), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1976), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1977), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2050), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2051), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2123), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2124), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2192), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2193), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2263), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2264), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2369), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2370), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2477), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2478), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2560), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2561), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2646), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2647), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2712), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2713), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2776), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2777), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2843), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2844), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 2901), 'ghb_green', 86.4, 1., 'green'),
#             ((0, 1), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 2), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 3), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 4), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 5), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 6), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 7), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 8), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 9), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 10), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 11), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 12), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 13), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 14), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 15), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 16), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 17), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 18), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 19), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 20), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 47), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 48), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 80), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 81), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 112), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 113), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 146), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 147), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 182), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 183), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 220), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 221), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 260), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 261), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 308), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 309), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 310), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 311), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 312), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 313), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 314), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 315), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 316), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 317), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 318), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 319), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 320), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 321), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 322), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 323), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 324), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 325), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 326), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 327), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 328), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 329), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 330), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 331), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 332), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 333), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 334), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 335), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 336), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 337), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 338), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 339), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 340), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 341), 'ghb_blue', 86.4, 1., 'blue'),
#             ((0, 342), 'ghb_blue', 86.4, 1., 'blue')],
#            dtype=[('cellid', 'O'), ('bhead', 'O'), ('cond', '<f8'), ('MULTIPLIER', '<f8'), ('boundname', 'O')])}

# %%
# Initialize ts-file
ghb.ts.initialize(filename='ghb_new.ts')

# %% [markdown]
# Write simulation files:

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing ims package hagfors_1...
#   writing model hagfors_1...
#     writing model name file...
#     writing package disv...
#     writing package sto...
#     writing package oc...
#     writing package npf...
#     writing package ic...
#     writing package sfr_ts...
#     writing package sfr_ts...
#     writing package sfr_ts...
#     writing package sfr_obs...
#     writing package sfr...
#     writing package gwf_obs...
#     writing package rch...
# INFORMATION: maxbound in ('gwf6', 'rch', 'dimensions') changed to 2798 based on size of stress_period_data
#     writing package ts_0...
#     writing package ghb...
# INFORMATION: maxbound in ('gwf6', 'ghb', 'dimensions') changed to 242 based on size of stress_period_data
#     writing package ts_1...

# %% [markdown]
# Move TS files:

# %%
ts_files = ['rch_new.ts', 'ghb_new.ts', 'sfr_reach_rainfall.ts', 'sfr_reach_evaporation.ts']
for file in ts_files:
    lumprem_ts = os.path.join(lr_ws, file)
    flopy_ts = os.path.join(tmp_model_ws, file)
    shutil.move(lumprem_ts, flopy_ts)

# %% [markdown]
# Move template files:

# %%
template_files = [i for i in os.listdir(lr_ws) if '.tpl' in i]

# %%
for file in template_files:
    lumprem_template = os.path.join(lr_ws, file)
    flopy_template = os.path.join(tmp_model_ws, file)
    shutil.move(lumprem_template, flopy_template)

# %% [markdown]
# One last thing before running the simulation. Current version of Flopy appends `.\` to components in the .nam-file. This will cause problems when the model is transferred onto a linux environment. For this reason any line in the .nam file appended with `.\` will have to be edited. Might as well do it during this step:

# %%
def replace_in_file(path, input_file, original_str, replacement_str):
    # Read in the file
    with open(os.path.join(path, input_file), 'r') as file :
        filedata = file.read()

    # Replace the target string
    filedata = filedata.replace(original_str, replacement_str)

    # Write the file out again
    with open(os.path.join(path, input_file), 'w') as file:
        file.write(filedata)

# %%
# Comment out kriging factors
replace_in_file(tmp_model_ws, f'{ml_name}.nam', '.\\', '')

# %%
sim.run_simulation()
# Out:
# FloPy is using the following executable to run the model: ..\bins\win\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 01/22/2022
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Jan 22 2022 02:25:10 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.5.0
#                              Build 20211109_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/02/02 10:55:38
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     2    Time step:     2
#     Solving:  Stress period:     2    Time step:     3
#     Solving:  Stress period:     2    Time step:     4
#     Solving:  Stress period:     2    Time step:     5
#     Solving:  Stress period:     2    Time step:     6
#     Solving:  Stress period:     2    Time step:     7
#     Solving:  Stress period:     2    Time step:     8
#     Solving:  Stress period:     2    Time step:     9
#     Solving:  Stress period:     2    Time step:    10
#     Solving:  Stress period:     2    Time step:    11
#     Solving:  Stress period:     2    Time step:    12
#     Solving:  Stress period:     2    Time step:    13
#     Solving:  Stress period:     2    Time step:    14
#     Solving:  Stress period:     2    Time step:    15
#     Solving:  Stress period:     2    Time step:    16
#     Solving:  Stress period:     2    Time step:    17
#     Solving:  Stress period:     2    Time step:    18
#     Solving:  Stress period:     2    Time step:    19
#     Solving:  Stress period:     2    Time step:    20
#     Solving:  Stress period:     2    Time step:    21
#     Solving:  Stress period:     2    Time step:    22
#     Solving:  Stress period:     2    Time step:    23
#     Solving:  Stress period:     2    Time step:    24
#     Solving:  Stress period:     2    Time step:    25
#     Solving:  Stress period:     2    Time step:    26
#     Solving:  Stress period:     2    Time step:    27
#     Solving:  Stress period:     2    Time step:    28
#     Solving:  Stress period:     2    Time step:    29
#     Solving:  Stress period:     2    Time step:    30
#     Solving:  Stress period:     2    Time step:    31
#     Solving:  Stress period:     2    Time step:    32
#     Solving:  Stress period:     2    Time step:    33
#     Solving:  Stress period:     2    Time step:    34
#     Solving:  Stress period:     2    Time step:    35
#     Solving:  Stress period:     2    Time step:    36
#     Solving:  Stress period:     2    Time step:    37
#     Solving:  Stress period:     2    Time step:    38
#     Solving:  Stress period:     2    Time step:    39
#     Solving:  Stress period:     2    Time step:    40
#     Solving:  Stress period:     2    Time step:    41
#     Solving:  Stress period:     2    Time step:    42
#     Solving:  Stress period:     2    Time step:    43
#     Solving:  Stress period:     2    Time step:    44
#     Solving:  Stress period:     2    Time step:    45
#     Solving:  Stress period:     2    Time step:    46
#     Solving:  Stress period:     2    Time step:    47
#     Solving:  Stress period:     2    Time step:    48
#     Solving:  Stress period:     2    Time step:    49
#     Solving:  Stress period:     2    Time step:    50
#     Solving:  Stress period:     2    Time step:    51
#     Solving:  Stress period:     2    Time step:    52
#     Solving:  Stress period:     2    Time step:    53
#     Solving:  Stress period:     2    Time step:    54
#     Solving:  Stress period:     2    Time step:    55
#     Solving:  Stress period:     2    Time step:    56
#     Solving:  Stress period:     2    Time step:    57
#     Solving:  Stress period:     2    Time step:    58
#     Solving:  Stress period:     2    Time step:    59
#     Solving:  Stress period:     2    Time step:    60
#     Solving:  Stress period:     2    Time step:    61
#     Solving:  Stress period:     2    Time step:    62
#     Solving:  Stress period:     2    Time step:    63
#     Solving:  Stress period:     2    Time step:    64
#     Solving:  Stress period:     2    Time step:    65
#     Solving:  Stress period:     2    Time step:    66
#     Solving:  Stress period:     2    Time step:    67
#     Solving:  Stress period:     2    Time step:    68
#     Solving:  Stress period:     2    Time step:    69
#     Solving:  Stress period:     2    Time step:    70
#     Solving:  Stress period:     2    Time step:    71
#     Solving:  Stress period:     2    Time step:    72
#     Solving:  Stress period:     2    Time step:    73
#     Solving:  Stress period:     2    Time step:    74
#     Solving:  Stress period:     2    Time step:    75
#     Solving:  Stress period:     2    Time step:    76
#     Solving:  Stress period:     2    Time step:    77
#     Solving:  Stress period:     2    Time step:    78
#     Solving:  Stress period:     2    Time step:    79
#     Solving:  Stress period:     2    Time step:    80
#     Solving:  Stress period:     2    Time step:    81
#     Solving:  Stress period:     2    Time step:    82
#     Solving:  Stress period:     2    Time step:    83
#     Solving:  Stress period:     2    Time step:    84
#     Solving:  Stress period:     2    Time step:    85
#     Solving:  Stress period:     2    Time step:    86
#     Solving:  Stress period:     2    Time step:    87
#     Solving:  Stress period:     2    Time step:    88
#     Solving:  Stress period:     2    Time step:    89
#     Solving:  Stress period:     2    Time step:    90
#     Solving:  Stress period:     2    Time step:    91
#     Solving:  Stress period:     2    Time step:    92
#     Solving:  Stress period:     2    Time step:    93
#     Solving:  Stress period:     2    Time step:    94
#     Solving:  Stress period:     2    Time step:    95
#     Solving:  Stress period:     2    Time step:    96
#     Solving:  Stress period:     2    Time step:    97
#     Solving:  Stress period:     2    Time step:    98
#     Solving:  Stress period:     2    Time step:    99
#     Solving:  Stress period:     2    Time step:   100
#     Solving:  Stress period:     2    Time step:   101
#     Solving:  Stress period:     2    Time step:   102
#     Solving:  Stress period:     2    Time step:   103
#     Solving:  Stress period:     2    Time step:   104
#     Solving:  Stress period:     2    Time step:   105
#     Solving:  Stress period:     2    Time step:   106
#     Solving:  Stress period:     2    Time step:   107
#     Solving:  Stress period:     2    Time step:   108
#     Solving:  Stress period:     2    Time step:   109
#     Solving:  Stress period:     2    Time step:   110
#     Solving:  Stress period:     2    Time step:   111
#     Solving:  Stress period:     2    Time step:   112
#     Solving:  Stress period:     2    Time step:   113
#     Solving:  Stress period:     2    Time step:   114
#     Solving:  Stress period:     2    Time step:   115
#     Solving:  Stress period:     2    Time step:   116
#     Solving:  Stress period:     2    Time step:   117
#     Solving:  Stress period:     2    Time step:   118
#     Solving:  Stress period:     2    Time step:   119
#     Solving:  Stress period:     2    Time step:   120
#     Solving:  Stress period:     2    Time step:   121
#     Solving:  Stress period:     2    Time step:   122
#     Solving:  Stress period:     2    Time step:   123
#     Solving:  Stress period:     2    Time step:   124
#     Solving:  Stress period:     2    Time step:   125
#     Solving:  Stress period:     2    Time step:   126
#     Solving:  Stress period:     2    Time step:   127
#     Solving:  Stress period:     2    Time step:   128
#     Solving:  Stress period:     2    Time step:   129
#     Solving:  Stress period:     2    Time step:   130
#     Solving:  Stress period:     2    Time step:   131
#     Solving:  Stress period:     2    Time step:   132
#     Solving:  Stress period:     2    Time step:   133
#     Solving:  Stress period:     2    Time step:   134
#     Solving:  Stress period:     2    Time step:   135
#     Solving:  Stress period:     2    Time step:   136
#     Solving:  Stress period:     2    Time step:   137
#     Solving:  Stress period:     2    Time step:   138
#     Solving:  Stress period:     2    Time step:   139
#     Solving:  Stress period:     2    Time step:   140
#     Solving:  Stress period:     2    Time step:   141
#     Solving:  Stress period:     2    Time step:   142
#     Solving:  Stress period:     2    Time step:   143
#     Solving:  Stress period:     2    Time step:   144
#     Solving:  Stress period:     2    Time step:   145
#     Solving:  Stress period:     2    Time step:   146
#     Solving:  Stress period:     2    Time step:   147
#     Solving:  Stress period:     2    Time step:   148
#     Solving:  Stress period:     2    Time step:   149
#     Solving:  Stress period:     2    Time step:   150
#     Solving:  Stress period:     2    Time step:   151
#     Solving:  Stress period:     2    Time step:   152
#     Solving:  Stress period:     2    Time step:   153
#     Solving:  Stress period:     2    Time step:   154
#     Solving:  Stress period:     2    Time step:   155
#     Solving:  Stress period:     2    Time step:   156
#     Solving:  Stress period:     2    Time step:   157
#     Solving:  Stress period:     2    Time step:   158
#     Solving:  Stress period:     2    Time step:   159
#     Solving:  Stress period:     2    Time step:   160
#     Solving:  Stress period:     2    Time step:   161
#     Solving:  Stress period:     2    Time step:   162
#     Solving:  Stress period:     2    Time step:   163
#     Solving:  Stress period:     2    Time step:   164
#     Solving:  Stress period:     2    Time step:   165
#     Solving:  Stress period:     2    Time step:   166
#     Solving:  Stress period:     2    Time step:   167
#     Solving:  Stress period:     2    Time step:   168
#     Solving:  Stress period:     2    Time step:   169
#     Solving:  Stress period:     2    Time step:   170
#     Solving:  Stress period:     2    Time step:   171
#     Solving:  Stress period:     2    Time step:   172
#     Solving:  Stress period:     2    Time step:   173
#     Solving:  Stress period:     2    Time step:   174
#     Solving:  Stress period:     2    Time step:   175
#     Solving:  Stress period:     2    Time step:   176
#     Solving:  Stress period:     2    Time step:   177
#     Solving:  Stress period:     2    Time step:   178
#     Solving:  Stress period:     2    Time step:   179
#     Solving:  Stress period:     2    Time step:   180
#     Solving:  Stress period:     2    Time step:   181
#     Solving:  Stress period:     2    Time step:   182
#     Solving:  Stress period:     2    Time step:   183
#     Solving:  Stress period:     2    Time step:   184
#     Solving:  Stress period:     2    Time step:   185
#     Solving:  Stress period:     2    Time step:   186
#     Solving:  Stress period:     2    Time step:   187
#     Solving:  Stress period:     2    Time step:   188
#     Solving:  Stress period:     2    Time step:   189
#     Solving:  Stress period:     2    Time step:   190
#     Solving:  Stress period:     2    Time step:   191
#     Solving:  Stress period:     2    Time step:   192
#     Solving:  Stress period:     2    Time step:   193
#     Solving:  Stress period:     2    Time step:   194
#     Solving:  Stress period:     2    Time step:   195
#     Solving:  Stress period:     2    Time step:   196
#     Solving:  Stress period:     2    Time step:   197
#     Solving:  Stress period:     2    Time step:   198
#     Solving:  Stress period:     2    Time step:   199
#     Solving:  Stress period:     2    Time step:   200
#     Solving:  Stress period:     2    Time step:   201
#     Solving:  Stress period:     2    Time step:   202
#     Solving:  Stress period:     2    Time step:   203
#     Solving:  Stress period:     2    Time step:   204
#     Solving:  Stress period:     2    Time step:   205
#     Solving:  Stress period:     2    Time step:   206
#     Solving:  Stress period:     2    Time step:   207
#     Solving:  Stress period:     2    Time step:   208
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2022/02/02 10:56:23
#  Elapsed run time: 44.700 Seconds
#
#  Normal termination of simulation.
# (True, [])

# %%
# check the output
csv = os.path.join(tmp_model_ws,'head.obs.csv')
df = pd.read_csv(csv)

# %%
df.columns
# Out:
# Index(['time', 'B10-1', 'B14-1', 'B15-1', 'B16-1', 'B2-1', 'B22-1', 'B26',
#        'B29', 'B34', 'B35', 'B36', 'B37', 'B4', 'B8-2', 'B9-2', 'KB1-1',
#        'KB4-3', 'NI1403-2', 'NI1404-1', 'NI1405-1', 'NI1407-2', 'NI1408-1',
#        'NI1409-1', 'NI1410-1', 'NI1412-1', 'NI15-O1', 'NI15-O44', 'NI15-O46',
#        'NI15-O47', 'NI15-O48', 'NI1501-3', 'NI1502-2', 'NI1504-2', 'NI1505-2',
#        'NI1506-1', 'NI1507-2', 'NI1601-3', 'NI1602-1', 'NI1603-1', 'NI1605-1',
#        'NI1606-1', 'NI1607-2', 'NI1608-1', 'NI1609-2', 'NI1610-2', 'NI1611-1',
#        'NI1612-1', 'NI1613-1', 'NI1701-1', 'NI1702-1', 'NI1703-1', 'NI1704-1',
#        'NI1705-1', 'NI1706-1', 'NI1707-1', 'NI1708-1', 'NI1709-1', 'NI1711-1',
#        'NI1712-1', 'NI1801-1', 'NI1802-1', 'NI1803-1', 'NI1804-1'],
#       dtype='object')

# %%
df['B10-1'].plot()
# Out:
# <AxesSubplot:>

# %%
headfile = '{}.hds'.format(ml_name)
fname = os.path.join(tmp_model_ws, headfile)
hds = flopy.utils.binaryfile.HeadFile(fname)
h = hds.get_data()

# %%
fig = plt.figure(figsize=(18, 5))
ax = fig.add_subplot(1, 1, 1)
ax.set_title("Cross section plot")

xsection = np.array([(427000, 6654690), (427540, 6655230)])
xsect = flopy.plot.PlotCrossSection(model=gwf, line={"line": xsection})
patch_collection = xsect.plot_array(h, head=h, alpha=0.5)
line_collection = xsect.plot_grid()
cb = plt.colorbar(patch_collection, shrink=0.75)

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

modelmap = flopy.plot.PlotMapView(model=gwf)
linecollection = modelmap.plot_grid(lw=0.25)
contours = modelmap.contour_array(h)
    
plt.tight_layout()
plt.show()

# %%
# get the specific discharge from the cell budget file
cbb_file = os.path.join(tmp_model_ws, f'{ml_name}.cbb')
cbb = flopy.utils.CellBudgetFile(cbb_file)

# get the head from the head file
head_file = os.path.join(tmp_model_ws, f'{ml_name}.hds')
head = flopy.utils.HeadFile(head_file)
hdata = head.get_alldata()

# %%
spd = 1

fig = plt.figure(figsize=(12, 12), dpi=90)
ax = fig.add_subplot(1, 1, 1, aspect='equal')
plt.ticklabel_format(axis='both', style='plain', useOffset=False) #Show coordinates

mapview = flopy.plot.PlotMapView(gwf, layer=0)
linecollection = mapview.plot_grid(lw=0.25, color='k')
quadmesh = mapview.plot_array(a=hdata[spd], alpha=0.9, masked_values=[1e30])
plt.colorbar(quadmesh, shrink=0.4);

levels = np.arange(130, 145, 1.0)
contour_set = mapview.contour_array(hdata[spd], levels=levels, colors='white')
plt.clabel(contour_set, fmt="%.1f", colors='white', fontsize=11)


plt.title(f'Heads (spd: {spd})')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#Check the budget
mf_list = flopy.utils.Mf6ListBudget(os.path.join(tmp_model_ws, f"{gwf.name}.lst"), timeunit='days') #MF6ListBudget is different from MfListBudget...*sigh*
incremental, cumulative = mf_list.get_budget()
incrementaldf, cumulativedf = mf_list.get_dataframes(start_datetime="01-09-2017")

incrementaldf
# Out:
#             STO-SS_IN   STO-SY_IN        GHB_IN      RCH_IN       SFR_IN  \
# 2017-01-09   0.000000    0.000000  12722.579102  402.663208  5390.717773
# 2021-01-08   0.012727  242.386993  12595.339844  420.538605  5384.389648
#
#                 TOTAL_IN  STO-SS_OUT  STO-SY_OUT      GHB_OUT  RCH_OUT  \
# 2017-01-09  18515.960938         0.0         0.0  6334.598145      0.0
# 2021-01-08  18642.667969         0.0         0.0  6446.459961      0.0
#
#                  SFR_OUT     TOTAL_OUT     IN-OUT  PERCENT_DISCREPANCY
# 2017-01-09  12199.719727  18534.318359 -18.357599                 -0.1
# 2021-01-08  12196.213867  18642.673828  -0.006212                 -0.0

# %% [markdown]
# ---

# %% [markdown]
# End of notebook

# %% [markdown]
# ---

# %% [markdown]
# Delete LR to start over:

# %%
#shutil.rmtree(lr_ws)

# %% [markdown]
# | parameter | initial | upper bound | lower bound |
# | --------- |--------:|-------------| ------------|
# | Ks        | 86.4    | 8640.0      | 0.0000864   |
# | m         | 1.0     | 2.0         | 0.01        |
# | f         | 0.5     | 0.9         | 0.01        |
# | γ         | 1.0     | 10.0        | 0.01        |
# | f1        | 10.0    | 50.0        | 1.0         |
# | f2        | 1.0     | 100.0       | 0.1         |
# | p         | 1.0     | 100.0       | 0.01        |
# | a_red     | 141.0   | 144.0       | 137.5       |
# | a_yellow  | 139.0   | 136.0       | 142.0       |
# | a_green   | 133.0   | 128.0       | 136.0       |
# | a_blue    | 136.5   | 135.0       | 140.0       |
